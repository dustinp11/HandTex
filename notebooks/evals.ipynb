# %%
import torch
import numpy as np
import sys
import pickle
from pathlib import Path
from datasets import load_dataset

sys.path.insert(0, "models")

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
ARTIFACTS = Path("artifacts")

def normalized_edit_distance(s1, s2):
    if len(s1) == 0 and len(s2) == 0: return 0.0
    if len(s1) == 0 or  len(s2) == 0: return 1.0
    d = [[0] * (len(s2) + 1) for _ in range(len(s1) + 1)]
    for i in range(len(s1) + 1): d[i][0] = i
    for j in range(len(s2) + 1): d[0][j] = j
    for i in range(1, len(s1) + 1):
        for j in range(1, len(s2) + 1):
            cost = 0 if s1[i-1] == s2[j-1] else 1
            d[i][j] = min(d[i-1][j]+1, d[i][j-1]+1, d[i-1][j-1]+cost)
    return d[len(s1)][len(s2)] / max(len(s1), len(s2))

print(f"Device: {DEVICE}")
# Out:
# Device: cpu

# %%
N = 100
ds = load_dataset("deepcopy/MathWriting-human")
ds_test = ds["val"].select(range(N))
gt_latex = [s["latex"] for s in ds_test]
print(f"Loaded {N} samples from validation split")
print(f"Available splits: {list(ds.keys())}")
# Out:
# Loaded 100 samples from validation split
# Available splits: ['train', 'test', 'val']

# %%
from PIL import Image

def resize_pad_grayscale(img_pil: Image.Image, target=256, pad_value=255):
    """
    Resize keeping aspect ratio so longest side == target,
    then pad to (target, target) with white background.
    """
    img = img_pil.convert("L")
    w, h = img.size

    scale = target / max(w, h)
    new_w = max(1, int(round(w * scale)))
    new_h = max(1, int(round(h * scale)))

    img_rs = img.resize((new_w, new_h), resample=Image.BICUBIC)

    canvas = Image.new("L", (target, target), color=pad_value)
    left = (target - new_w) // 2
    top  = (target - new_h) // 2
    canvas.paste(img_rs, (left, top))

    return canvas

# %% [markdown]
# ## Eval 1 — DINOv2 with LoRa + LSTM (Bahdanau Attention)

# %%
from vit_lora_lstm_attn import ViTLatexModelLoRA as LSTMModel
from PIL import Image

# Tokenizer + special token indices
with open(ARTIFACTS / "lstm_tokenizer.pkl", "rb") as f:
    lstm_tok = pickle.load(f)
VOCAB_SIZE = 66



LSTM_START = VOCAB_SIZE - 2
LSTM_END = VOCAB_SIZE - 1
lstm_inv_vocab = {v: k for k, v in lstm_tok.word_index.items()}
print(f"vocab_size={VOCAB_SIZE}, START={LSTM_START}, END={LSTM_END}")

def lstm_decode(seq):
    return "".join(lstm_inv_vocab.get(t, "") for t in seq
                   if t not in (0, LSTM_START, LSTM_END))

# Load model
lstm_model = LSTMModel(vocab_size=VOCAB_SIZE, lora_r=16).to(DEVICE)
ckpt = torch.load(ARTIFACTS / "lstm(2).pt", map_location=DEVICE, weights_only=False)
lstm_model.load_state_dict(ckpt["model"])
lstm_model.eval()
print("LSTM model loaded.")

# Preprocess: RGB 224x224, /255, ImageNet norm (matches training)
MEAN = torch.tensor([0.485, 0.456, 0.406], device=DEVICE).view(1, 3, 1, 1)
STD  = torch.tensor([0.229, 0.224, 0.225], device=DEVICE).view(1, 3, 1, 1)

lstm_images = []
for s in ds_test:
    # Match training: grayscale and 256x256
    img = resize_pad_grayscale(img, target=256)
    img = np.array(img, dtype=np.float32) / 255.0 # normalize
    
    lstm_images.append(img)

# (N,256,256) -> torch uint8 (N,1,256,256)
lstm_images = np.array(lstm_images)
lstm_images = lstm_images[..., np.newaxis]
lstm_images = torch.tensor(lstm_images, dtype=torch.float32).permute(0, 3, 1, 2)

#lstm_images = torch.tensor(np.array(lstm_images), dtype=torch.float32).unsqueeze(1)
# repeat channels: (N,1,256,256) -> (N,3,256,256)
print(f"Preprocessed {N} images.")
# Out:
# vocab_size=66, START=64, END=65
# LSTM model loaded.
# Preprocessed 100 images.

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences

latex_list = [s["latex"] for s in ds_test]

seqs = lstm_tok.texts_to_sequences(latex_list)
seqs = [[LSTM_START] + s + [LSTM_END] for s in seqs]

tokens_val = torch.tensor(
    pad_sequences(seqs, padding="post"),
    dtype=torch.long
)

# %%
exact = 0
total_ed = 0.0
print(f"Evaluating LSTM on {N} test samples...")
print("-" * 60)

print("START/END from tokenizer:", lstm_tok.word_index.get("<START>"), lstm_tok.word_index.get("<END>"))
print("START/END you're using:", LSTM_START, LSTM_END)

for i in range(N):
    img = lstm_images[i:i+1]
    img = img.repeat(1, 3, 1, 1).to(DEVICE)
    # img = (img - MEAN) / STD
    gt_token = tokens_val[i]
    pred_tokens  = lstm_model.generate_beam(img, max_len = 150, sos_idx=LSTM_START, eos_idx=LSTM_END, beam_size = 5)
    #pred_tokens = lstm_model.generate(img, max_len = 150, sos_idx=LSTM_START, eos_idx=LSTM_END)
    prediction   = lstm_decode(pred_tokens)
    ground_truth = lstm_decode(gt_token.tolist())

    is_exact  = prediction == ground_truth
    edit_dist = normalized_edit_distance(prediction, ground_truth)
    if is_exact: exact += 1
    total_ed += edit_dist

    status = "EXACT" if is_exact else f"edit_dist={edit_dist:.4f}"
    print(f"  [{i+1:2d}/{N}] {status}")
    print(f"    GT:   {ground_truth[:80]}")
    print(f"    PRED: {prediction[:80]}")
    print("-" * 40)

print("=" * 60)
print("LSTM results")
print(f"Exact match: {exact/N:.2%} ({exact}/{N})")
print(f"Avg normalized edit: {total_ed/N:.4f}")
# Out:
# Evaluating LSTM on 100 test samples...
# ------------------------------------------------------------
# START/END from tokenizer: 64 65
# START/END you're using: 64 65
#   [ 1/100] EXACT
#     GT:   \frac{\partial\psi}{\partial t}=p\psi
#     PRED: \frac{\partial\psi}{\partial t}=p\psi
# ----------------------------------------
#   [ 2/100] edit_dist=0.1765
#     GT:   c_{0}=d/v_{blood}
#     PRED: c_{0}=d/v_{6log}
# ----------------------------------------
#   [ 3/100] EXACT
#     GT:   e^{2}/\hbar c\approx1/137
#     PRED: e^{2}/\hbar c\approx1/137
# ----------------------------------------
#   [ 4/100] edit_dist=0.5000
#     GT:   nassoc(s,\overline{s})
#     PRED: nassoc(s,s)
# ----------------------------------------
#   [ 5/100] edit_dist=0.4516
#     GT:   eq.1\frac{dv}{dx}=w
#     PRED: e_{q}\cdot1\frac{dv}{dx}=\omega
# ----------------------------------------
#   [ 6/100] EXACT
#     GT:   \underline{r}
#     PRED: \underline{r}
# ----------------------------------------
#   [ 7/100] EXACT
#     GT:   \hat{k}_{g}
#     PRED: \hat{k}_{g}
# ----------------------------------------
#   [ 8/100] edit_dist=0.0870
#     GT:   \int_{0}^{1}f(r)g(r)rdr
#     PRED: \int_{0}^{7}f(r)g(r)dr
# ----------------------------------------
#   [ 9/100] edit_dist=0.3636
#     GT:   \sigma_{b}=p\cdot\hat{n}_{out}
#     PRED: \sigma_{b}=\mathbb{\theta}\cdot\hat{n}_{ouf}
# ----------------------------------------
#   [10/100] edit_dist=0.2045
#     GT:   w_{i}^{*}=\frac{rgq_{bi}}{f_{i}u*^{3}}
#     PRED: w_{i}^{*}=\frac{r_{qq_{ii}}}{f_{i}u_{*}^{s}}
# ----------------------------------------
#   [11/100] edit_dist=0.0417
#     GT:   z\rightarrow-z^{5}+z_{0}
#     PRED: 2\rightarrow-z^{5}+z_{0}
# ----------------------------------------
#   [12/100] edit_dist=0.4706
#     GT:   1/(d_{i}d_{j})^{1/2}
#     PRED: 1/(\partial_{i}\partial_{j})^{1/2}
# ----------------------------------------
#   [13/100] EXACT
#     GT:   t_{r}^{\prime}=t-\frac{1}{c}|r-r^{\prime}|
#     PRED: t_{r}^{\prime}=t-\frac{1}{c}|r-r^{\prime}|
# ----------------------------------------
#   [14/100] edit_dist=0.2432
#     GT:   \frac{\partial h}{\partial z_{j}^{-}}
#     PRED: \frac{\partial n}{\partial z\rho}
# ----------------------------------------
#   [15/100] edit_dist=0.3529
#     GT:   {j^{\lambda}}^{y}
#     PRED: i^{\lambda y}
# ----------------------------------------
#   [16/100] edit_dist=0.1613
#     GT:   r_{i}\rightarrow r=\prod r_{i}
#     PRED: r_{i}\rightarrow r=\gamma r_{i}
# ----------------------------------------
#   [17/100] edit_dist=0.2903
#     GT:   \int_{0}^{1}\phi(p)dp=1
#     PRED: \int_{0}^{1}\phi(p)\partial p=1
# ----------------------------------------
#   [18/100] EXACT
#     GT:   h(x)=1_{(0,\infty)}(x)
#     PRED: h(x)=1_{(0,\infty)}(x)
# ----------------------------------------
#   [19/100] EXACT
#     GT:   \tilde{x}_{0}
#     PRED: \tilde{x}_{0}
# ----------------------------------------
#   [20/100] EXACT
#     GT:   \sqrt{n}/ln(\sqrt{n})
#     PRED: \sqrt{n}/ln(\sqrt{n})
# ----------------------------------------
#   [21/100] edit_dist=0.4444
#     GT:   a^{\prime}=\lambda_{1}a+\lambda_{2}b
#     PRED: a^{\prime}=\lambda,r+1,b
# ----------------------------------------
#   [22/100] EXACT
#     GT:   \lambda=\mu_{1}^{2}+\cdot\cdot\cdot+\mu_{k}^{2}
#     PRED: \lambda=\mu_{1}^{2}+\cdot\cdot\cdot+\mu_{k}^{2}
# ----------------------------------------
#   [23/100] edit_dist=0.0526
#     GT:   \int_{0}^{t}z_{s}ds
#     PRED: \int_{0}^{z}z_{s}ds
# ----------------------------------------
#   [24/100] edit_dist=0.1538
#     GT:   d_{x}(p+ta)=0
#     PRED: p_{x}(p+t)=0
# ----------------------------------------
#   [25/100] EXACT
#     GT:   \delta t=\dot{q}r
#     PRED: \delta t=\dot{q}r
# ----------------------------------------
#   [26/100] edit_dist=0.4167
#     GT:   h_{1}(g;z)=0
#     PRED: h,cg;z)=0
# ----------------------------------------
#   [27/100] edit_dist=0.3333
#     GT:   \prod_{i=0}^{k-1}(x-i)^{n}
#     PRED: \frac{k_{-1}}{u=0}^{k-1}(x-i)^{n}
# ----------------------------------------
#   [28/100] EXACT
#     GT:   v(r)=\frac{1}{2}m_{0}\omega^{2}r^{2}
#     PRED: v(r)=\frac{1}{2}m_{0}\omega^{2}r^{2}
# ----------------------------------------
#   [29/100] edit_dist=0.1176
#     GT:   z_{l}=r_{l}(\omega)+jx_{l}(\omega)
#     PRED: z_{2}=r_{2}(\omega)+jz_{z}(\omega)
# ----------------------------------------
#   [30/100] edit_dist=0.0278
#     GT:   \partial_{t}l=\frac{1}{2}\nabla^{2}l
#     PRED: \partial_{+}l=\frac{1}{2}\nabla^{2}l
# ----------------------------------------
#   [31/100] EXACT
#     GT:   \hat{r}\cdot\hat{e}_{3}
#     PRED: \hat{r}\cdot\hat{e}_{3}
# ----------------------------------------
#   [32/100] EXACT
#     GT:   c_{1},c_{2},...\in k
#     PRED: c_{1},c_{2},...\in k
# ----------------------------------------
#   [33/100] edit_dist=0.0769
#     GT:   \overline{op_{1}}^{\prime}
#     PRED: \overline{q_{1}}^{\prime}
# ----------------------------------------
#   [34/100] EXACT
#     GT:   a=(a_{ij})
#     PRED: a=(a_{ij})
# ----------------------------------------
#   [35/100] EXACT
#     GT:   \varphi\vdash\neg\psi
#     PRED: \varphi\vdash\neg\psi
# ----------------------------------------
#   [36/100] edit_dist=0.0952
#     GT:   \sqrt{n}/ln(\sqrt{n})
#     PRED: \sqrt{x}/ln(\sqrt{x})
# ----------------------------------------
#   [37/100] EXACT
#     GT:   a=\{a_{ij}\}_{i,j=0}^{p-1}
#     PRED: a=\{a_{ij}\}_{i,j=0}^{p-1}
# ----------------------------------------
#   [38/100] EXACT
#     GT:   c=\frac{6000}{200-2x}
#     PRED: c=\frac{6000}{200-2x}
# ----------------------------------------
#   [39/100] EXACT
#     GT:   \frac{\partial w}{\partial t}=f_{e}\cdot v
#     PRED: \frac{\partial w}{\partial t}=f_{e}\cdot v
# ----------------------------------------
#   [40/100] EXACT
#     GT:   a=(\begin{matrix}1&-2\\ 1&-1\end{matrix})
#     PRED: a=(\begin{matrix}1&-2\\ 1&-1\end{matrix})
# ----------------------------------------
#   [41/100] EXACT
#     GT:   (\begin{matrix}4\\ 2\end{matrix})
#     PRED: (\begin{matrix}4\\ 2\end{matrix})
# ----------------------------------------
#   [42/100] edit_dist=0.0625
#     GT:   \frac{x}{2\pi}=\frac{y}{2\pi r}=
#     PRED: \frac{x}{2\pi}=\frac{y}{2\pi}r=
# ----------------------------------------
#   [43/100] EXACT
#     GT:   f(r)=-\frac{k}{r^{3}}
#     PRED: f(r)=-\frac{k}{r^{3}}
# ----------------------------------------
#   [44/100] EXACT
#     GT:   \lambda_{2}=3-\sqrt{5}
#     PRED: \lambda_{2}=3-\sqrt{5}
# ----------------------------------------
#   [45/100] EXACT
#     GT:   \tilde{q}
#     PRED: \tilde{q}
# ----------------------------------------
#   [46/100] edit_dist=0.2000
#     GT:   gh^{\top}=p-p=0
#     PRED: gh^{t}=p-p=0
# ----------------------------------------
#   [47/100] EXACT
#     GT:   -s
#     PRED: -s
# ----------------------------------------
#   [48/100] EXACT
#     GT:   \sqrt{-7}
#     PRED: \sqrt{-7}
# ----------------------------------------
#   [49/100] EXACT
#     GT:   x=y=\frac{i}{\sqrt{2}}
#     PRED: x=y=\frac{i}{\sqrt{2}}
# ----------------------------------------
#   [50/100] EXACT
#     GT:   \frac{\partial u}{\partial t}=0
#     PRED: \frac{\partial u}{\partial t}=0
# ----------------------------------------
#   [51/100] EXACT
#     GT:   g=\int_{0}^{t}k(t)x(t)dt
#     PRED: g=\int_{0}^{t}k(t)x(t)dt
# ----------------------------------------
#   [52/100] EXACT
#     GT:   (\begin{matrix}2n-2\\ n-2\end{matrix})
#     PRED: (\begin{matrix}2n-2\\ n-2\end{matrix})
# ----------------------------------------
#   [53/100] edit_dist=0.0270
#     GT:   tr\{\begin{matrix}4\\ 3\end{matrix}\}
#     PRED: tr\{\begin{matrix}5\\ 3\end{matrix}\}
# ----------------------------------------
#   [54/100] EXACT
#     GT:   \sqrt{-1}
#     PRED: \sqrt{-1}
# ----------------------------------------
#   [55/100] edit_dist=0.0263
#     GT:   n=(\begin{matrix}2k-1\\ k\end{matrix})
#     PRED: h=(\begin{matrix}2k-1\\ k\end{matrix})
# ----------------------------------------
#   [56/100] edit_dist=0.3448
#     GT:   e^{2}=p\cdot p+{m_{0}}^{2}
#     PRED: e^{2}=\rho\cdot\rho+m_{0}^{2}
# ----------------------------------------
#   [57/100] EXACT
#     GT:   \sqrt{i}
#     PRED: \sqrt{i}
# ----------------------------------------
#   [58/100] edit_dist=0.7143
#     GT:   i_{f}(f)
#     PRED: \frac{i}{\sqrt{3}}(f)
# ----------------------------------------
#   [59/100] EXACT
#     GT:   \dot{\varphi}^{2}+\dot{\psi}^{2}=1
#     PRED: \dot{\varphi}^{2}+\dot{\psi}^{2}=1
# ----------------------------------------
#   [60/100] edit_dist=0.0500
#     GT:   \hat{t},\hat{\omega}
#     PRED: \hat{-},\hat{\omega}
# ----------------------------------------
#   [61/100] edit_dist=0.0714
#     GT:   f(x)=|x|^{k+1}
#     PRED: f(x)=|x|^{4+1}
# ----------------------------------------
#   [62/100] EXACT
#     GT:   (\begin{matrix}m\\ n\end{matrix})
#     PRED: (\begin{matrix}m\\ n\end{matrix})
# ----------------------------------------
#   [63/100] edit_dist=0.1333
#     GT:   [a_{j},a_{k}^{*}]=\delta_{j,k}
#     PRED: [a_{j},a_{k}]=\delta_{j,k}
# ----------------------------------------
#   [64/100] edit_dist=0.0690
#     GT:   f(g^{a}h^{c},g^{b}h^{d},\tau)
#     PRED: f(g^{a}h^{a}g^{b}h^{d},\tau)
# ----------------------------------------
#   [65/100] EXACT
#     GT:   \{\tilde{e}_{k}\}
#     PRED: \{\tilde{e}_{k}\}
# ----------------------------------------
#   [66/100] EXACT
#     GT:   (2^{r}+1)|(2^{k}+1)
#     PRED: (2^{r}+1)|(2^{k}+1)
# ----------------------------------------
#   [67/100] EXACT
#     GT:   \rho^{\prime\prime}=\sum_{n}p_{n}\rho p_{n}
#     PRED: \rho^{\prime\prime}=\sum_{n}p_{n}\rho p_{n}
# ----------------------------------------
#   [68/100] EXACT
#     GT:   \int_{a}^{b}f(x)dx
#     PRED: \int_{a}^{b}f(x)dx
# ----------------------------------------
#   [69/100] EXACT
#     GT:   \mathbb{o}
#     PRED: \mathbb{o}
# ----------------------------------------
#   [70/100] EXACT
#     GT:   r^{(3)}=h^{ij}r_{ij}^{(3)}
#     PRED: r^{(3)}=h^{ij}r_{ij}^{(3)}
# ----------------------------------------
#   [71/100] edit_dist=0.0222
#     GT:   e_{c}=\frac{v_{m}}{e_{m}}+\frac{v_{f}}{e_{f}}
#     PRED: e_{c}=\frac{v_{m}}{e_{m}}+\frac{v_{f}}{f_{f}}
# ----------------------------------------
#   [72/100] edit_dist=0.0141
#     GT:   (\begin{matrix}m-1\\ k-1\end{matrix})/(\begin{matrix}n\\ k\end{matrix})
#     PRED: (\begin{matrix}m-1\\ k-1\end{matrix})/(\begin{matrix}n\\ k\end{matrix}|
# ----------------------------------------
#   [73/100] edit_dist=0.3030
#     GT:   ra_{x}^{*}=\frac{g\beta q_{o}^{\prime\prime}}{\nu\alpha k}x^{4}
#     PRED: ra_{x}^{*}=\frac{gb_{0}^{\prime\prime}}{v_{\alpha}^{\prime}k}x^{4}
# ----------------------------------------
#   [74/100] EXACT
#     GT:   \hat{f}(t)
#     PRED: \hat{f}(t)
# ----------------------------------------
#   [75/100] edit_dist=0.0833
#     GT:   y=\frac{1}{2}laea_{y}(\frac{\lambda}{2},\varphi)
#     PRED: y=\frac{1}{2}lacay(\frac{\lambda}{2},\varphi)
# ----------------------------------------
#   [76/100] edit_dist=0.1250
#     GT:   a\rightarrow_{amb}^{*}b
#     PRED: a\rightarrow a_{mb}^{*}b
# ----------------------------------------
#   [77/100] edit_dist=0.2000
#     GT:   (-b+\sqrt{b^{2}-4c})/2
#     PRED: (-b+\sqrt{b^{2}-k_{2}})/2
# ----------------------------------------
#   [78/100] edit_dist=0.0294
#     GT:   (\frac{x_{i}-\overline{x}}{s_{x}})
#     PRED: (\frac{x_{i}-\overline{y}}{s_{x}})
# ----------------------------------------
#   [79/100] edit_dist=0.2400
#     GT:   (b-a)e^{n(f(x_{0})-\eta)}
#     PRED: (b-a)e^{n(a(x)}-\eta)
# ----------------------------------------
#   [80/100] edit_dist=0.2105
#     GT:   \gamma_{\chi}^{\mu}
#     PRED: \gamma_{x}^{\mu}
# ----------------------------------------
#   [81/100] edit_dist=0.5455
#     GT:   \frac{dy}{dx}=x+y
#     PRED: \frac{\partial y}{\partial x}=x+y
# ----------------------------------------
#   [82/100] EXACT
#     GT:   \sum c(s_{i})\cdot x_{i}\le b
#     PRED: \sum c(s_{i})\cdot x_{i}\le b
# ----------------------------------------
#   [83/100] EXACT
#     GT:   m
#     PRED: m
# ----------------------------------------
#   [84/100] edit_dist=0.3571
#     GT:   l=10\cdot0.5=5
#     PRED: l=10.0.5=5
# ----------------------------------------
#   [85/100] EXACT
#     GT:   \tilde{e}_{i}^{3}
#     PRED: \tilde{e}_{i}^{3}
# ----------------------------------------
#   [86/100] EXACT
#     GT:   (u_{\alpha})_{\alpha\in a_{n}}
#     PRED: (u_{\alpha})_{\alpha\in a_{n}}
# ----------------------------------------
#   [87/100] edit_dist=0.5833
#     GT:   \tilde{o}(log(n)^{10.5})
#     PRED: \sigma(logl_{n})^{10s)}
# ----------------------------------------
#   [88/100] edit_dist=0.0909
#     GT:   d_{(j_{u})}
#     PRED: d_{(j_{v})}
# ----------------------------------------
#   [89/100] EXACT
#     GT:   \tilde{d}_{4}
#     PRED: \tilde{d}_{4}
# ----------------------------------------
#   [90/100] edit_dist=0.1053
#     GT:   e^{-\beta\hat{h}}
#     PRED: e^{-(\beta\hat{h}})
# ----------------------------------------
#   [91/100] EXACT
#     GT:   s=\int ldt
#     PRED: s=\int ldt
# ----------------------------------------
#   [92/100] EXACT
#     GT:   \sum(\overline{x}-x_{i})=0
#     PRED: \sum(\overline{x}-x_{i})=0
# ----------------------------------------
#   [93/100] EXACT
#     GT:   \frac{dy}{y}=-f(t)dt
#     PRED: \frac{dy}{y}=-f(t)dt
# ----------------------------------------
#   [94/100] EXACT
#     GT:   m=\frac{m}{\sqrt{1-v^{2}/c^{2}}}
#     PRED: m=\frac{m}{\sqrt{1-v^{2}/c^{2}}}
# ----------------------------------------
#   [95/100] EXACT
#     GT:   \frac{f_{r}}{f_{s}}=\frac{v_{r}\cdot x}{v_{s}\cdot x}
#     PRED: \frac{f_{r}}{f_{s}}=\frac{v_{r}\cdot x}{v_{s}\cdot x}
# ----------------------------------------
#   [96/100] edit_dist=0.2308
#     GT:   c_{1}:=\{z:|z|=r_{1}\}
#     PRED: c_{i}:=\{z\cdot|z|=r_{1}\}
# ----------------------------------------
#   [97/100] edit_dist=0.4286
#     GT:   \hat{\sigma}_{/j,/j}
#     PRED: \hat{\sum_{ij},/_{j}}
# ----------------------------------------
#   [98/100] edit_dist=0.5000
#     GT:   (a\times b)^{\sigma}
#     PRED: (a\le b)^{6}
# ----------------------------------------
#   [99/100] EXACT
#     GT:   y=20+3\epsilon_{4}+4\epsilon_{8}
#     PRED: y=20+3\epsilon_{4}+4\epsilon_{8}
# ----------------------------------------
#   [100/100] EXACT
#     GT:   \lambda(y_{i})<c
#     PRED: \lambda(y_{i})<c
# ----------------------------------------
# ============================================================
# LSTM results
# Exact match: 52.00% (52/100)
# Avg normalized edit: 0.1083

# %% [markdown]
# ## Eval 2 — DINOv2 + Transfomer

# %%
from vit_transformer_v2 import ViTLatexModelLoRA
import numpy as np

ARTIFACTS = Path("artifacts")
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# 1. Load Vocab and Tokenizer
VOCAB_SIZE = 66

with open(ARTIFACTS / "lstm_tokenizer.pkl", "rb") as f:
    tokenizer = pickle.load(f)

inv_vocab = {v: k for k, v in tokenizer.word_index.items()}
START_TOKEN = VOCAB_SIZE - 2
END_TOKEN = VOCAB_SIZE - 1

def decode(seq):
    filtered = [t for t in seq if t not in (0, START_TOKEN, END_TOKEN)]
    return "".join(inv_vocab.get(t, "") for t in filtered)

# 2. Initialize and Load Model
model = ViTLatexModelLoRA(vocab_size=VOCAB_SIZE).to(DEVICE)
checkpoint = torch.load(ARTIFACTS / "transformer.pt", map_location=DEVICE, weights_only=False)
model.load_state_dict(checkpoint["model"])
model.eval()

print(f"Model loaded and running on {DEVICE}")

# 3. Evaluation Loop
exact_matches = 0
total_edit_dist = 0.0
N = len(ds_test)

print(f"Evaluating Transformer on {N} samples...")
print("-" * 60)

# Preprocessing constants (ImageNet Norm)
MEAN = torch.tensor([0.485, 0.456, 0.406], device=DEVICE).view(1, 3, 1, 1)
STD  = torch.tensor([0.229, 0.224, 0.225], device=DEVICE).view(1, 3, 1, 1)

for i in range(N):
    img = lstm_images[i:i+1]
    img = img.repeat(1, 3, 1, 1).to(DEVICE)
    
    with torch.no_grad():
        pred_tokens = model.generate(img, max_len=150, sos_idx=START_TOKEN, eos_idx=END_TOKEN)
    
    prediction = decode(pred_tokens)
    ground_truth = decode(tokens_val[i].tolist())
    
    is_exact = prediction == ground_truth
    edit_dist = normalized_edit_distance(prediction, ground_truth)
    
    if is_exact:
        exact_matches += 1
    total_edit_dist += edit_dist
    
    status = "EXACT" if is_exact else f"ED={edit_dist:.4f}"
    print(f"  [{i+1:2d}/{N}] {status}")
    print(f"    GT:   {ground_truth[:80]}")
    print(f"    PRED: {prediction[:80]}")
    print("-" * 40)

print("\n" + "=" * 60)
print("Transformer results")
print(f"Exact match: {exact_matches/N:.2%} ({exact_matches}/{N})")
print(f"Avg normalized edit: {total_edit_dist/N:.4f}")
# Out:
# Model loaded and running on cuda
# Evaluating Transformer on 500 samples...
# ------------------------------------------------------------
#   [ 1/500] EXACT
#     GT:   \frac{\partial\psi}{\partial t}=p\psi
#     PRED: \frac{\partial\psi}{\partial t}=p\psi
# ----------------------------------------
#   [ 2/500] ED=0.3333
#     GT:   c_{0}=d/v_{blood}
#     PRED: c_{0}=d/v_{6106x})
# ----------------------------------------
#   [ 3/500] EXACT
#     GT:   e^{2}/\hbar c\approx1/137
#     PRED: e^{2}/\hbar c\approx1/137
# ----------------------------------------
#   [ 4/500] ED=0.5000
#     GT:   nassoc(s,\overline{s})
#     PRED: nassoc(s,s)
# ----------------------------------------
#   [ 5/500] ED=0.4516
#     GT:   eq.1\frac{dv}{dx}=w
#     PRED: e_{q}\cdot1\frac{dv}{dx}=\omega
# ----------------------------------------
#   [ 6/500] EXACT
#     GT:   \underline{r}
#     PRED: \underline{r}
# ----------------------------------------
#   [ 7/500] EXACT
#     GT:   \hat{k}_{g}
#     PRED: \hat{k}_{g}
# ----------------------------------------
#   [ 8/500] ED=0.0435
#     GT:   \int_{0}^{1}f(r)g(r)rdr
#     PRED: \int_{0}^{1}f(r)g(r)dr
# ----------------------------------------
#   [ 9/500] ED=0.1290
#     GT:   \sigma_{b}=p\cdot\hat{n}_{out}
#     PRED: \sigma_{b}=p\cdot\hat{n}_{can}f
# ----------------------------------------
#   [10/500] ED=0.2000
#     GT:   w_{i}^{*}=\frac{rgq_{bi}}{f_{i}u*^{3}}
#     PRED: w_{i}^{*}=\frac{rgq_{l_{i}}}{f_{i}v_{i}}
# ----------------------------------------
#   [11/500] ED=0.5000
#     GT:   z\rightarrow-z^{5}+z_{0}
#     PRED: z\mapsto-z^{5}+zc
# ----------------------------------------
#   [12/500] ED=0.4706
#     GT:   1/(d_{i}d_{j})^{1/2}
#     PRED: 1/(\partial_{i}\partial_{j})^{1/2}
# ----------------------------------------
#   [13/500] ED=0.0238
#     GT:   t_{r}^{\prime}=t-\frac{1}{c}|r-r^{\prime}|
#     PRED: t_{r}^{\prime}=t-\frac{1}{c}|r-r^{\prime}
# ----------------------------------------
#   [14/500] ED=0.2432
#     GT:   \frac{\partial h}{\partial z_{j}^{-}}
#     PRED: \frac{\partial n}{\partial z\rho}
# ----------------------------------------
#   [15/500] ED=0.1765
#     GT:   {j^{\lambda}}^{y}
#     PRED: {j^{\lambda}y}
# ----------------------------------------
#   [16/500] ED=0.2258
#     GT:   r_{i}\rightarrow r=\prod r_{i}
#     PRED: r_{i}\rightarrow r=\sqrt{1}_{j}
# ----------------------------------------
#   [17/500] ED=0.2903
#     GT:   \int_{0}^{1}\phi(p)dp=1
#     PRED: \int_{0}^{1}\phi(p)\partial p=1
# ----------------------------------------
#   [18/500] ED=0.0455
#     GT:   h(x)=1_{(0,\infty)}(x)
#     PRED: h(x)=l_{(0,\infty)}(x)
# ----------------------------------------
#   [19/500] EXACT
#     GT:   \tilde{x}_{0}
#     PRED: \tilde{x}_{0}
# ----------------------------------------
#   [20/500] EXACT
#     GT:   \sqrt{n}/ln(\sqrt{n})
#     PRED: \sqrt{n}/ln(\sqrt{n})
# ----------------------------------------
#   [21/500] ED=0.4167
#     GT:   a^{\prime}=\lambda_{1}a+\lambda_{2}b
#     PRED: a^{\prime}=\lambda,a+\lambda_{2}\theta_{2}\theta
# ----------------------------------------
#   [22/500] ED=0.3182
#     GT:   \lambda=\mu_{1}^{2}+\cdot\cdot\cdot+\mu_{k}^{2}
#     PRED: \lambda=\mu_{1}^{2}f\cdot\cdot\cdot\cdot\cdot\cdot\cdot\mu_{k}^{2}
# ----------------------------------------
#   [23/500] ED=0.1053
#     GT:   \int_{0}^{t}z_{s}ds
#     PRED: \int_{0}^{2}2_{s}ds
# ----------------------------------------
#   [24/500] ED=0.1538
#     GT:   d_{x}(p+ta)=0
#     PRED: p_{x}(p+a)=0
# ----------------------------------------
#   [25/500] ED=0.2609
#     GT:   \delta t=\dot{q}r
#     PRED: \delta t=\dot{q}\dot{r}
# ----------------------------------------
#   [26/500] ED=0.3333
#     GT:   h_{1}(g;z)=0
#     PRED: h,(g;z)=0
# ----------------------------------------
#   [27/500] ED=0.4231
#     GT:   \prod_{i=0}^{k-1}(x-i)^{n}
#     PRED: \frac{k-1}{4=0}(x-i)^{n}
# ----------------------------------------
#   [28/500] EXACT
#     GT:   v(r)=\frac{1}{2}m_{0}\omega^{2}r^{2}
#     PRED: v(r)=\frac{1}{2}m_{0}\omega^{2}r^{2}
# ----------------------------------------
#   [29/500] ED=0.3571
#     GT:   z_{l}=r_{l}(\omega)+jx_{l}(\omega)
#     PRED: \partial_{2}=r_{2}(\omega)+j\delta(\omega)
# ----------------------------------------
#   [30/500] ED=0.0278
#     GT:   \partial_{t}l=\frac{1}{2}\nabla^{2}l
#     PRED: \partial_{+}l=\frac{1}{2}\nabla^{2}l
# ----------------------------------------
#   [31/500] EXACT
#     GT:   \hat{r}\cdot\hat{e}_{3}
#     PRED: \hat{r}\cdot\hat{e}_{3}
# ----------------------------------------
#   [32/500] ED=0.0500
#     GT:   c_{1},c_{2},...\in k
#     PRED: c_{1},c_{2},..\in k
# ----------------------------------------
#   [33/500] ED=0.4231
#     GT:   \overline{op_{1}}^{\prime}
#     PRED: \overline{q_{1}}
# ----------------------------------------
#   [34/500] ED=0.1000
#     GT:   a=(a_{ij})
#     PRED: a=(a_{ii})
# ----------------------------------------
#   [35/500] EXACT
#     GT:   \varphi\vdash\neg\psi
#     PRED: \varphi\vdash\neg\psi
# ----------------------------------------
#   [36/500] EXACT
#     GT:   \sqrt{n}/ln(\sqrt{n})
#     PRED: \sqrt{n}/ln(\sqrt{n})
# ----------------------------------------
#   [37/500] ED=0.1538
#     GT:   a=\{a_{ij}\}_{i,j=0}^{p-1}
#     PRED: a=\{a_{i,j}\}_{i,j}^{p-c}
# ----------------------------------------
#   [38/500] ED=0.0455
#     GT:   c=\frac{6000}{200-2x}
#     PRED: c=\frac{6000}{2000-2x}
# ----------------------------------------
#   [39/500] EXACT
#     GT:   \frac{\partial w}{\partial t}=f_{e}\cdot v
#     PRED: \frac{\partial w}{\partial t}=f_{e}\cdot v
# ----------------------------------------
#   [40/500] EXACT
#     GT:   a=(\begin{matrix}1&-2\\ 1&-1\end{matrix})
#     PRED: a=(\begin{matrix}1&-2\\ 1&-1\end{matrix})
# ----------------------------------------
#   [41/500] EXACT
#     GT:   (\begin{matrix}4\\ 2\end{matrix})
#     PRED: (\begin{matrix}4\\ 2\end{matrix})
# ----------------------------------------
#   [42/500] EXACT
#     GT:   \frac{x}{2\pi}=\frac{y}{2\pi r}=
#     PRED: \frac{x}{2\pi}=\frac{y}{2\pi r}=
# ----------------------------------------
#   [43/500] ED=0.0476
#     GT:   f(r)=-\frac{k}{r^{3}}
#     PRED: f(r)=-\frac{k}{p^{3}}
# ----------------------------------------
#   [44/500] EXACT
#     GT:   \lambda_{2}=3-\sqrt{5}
#     PRED: \lambda_{2}=3-\sqrt{5}
# ----------------------------------------
#   [45/500] EXACT
#     GT:   \tilde{q}
#     PRED: \tilde{q}
# ----------------------------------------
#   [46/500] ED=0.2667
#     GT:   gh^{\top}=p-p=0
#     PRED: ghh^{t}=p-p=0
# ----------------------------------------
#   [47/500] EXACT
#     GT:   -s
#     PRED: -s
# ----------------------------------------
#   [48/500] EXACT
#     GT:   \sqrt{-7}
#     PRED: \sqrt{-7}
# ----------------------------------------
#   [49/500] ED=0.0435
#     GT:   x=y=\frac{i}{\sqrt{2}}
#     PRED: x=y=\frac{i}{\sqrt{21}}
# ----------------------------------------
#   [50/500] EXACT
#     GT:   \frac{\partial u}{\partial t}=0
#     PRED: \frac{\partial u}{\partial t}=0
# ----------------------------------------
#   [51/500] ED=0.2069
#     GT:   g=\int_{0}^{t}k(t)x(t)dt
#     PRED: g=\int_{0}^{t}k(t)\times(t)dt
# ----------------------------------------
#   [52/500] EXACT
#     GT:   (\begin{matrix}2n-2\\ n-2\end{matrix})
#     PRED: (\begin{matrix}2n-2\\ n-2\end{matrix})
# ----------------------------------------
#   [53/500] EXACT
#     GT:   tr\{\begin{matrix}4\\ 3\end{matrix}\}
#     PRED: tr\{\begin{matrix}4\\ 3\end{matrix}\}
# ----------------------------------------
#   [54/500] EXACT
#     GT:   \sqrt{-1}
#     PRED: \sqrt{-1}
# ----------------------------------------
#   [55/500] ED=0.0263
#     GT:   n=(\begin{matrix}2k-1\\ k\end{matrix})
#     PRED: h=(\begin{matrix}2k-1\\ k\end{matrix})
# ----------------------------------------
#   [56/500] ED=0.1154
#     GT:   e^{2}=p\cdot p+{m_{0}}^{2}
#     PRED: e^{2}=p\cdot p+m_{c}^{2}
# ----------------------------------------
#   [57/500] EXACT
#     GT:   \sqrt{i}
#     PRED: \sqrt{i}
# ----------------------------------------
#   [58/500] ED=0.4615
#     GT:   i_{f}(f)
#     PRED: \xi_{\tau}(f)
# ----------------------------------------
#   [59/500] EXACT
#     GT:   \dot{\varphi}^{2}+\dot{\psi}^{2}=1
#     PRED: \dot{\varphi}^{2}+\dot{\psi}^{2}=1
# ----------------------------------------
#   [60/500] ED=0.0500
#     GT:   \hat{t},\hat{\omega}
#     PRED: \hat{h},\hat{\omega}
# ----------------------------------------
#   [61/500] EXACT
#     GT:   f(x)=|x|^{k+1}
#     PRED: f(x)=|x|^{k+1}
# ----------------------------------------
#   [62/500] EXACT
#     GT:   (\begin{matrix}m\\ n\end{matrix})
#     PRED: (\begin{matrix}m\\ n\end{matrix})
# ----------------------------------------
#   [63/500] EXACT
#     GT:   [a_{j},a_{k}^{*}]=\delta_{j,k}
#     PRED: [a_{j},a_{k}^{*}]=\delta_{j,k}
# ----------------------------------------
#   [64/500] ED=0.2759
#     GT:   f(g^{a}h^{c},g^{b}h^{d},\tau)
#     PRED: f(g^{a}h^{c},g^{b},t)
# ----------------------------------------
#   [65/500] ED=0.1765
#     GT:   \{\tilde{e}_{k}\}
#     PRED: \{\tilde{e}k\}
# ----------------------------------------
#   [66/500] ED=0.0526
#     GT:   (2^{r}+1)|(2^{k}+1)
#     PRED: (2^{r}+1)/(2^{k}+1)
# ----------------------------------------
#   [67/500] ED=0.1860
#     GT:   \rho^{\prime\prime}=\sum_{n}p_{n}\rho p_{n}
#     PRED: p^{\prime\prime}=\sum_{n}p_{n}\rho_{n}p_{n}
# ----------------------------------------
#   [68/500] EXACT
#     GT:   \int_{a}^{b}f(x)dx
#     PRED: \int_{a}^{b}f(x)dx
# ----------------------------------------
#   [69/500] ED=0.1000
#     GT:   \mathbb{o}
#     PRED: \mathbb{c}
# ----------------------------------------
#   [70/500] EXACT
#     GT:   r^{(3)}=h^{ij}r_{ij}^{(3)}
#     PRED: r^{(3)}=h^{ij}r_{ij}^{(3)}
# ----------------------------------------
#   [71/500] EXACT
#     GT:   e_{c}=\frac{v_{m}}{e_{m}}+\frac{v_{f}}{e_{f}}
#     PRED: e_{c}=\frac{v_{m}}{e_{m}}+\frac{v_{f}}{e_{f}}
# ----------------------------------------
#   [72/500] ED=0.4225
#     GT:   (\begin{matrix}m-1\\ k-1\end{matrix})/(\begin{matrix}n\\ k\end{matrix})
#     PRED: (\begin{matrix}m-1\\ k-1\end{matrix})/1^{n}
# ----------------------------------------
#   [73/500] ED=0.4400
#     GT:   ra_{x}^{*}=\frac{g\beta q_{o}^{\prime\prime}}{\nu\alpha k}x^{4}
#     PRED: ra_{x}^{*}=\frac{g\beta_{g_{0}^{0}}{v\alpha_{4}^{\prime\prime}}\ametha^{4}}
# ----------------------------------------
#   [74/500] EXACT
#     GT:   \hat{f}(t)
#     PRED: \hat{f}(t)
# ----------------------------------------
#   [75/500] ED=0.0833
#     GT:   y=\frac{1}{2}laea_{y}(\frac{\lambda}{2},\varphi)
#     PRED: y=\frac{1}{2}laeag(\frac{\lambda}{2},\varphi)
# ----------------------------------------
#   [76/500] ED=0.4815
#     GT:   a\rightarrow_{amb}^{*}b
#     PRED: a\mapsto\int_{amb}^{*}\beta
# ----------------------------------------
#   [77/500] ED=0.0909
#     GT:   (-b+\sqrt{b^{2}-4c})/2
#     PRED: 1-b+\sqrt{b^{2}-kc})/2
# ----------------------------------------
#   [78/500] EXACT
#     GT:   (\frac{x_{i}-\overline{x}}{s_{x}})
#     PRED: (\frac{x_{i}-\overline{x}}{s_{x}})
# ----------------------------------------
#   [79/500] ED=0.1200
#     GT:   (b-a)e^{n(f(x_{0})-\eta)}
#     PRED: (b-a)e^{n(a(x_{1})-\eta}
# ----------------------------------------
#   [80/500] EXACT
#     GT:   \gamma_{\chi}^{\mu}
#     PRED: \gamma_{\chi}^{\mu}
# ----------------------------------------
#   [81/500] ED=0.5455
#     GT:   \frac{dy}{dx}=x+y
#     PRED: \frac{\partial y}{\partial x}=x+y
# ----------------------------------------
#   [82/500] EXACT
#     GT:   \sum c(s_{i})\cdot x_{i}\le b
#     PRED: \sum c(s_{i})\cdot x_{i}\le b
# ----------------------------------------
#   [83/500] EXACT
#     GT:   m
#     PRED: m
# ----------------------------------------
#   [84/500] ED=0.4286
#     GT:   l=10\cdot0.5=5
#     PRED: l=10.05=5
# ----------------------------------------
#   [85/500] EXACT
#     GT:   \tilde{e}_{i}^{3}
#     PRED: \tilde{e}_{i}^{3}
# ----------------------------------------
#   [86/500] ED=0.0333
#     GT:   (u_{\alpha})_{\alpha\in a_{n}}
#     PRED: (u_{\alpha})_{\alpha\in a_{n}
# ----------------------------------------
#   [87/500] ED=0.4231
#     GT:   \tilde{o}(log(n)^{10.5})
#     PRED: \tilde{o}(10,c_{1})^{10s1}
# ----------------------------------------
#   [88/500] ED=0.0909
#     GT:   d_{(j_{u})}
#     PRED: d_{(j_{v})}
# ----------------------------------------
#   [89/500] EXACT
#     GT:   \tilde{d}_{4}
#     PRED: \tilde{d}_{4}
# ----------------------------------------
#   [90/500] ED=0.1053
#     GT:   e^{-\beta\hat{h}}
#     PRED: e^{-\beta d\hat{h}}
# ----------------------------------------
#   [91/500] EXACT
#     GT:   s=\int ldt
#     PRED: s=\int ldt
# ----------------------------------------
#   [92/500] EXACT
#     GT:   \sum(\overline{x}-x_{i})=0
#     PRED: \sum(\overline{x}-x_{i})=0
# ----------------------------------------
#   [93/500] EXACT
#     GT:   \frac{dy}{y}=-f(t)dt
#     PRED: \frac{dy}{y}=-f(t)dt
# ----------------------------------------
#   [94/500] EXACT
#     GT:   m=\frac{m}{\sqrt{1-v^{2}/c^{2}}}
#     PRED: m=\frac{m}{\sqrt{1-v^{2}/c^{2}}}
# ----------------------------------------
#   [95/500] ED=0.3944
#     GT:   \frac{f_{r}}{f_{s}}=\frac{v_{r}\cdot x}{v_{s}\cdot x}
#     PRED: \frac{f_{r}}{f_{s}}=\frac{v_{r}^{\prime}\prime x}{v_{s}^{\prime}\prime}
# ----------------------------------------
#   [96/500] ED=0.1923
#     GT:   c_{1}:=\{z:|z|=r_{1}\}
#     PRED: c_{1}:=\{z\cdot|z|=r_{1}\}
# ----------------------------------------
#   [97/500] ED=0.3500
#     GT:   \hat{\sigma}_{/j,/j}
#     PRED: \hat{z}_{1j,/j}
# ----------------------------------------
#   [98/500] ED=0.2000
#     GT:   (a\times b)^{\sigma}
#     PRED: (a\le b)^{\sigma}
# ----------------------------------------
#   [99/500] EXACT
#     GT:   y=20+3\epsilon_{4}+4\epsilon_{8}
#     PRED: y=20+3\epsilon_{4}+4\epsilon_{8}
# ----------------------------------------
#   [100/500] EXACT
#     GT:   \lambda(y_{i})<c
#     PRED: \lambda(y_{i})<c
# ----------------------------------------
#   [101/500] ED=0.0952
#     GT:   |\frac{y_{1}+y_{2}}{2}-x|^{2}\ge\delta^{2}
#     PRED: |\frac{y_{1}+y_{2}}{2}-x^{2}2\delta^{2}
# ----------------------------------------
#   [102/500] EXACT
#     GT:   |\overline{bl}|=\frac{\pi}{2}r
#     PRED: |\overline{bl}|=\frac{\pi}{2}r
# ----------------------------------------
#   [103/500] ED=0.1837
#     GT:   [\begin{matrix}2&2&4\\ 3&5\\ 6&6\\ 8\end{matrix}]
#     PRED: [\begin{matrix}2&2&4\\ 6\\ 6\end{matrix}]
# ----------------------------------------
#   [104/500] EXACT
#     GT:   r=\sqrt{\frac{a}{\pi}}
#     PRED: r=\sqrt{\frac{a}{\pi}}
# ----------------------------------------
#   [105/500] ED=0.3529
#     GT:   (\eta,\sigma)\in p_{1}\times\sigma
#     PRED: (\eta,8)\in p_{1}\times[
# ----------------------------------------
#   [106/500] EXACT
#     GT:   h_{1}(t^{2};z_{2})
#     PRED: h_{1}(t^{2};z_{2})
# ----------------------------------------
#   [107/500] ED=0.5000
#     GT:   \mathbb{o}
#     PRED: \mathbb{\mathbb{z}
# ----------------------------------------
#   [108/500] ED=0.0667
#     GT:   \tilde{g}_{33}
#     PRED: \tilde{g}_{333}
# ----------------------------------------
#   [109/500] EXACT
#     GT:   \int_{e}|f|<\epsilon
#     PRED: \int_{e}|f|<\epsilon
# ----------------------------------------
#   [110/500] ED=0.5385
#     GT:   [0]=\emptyset
#     PRED: [0]=\phi
# ----------------------------------------
#   [111/500] ED=0.0500
#     GT:   =\frac{1}{(1+z)^{2}}
#     PRED: =\frac{1}{(1+2)^{2}}
# ----------------------------------------
#   [112/500] EXACT
#     GT:   (\begin{matrix}n+1\\ 3\end{matrix})+1
#     PRED: (\begin{matrix}n+1\\ 3\end{matrix})+1
# ----------------------------------------
#   [113/500] EXACT
#     GT:   \{\begin{matrix}3\\ 5/2\end{matrix}\}
#     PRED: \{\begin{matrix}3\\ 5/2\end{matrix}\}
# ----------------------------------------
#   [114/500] EXACT
#     GT:   \frac{\partial^{2}z}{\partial t^{2}}
#     PRED: \frac{\partial^{2}z}{\partial t^{2}}
# ----------------------------------------
#   [115/500] EXACT
#     GT:   \int_{0}^{\infty}e^{ax}cosxdx
#     PRED: \int_{0}^{\infty}e^{ax}cosxdx
# ----------------------------------------
#   [116/500] EXACT
#     GT:   \tilde{s}_{i}
#     PRED: \tilde{s}_{i}
# ----------------------------------------
#   [117/500] ED=0.0750
#     GT:   [\begin{matrix}a&b\\ c&d\\ \end{matrix}]
#     PRED: [\begin{matrix}a&b\\ c&d\end{matrix}]
# ----------------------------------------
#   [118/500] EXACT
#     GT:   (\begin{matrix}n\\ q\end{matrix})
#     PRED: (\begin{matrix}n\\ q\end{matrix})
# ----------------------------------------
#   [119/500] ED=0.0625
#     GT:   y^{l}=y_{1:ymid}
#     PRED: y^{l}=y_{1.ymid}
# ----------------------------------------
#   [120/500] EXACT
#     GT:   \tilde{y}
#     PRED: \tilde{y}
# ----------------------------------------
#   [121/500] ED=0.0769
#     GT:   2^{m},2^{m},1
#     PRED: 2^{m},2^{n},1
# ----------------------------------------
#   [122/500] ED=0.0625
#     GT:   tan\theta=\frac{|v|^{2}}{|g|r}
#     PRED: tan\theta=\frac{|v|^{2}}{|g|r|r}
# ----------------------------------------
#   [123/500] ED=0.5500
#     GT:   \tilde{f}(k)
#     PRED: \overline{f}(\kappa)
# ----------------------------------------
#   [124/500] EXACT
#     GT:   \tilde{e}^{a}
#     PRED: \tilde{e}^{a}
# ----------------------------------------
#   [125/500] ED=0.1667
#     GT:   e[(x-\mu_{x})^{2}]
#     PRED: e[(x-\mu x)^{2}]
# ----------------------------------------
#   [126/500] ED=0.0435
#     GT:   [x_{w}y_{w}z_{w}1]^{t}
#     PRED: [x_{w}y_{w}z_{w}1[]^{t}
# ----------------------------------------
#   [127/500] EXACT
#     GT:   x,x-20
#     PRED: x,x-20
# ----------------------------------------
#   [128/500] EXACT
#     GT:   -\sqrt{x}
#     PRED: -\sqrt{x}
# ----------------------------------------
#   [129/500] EXACT
#     GT:   \tilde{q}
#     PRED: \tilde{q}
# ----------------------------------------
#   [130/500] ED=0.6250
#     GT:   \overline{r_{f}}
#     PRED: \mathbb{r}_{f}
# ----------------------------------------
#   [131/500] ED=0.0286
#     GT:   (\begin{matrix}n+1\\ k\end{matrix})
#     PRED: (\begin{matrix}n-1\\ k\end{matrix})
# ----------------------------------------
#   [132/500] ED=0.2727
#     GT:   \int_{-2}^{6}\frac{dx}{x}
#     PRED: \int_{-2}^{6}\frac{\partial x}{x}
# ----------------------------------------
#   [133/500] ED=0.1429
#     GT:   e_{i}\frac{x^{i}}{i!}
#     PRED: e_{1}\frac{x^{2}}{x!}
# ----------------------------------------
#   [134/500] EXACT
#     GT:   (\begin{matrix}p\\ r\end{matrix})
#     PRED: (\begin{matrix}p\\ r\end{matrix})
# ----------------------------------------
#   [135/500] ED=0.2000
#     GT:   o(kn+1.274^{k})
#     PRED: o(kn)+1-274^{k}
# ----------------------------------------
#   [136/500] ED=0.1224
#     GT:   \frac{d^{2}u}{dy^{2}}=\frac{1}{\mu}\frac{dp}{dx}
#     PRED: \frac{d^{2}u}{dy^{2}}=\frac{1}{r}\frac{d_{p}}{dx}
# ----------------------------------------
#   [137/500] EXACT
#     GT:   (\begin{matrix}1&0\\ 1&-1\end{matrix})
#     PRED: (\begin{matrix}1&0\\ 1&-1\end{matrix})
# ----------------------------------------
#   [138/500] ED=0.4167
#     GT:   o((n+r)log(n))
#     PRED: o((n+r)rlog(n))\rfloooor
# ----------------------------------------
#   [139/500] ED=0.4706
#     GT:   0.5<\frac{a}{l}<2
#     PRED: 0.5\hat{c}<2
# ----------------------------------------
#   [140/500] EXACT
#     GT:   \frac{dy}{dx}-y=x
#     PRED: \frac{dy}{dx}-y=x
# ----------------------------------------
#   [141/500] EXACT
#     GT:   \hat{e}
#     PRED: \hat{e}
# ----------------------------------------
#   [142/500] EXACT
#     GT:   f(d^{\prime},r,w^{\prime})
#     PRED: f(d^{\prime},r,w^{\prime})
# ----------------------------------------
#   [143/500] ED=0.1915
#     GT:   c(k)=(\begin{matrix}2k\\ k\end{matrix})
#     PRED: c(k)=(\begin{matrix}\partial k\\ k\end{matrix})
# ----------------------------------------
#   [144/500] EXACT
#     GT:   i(\theta)=p_{i}(\theta)q_{i}(\theta)
#     PRED: i(\theta)=p_{i}(\theta)q_{i}(\theta)
# ----------------------------------------
#   [145/500] ED=0.0270
#     GT:   (\begin{matrix}7\\ 3\end{matrix})=35
#     PRED: (\begin{matrix}7\\ 3\end{matrix})=355
# ----------------------------------------
#   [146/500] ED=0.0833
#     GT:   h(r)=r^{2}\cdot loglog\frac{1}{r}
#     PRED: h(r)=r^{2}\cdot logloglog\frac{1}{r}
# ----------------------------------------
#   [147/500] EXACT
#     GT:   \tilde{z}_{0}
#     PRED: \tilde{z}_{0}
# ----------------------------------------
#   [148/500] ED=0.7073
#     GT:   x=[\begin{matrix}w+ix\\ y+iz\end{matrix}]
#     PRED: x=\int_{y+iz}^{w}
# ----------------------------------------
#   [149/500] ED=0.0323
#     GT:   \overline{\omega}=exp(-i2\pi/3)
#     PRED: \overline{\omega}=exp(-12\pi/3)
# ----------------------------------------
#   [150/500] ED=0.0189
#     GT:   \frac{\partial\rho}{\partial t}+\nabla\cdot(\rho v)=0
#     PRED: \frac{\partial\rho}{\partial t}+\nabla\cdot(\rho v)=c
# ----------------------------------------
#   [151/500] ED=0.6122
#     GT:   lim_{i\rightarrow\infty}c_{i}t_{a,r_{i}\#}\mu=\nu
#     PRED: lim_{i\mu}\mu\mu_{i}r_{i}\notin\mu=1
# ----------------------------------------
#   [152/500] ED=0.2973
#     GT:   p_{avg}=\frac{1}{2}r_{a}i_{\circ}^{2}
#     PRED: p_{ay}=\frac{1}{2}r_{a}^{2}
# ----------------------------------------
#   [153/500] EXACT
#     GT:   f(n):=n!
#     PRED: f(n):=n!
# ----------------------------------------
#   [154/500] EXACT
#     GT:   [\begin{matrix}a\\ b\\ c\end{matrix}]
#     PRED: [\begin{matrix}a\\ b\\ c\end{matrix}]
# ----------------------------------------
#   [155/500] EXACT
#     GT:   \hat{k}_{g}
#     PRED: \hat{k}_{g}
# ----------------------------------------
#   [156/500] EXACT
#     GT:   \sum_{j=0}^{n}(-1)^{j}(\begin{matrix}n\\ j\end{matrix})p(j)=0
#     PRED: \sum_{j=0}^{n}(-1)^{j}(\begin{matrix}n\\ j\end{matrix})p(j)=0
# ----------------------------------------
#   [157/500] EXACT
#     GT:   x=y=\frac{i}{\sqrt{2}}
#     PRED: x=y=\frac{i}{\sqrt{2}}
# ----------------------------------------
#   [158/500] EXACT
#     GT:   \hat{y}\in\{-1,1\}
#     PRED: \hat{y}\in\{-1,1\}
# ----------------------------------------
#   [159/500] ED=0.1111
#     GT:   gf(q)^{n}
#     PRED: gf(q)^{r}
# ----------------------------------------
#   [160/500] ED=0.0244
#     GT:   (\begin{matrix}a&b/2\\ b/2&c\end{matrix})
#     PRED: (\begin{matrix}a&b/2\\ 5/2&c\end{matrix})
# ----------------------------------------
#   [161/500] EXACT
#     GT:   s\{\begin{matrix}5\\ 4\end{matrix}\}
#     PRED: s\{\begin{matrix}5\\ 4\end{matrix}\}
# ----------------------------------------
#   [162/500] EXACT
#     GT:   \underline{x}(t)
#     PRED: \underline{x}(t)
# ----------------------------------------
#   [163/500] ED=0.6667
#     GT:   [0,
#     PRED: [0_{1}
# ----------------------------------------
#   [164/500] EXACT
#     GT:   (\begin{matrix}6\\ 2\end{matrix})(\begin{matrix}43\\ 4\end{matrix})
#     PRED: (\begin{matrix}6\\ 2\end{matrix})(\begin{matrix}43\\ 4\end{matrix})
# ----------------------------------------
#   [165/500] ED=0.6000
#     GT:   j=1,2,\cdot\cdot\cdot,k-1
#     PRED: j=1,2,..,k-1
# ----------------------------------------
#   [166/500] ED=0.2462
#     GT:   \overline{op_{1}}^{\prime}=\overline{op_{1}^{\prime}}
#     PRED: \overline{\partial p_{1}^{\prime}=\overline{\prime}_{1}^{\prime}}
# ----------------------------------------
#   [167/500] EXACT
#     GT:   s\notin t
#     PRED: s\notin t
# ----------------------------------------
#   [168/500] EXACT
#     GT:   0\le f(\vec{r})\le1
#     PRED: 0\le f(\vec{r})\le1
# ----------------------------------------
#   [169/500] EXACT
#     GT:   e=\sum_{n=-\infty}^{\infty}e[n]^{2}
#     PRED: e=\sum_{n=-\infty}^{\infty}e[n]^{2}
# ----------------------------------------
#   [170/500] ED=0.0400
#     GT:   \int_{a}^{b}[f(x)-g(x)]dx
#     PRED: \int_{u}^{b}[f(x)-g(x)]dx
# ----------------------------------------
#   [171/500] EXACT
#     GT:   \{\hat{f}_{n}\}_{n=1}^{\infty}
#     PRED: \{\hat{f}_{n}\}_{n=1}^{\infty}
# ----------------------------------------
#   [172/500] ED=0.2326
#     GT:   x\mapsto\{\langle e_{k},x\rangle\}_{k\in n}
#     PRED: x\mapsto\{\lambda_{k_{1}}\rangle\}_{k\in n}
# ----------------------------------------
#   [173/500] ED=0.1250
#     GT:   \int\psi\psi^{*}dv=n_{s}
#     PRED: \int\psi\psi^{*}dv=ns
# ----------------------------------------
#   [174/500] EXACT
#     GT:   \prod_{i=1}^{4}i=24
#     PRED: \prod_{i=1}^{4}i=24
# ----------------------------------------
#   [175/500] ED=0.2143
#     GT:   (x,y,z,az^{4})
#     PRED: (x,1,2,a^{4})
# ----------------------------------------
#   [176/500] EXACT
#     GT:   s\{\begin{matrix}4\\ 3\end{matrix}\}
#     PRED: s\{\begin{matrix}4\\ 3\end{matrix}\}
# ----------------------------------------
#   [177/500] ED=0.1875
#     GT:   r_{1}r_{3}=\frac{r_{a}r_{b}^{2}r_{c}}{r_{t}^{2}}
#     PRED: r_{3}r_{a}=\frac{r_{b}r_{c}^{2}}{r_{t}^{2}}
# ----------------------------------------
#   [178/500] ED=0.1071
#     GT:   \tilde{p}(x_{1},...,x_{n-1})
#     PRED: \tilde{p}(x_{n},..,x_{n,1})
# ----------------------------------------
#   [179/500] ED=0.1951
#     GT:   d:\phi\mapsto\frac{1}{i}\phi^{\prime}
#     PRED: d:\phi\rightarrow\frac{1}{i}\phi^{\prime}
# ----------------------------------------
#   [180/500] EXACT
#     GT:   \prod_{k=1}^{n}f(k)
#     PRED: \prod_{k=1}^{n}f(k)
# ----------------------------------------
#   [181/500] EXACT
#     GT:   \sqrt{x}/lnx
#     PRED: \sqrt{x}/lnx
# ----------------------------------------
#   [182/500] EXACT
#     GT:   y
#     PRED: y
# ----------------------------------------
#   [183/500] EXACT
#     GT:   s_{k}=(\begin{matrix}m\\ k\end{matrix})\frac{(m-k)!}{m!}=\frac{1}{k!}
#     PRED: s_{k}=(\begin{matrix}m\\ k\end{matrix})\frac{(m-k)!}{m!}=\frac{1}{k!}
# ----------------------------------------
#   [184/500] ED=0.1000
#     GT:   angle(x_{1}):=\theta
#     PRED: anyl(x_{1}):=\theta
# ----------------------------------------
#   [185/500] EXACT
#     GT:   x_{0}\in m(t_{0})
#     PRED: x_{0}\in m(t_{0})
# ----------------------------------------
#   [186/500] ED=0.1562
#     GT:   e_{n}=\hbar\omega(n+\frac{1}{2})
#     PRED: e_{n}=tn\omega(n+\frac{1}{2})
# ----------------------------------------
#   [187/500] ED=0.5455
#     GT:   (pf)^{\wedge}=q\hat{f}
#     PRED: (pf)^{n}=qf
# ----------------------------------------
#   [188/500] EXACT
#     GT:   \sqrt{x}
#     PRED: \sqrt{x}
# ----------------------------------------
#   [189/500] EXACT
#     GT:   \tilde{b}_{3}
#     PRED: \tilde{b}_{3}
# ----------------------------------------
#   [190/500] EXACT
#     GT:   x\notin n
#     PRED: x\notin n
# ----------------------------------------
#   [191/500] EXACT
#     GT:   \overline{k_{q}}
#     PRED: \overline{k_{q}}
# ----------------------------------------
#   [192/500] EXACT
#     GT:   [\begin{matrix}0&1\\ 1&0\end{matrix}]
#     PRED: [\begin{matrix}0&1\\ 1&0\end{matrix}]
# ----------------------------------------
#   [193/500] EXACT
#     GT:   (d,(\begin{matrix}d+1\\ 2\end{matrix}))
#     PRED: (d,(\begin{matrix}d+1\\ 2\end{matrix}))
# ----------------------------------------
#   [194/500] EXACT
#     GT:   x_{0}=\frac{s^{2}-1}{s^{2}+1}
#     PRED: x_{0}=\frac{s^{2}-1}{s^{2}+1}
# ----------------------------------------
#   [195/500] EXACT
#     GT:   x=\pm\sqrt[m]{a^{n}}
#     PRED: x=\pm\sqrt[m]{a^{n}}
# ----------------------------------------
#   [196/500] ED=0.0417
#     GT:   y=\frac{1}{2}laea_{y}(\frac{\lambda}{2},\varphi)
#     PRED: y=\frac{1}{2}/aeg_{y}(\frac{\lambda}{2},\varphi)
# ----------------------------------------
#   [197/500] ED=0.7358
#     GT:   m=(\begin{matrix}-i&i\\ exp(it)&exp(-it)\end{matrix})
#     PRED: m=(_{exp(il}^{j}exp(-i))
# ----------------------------------------
#   [198/500] EXACT
#     GT:   (\begin{matrix}0&1\\ -1&0\end{matrix})
#     PRED: (\begin{matrix}0&1\\ -1&0\end{matrix})
# ----------------------------------------
#   [199/500] EXACT
#     GT:   \frac{d\mu}{dn}
#     PRED: \frac{d\mu}{dn}
# ----------------------------------------
#   [200/500] EXACT
#     GT:   i_{2}=\int f(\theta)d^{3}x
#     PRED: i_{2}=\int f(\theta)d^{3}x
# ----------------------------------------
#   [201/500] EXACT
#     GT:   s\notin
#     PRED: s\notin
# ----------------------------------------
#   [202/500] EXACT
#     GT:   \hat{f}(x)
#     PRED: \hat{f}(x)
# ----------------------------------------
#   [203/500] EXACT
#     GT:   h(x)|x^{n}-1
#     PRED: h(x)|x^{n}-1
# ----------------------------------------
#   [204/500] ED=0.2000
#     GT:   l=n_{l}-n_{\overline{l}}
#     PRED: l=n_{\lambda}-n_{\overline{l}}
# ----------------------------------------
#   [205/500] ED=0.1053
#     GT:   z(n;t)=o(n^{2-1/t})
#     PRED: z(n;t)=o(n^{2-1})
# ----------------------------------------
#   [206/500] EXACT
#     GT:   \frac{p}{q}\cdot\pi^{2m}
#     PRED: \frac{p}{q}\cdot\pi^{2m}
# ----------------------------------------
#   [207/500] EXACT
#     GT:   \int x^{k}d\mu(x)=m_{k}
#     PRED: \int x^{k}d\mu(x)=m_{k}
# ----------------------------------------
#   [208/500] EXACT
#     GT:   \int_{0}^{t}\lambda(t)dt=1
#     PRED: \int_{0}^{t}\lambda(t)dt=1
# ----------------------------------------
#   [209/500] ED=0.2593
#     GT:   \delta(\omega\cdot x_{1,2})
#     PRED: \delta(\omega,\chi_{11,2})
# ----------------------------------------
#   [210/500] EXACT
#     GT:   \frac{dy}{dx}=0
#     PRED: \frac{dy}{dx}=0
# ----------------------------------------
#   [211/500] ED=0.1176
#     GT:   t_{n}n!=n^{n-2}n!
#     PRED: t_{n}n!=n^{n-2}
# ----------------------------------------
#   [212/500] EXACT
#     GT:   \{x_{i},x_{j}\}\notin e
#     PRED: \{x_{i},x_{j}\}\notin e
# ----------------------------------------
#   [213/500] ED=0.0312
#     GT:   lim\frac{x}{y}=\frac{limx}{limy}
#     PRED: lim\frac{x}{y}=\frac{limx}{liny}
# ----------------------------------------
#   [214/500] ED=0.2917
#     GT:   c(c^{m},c^{n\times n})=0
#     PRED: c(c^{m},c^{nxn})=0
# ----------------------------------------
#   [215/500] EXACT
#     GT:   p_{n}\#=\prod_{k=1}^{n}p_{k}
#     PRED: p_{n}\#=\prod_{k=1}^{n}p_{k}
# ----------------------------------------
#   [216/500] ED=0.0820
#     GT:   \lambda_{1}=(\begin{matrix}0&1&0\\ 1&0&0\\ 0&0&0\end{matrix})
#     PRED: \lambda_{1}=(\begin{matrix}010\\ 1&0\\ 10&0&0\end{matrix})
# ----------------------------------------
#   [217/500] ED=0.2381
#     GT:   h(g,u_{l})=[l:k]
#     PRED: h(g,u_{l})=[l:\kappa]
# ----------------------------------------
#   [218/500] ED=0.1667
#     GT:   \int\int_{x}\int_{y}^{z}
#     PRED: \int_{x}\int_{y}^{z}
# ----------------------------------------
#   [219/500] EXACT
#     GT:   (\begin{matrix}c_{i}\\ i\end{matrix})
#     PRED: (\begin{matrix}c_{i}\\ i\end{matrix})
# ----------------------------------------
#   [220/500] ED=0.4426
#     GT:   \sum_{i=n}^{m}\frac{(\begin{matrix}i\\ n\end{matrix})}{2^{i}}
#     PRED: \sum_{i=n}^{m}\frac{(n^{i})}{2^{i}}
# ----------------------------------------
#   [221/500] EXACT
#     GT:   (f^{+})_{+}
#     PRED: (f^{+})_{+}
# ----------------------------------------
#   [222/500] EXACT
#     GT:   [\begin{matrix}0\\ 1\end{matrix}]
#     PRED: [\begin{matrix}0\\ 1\end{matrix}]
# ----------------------------------------
#   [223/500] EXACT
#     GT:   \hat{\nu}_{i}
#     PRED: \hat{\nu}_{i}
# ----------------------------------------
#   [224/500] EXACT
#     GT:   10^{-12}w/\sqrt{hz}
#     PRED: 10^{-12}w/\sqrt{hz}
# ----------------------------------------
#   [225/500] ED=0.0625
#     GT:   x_{n}=m^{n}x_{0}
#     PRED: x_{n}=m^{n}x_{c}
# ----------------------------------------
#   [226/500] EXACT
#     GT:   h(e^{i\omega})
#     PRED: h(e^{i\omega})
# ----------------------------------------
#   [227/500] ED=0.1250
#     GT:   v_{y}\sqrt{v_{x}^{2}+v_{y}^{2}}
#     PRED: v_{j}\sqrt{r_{2c}^{2}+v_{y}^{2}}
# ----------------------------------------
#   [228/500] ED=0.2162
#     GT:   o(|\omega|k^{2}log(1/\epsilon))
#     PRED: \theta(|\omega|e^{2}log(1/\epsilon)))
# ----------------------------------------
#   [229/500] EXACT
#     GT:   \{0,1,-1\}
#     PRED: \{0,1,-1\}
# ----------------------------------------
#   [230/500] EXACT
#     GT:   e_{p}=k_{b}t
#     PRED: e_{p}=k_{b}t
# ----------------------------------------
#   [231/500] EXACT
#     GT:   c(1-\frac{r_{s}}{r})
#     PRED: c(1-\frac{r_{s}}{r})
# ----------------------------------------
#   [232/500] ED=0.2308
#     GT:   \delta_{0}logf=-kf^{2}
#     PRED: \delta_{c}logf=-kf^{\circ}
# ----------------------------------------
#   [233/500] EXACT
#     GT:   \hat{l}
#     PRED: \hat{l}
# ----------------------------------------
#   [234/500] ED=0.1250
#     GT:   p^{-1}fp
#     PRED: p^{-1}p
# ----------------------------------------
#   [235/500] EXACT
#     GT:   m=[\begin{matrix}m_{1}&0\\ 0&m_{2}\end{matrix}]
#     PRED: m=[\begin{matrix}m_{1}&0\\ 0&m_{2}\end{matrix}]
# ----------------------------------------
#   [236/500] ED=0.0750
#     GT:   [\begin{matrix}x&0\\ 0&y\\ \end{matrix}]
#     PRED: [\begin{matrix}x&0\\ 0&y\end{matrix}]
# ----------------------------------------
#   [237/500] ED=0.0303
#     GT:   e\cap\overline{e}=\delta\otimes c
#     PRED: e\cap\overline{e}=\delta\otimes o
# ----------------------------------------
#   [238/500] EXACT
#     GT:   f[x,y]/(xy)
#     PRED: f[x,y]/(xy)
# ----------------------------------------
#   [239/500] ED=0.0714
#     GT:   \tilde{m}=m//g
#     PRED: \tilde{m}=m/g
# ----------------------------------------
#   [240/500] ED=0.0556
#     GT:   \int_{a}^{b}f(x)dx
#     PRED: \int_{n}^{b}f(x)dx
# ----------------------------------------
#   [241/500] EXACT
#     GT:   s=\int ldx_{3}
#     PRED: s=\int ldx_{3}
# ----------------------------------------
#   [242/500] ED=0.0526
#     GT:   ff\in l^{1}(r^{n})
#     PRED: fff\in l^{1}(r^{n})
# ----------------------------------------
#   [243/500] EXACT
#     GT:   (\begin{matrix}n\\ c\end{matrix})
#     PRED: (\begin{matrix}n\\ c\end{matrix})
# ----------------------------------------
#   [244/500] EXACT
#     GT:   g_{kl}=2\chi\delta n\overline{n}
#     PRED: g_{kl}=2\chi\delta n\overline{n}
# ----------------------------------------
#   [245/500] ED=0.0500
#     GT:   y=a\frac{d-c}{a-b}+c
#     PRED: y=a\frac{2-c}{a-b}+c
# ----------------------------------------
#   [246/500] EXACT
#     GT:   [\frac{\alpha}{\pi}]=[\frac{\alpha}{\theta}]
#     PRED: [\frac{\alpha}{\pi}]=[\frac{\alpha}{\theta}]
# ----------------------------------------
#   [247/500] ED=0.3043
#     GT:   dir(\alpha/k\cdot1_{k})
#     PRED: d:r(\alpha/k-2_{k})
# ----------------------------------------
#   [248/500] EXACT
#     GT:   \int ldt
#     PRED: \int ldt
# ----------------------------------------
#   [249/500] ED=0.4286
#     GT:   d_{e}(x_{e}+1)
#     PRED: de(xe+1)
# ----------------------------------------
#   [250/500] EXACT
#     GT:   \{\begin{matrix}3\\ 3\end{matrix}\}
#     PRED: \{\begin{matrix}3\\ 3\end{matrix}\}
# ----------------------------------------
#   [251/500] ED=0.0556
#     GT:   \delta e^{tot}=q+w
#     PRED: \delta e^{tot}=q+4
# ----------------------------------------
#   [252/500] EXACT
#     GT:   d_{e}(x_{e}+1)
#     PRED: d_{e}(x_{e}+1)
# ----------------------------------------
#   [253/500] EXACT
#     GT:   |z|=\sqrt{a^{2}+b^{2}}
#     PRED: |z|=\sqrt{a^{2}+b^{2}}
# ----------------------------------------
#   [254/500] ED=0.3333
#     GT:   4\sigma/\sqrt{n}=w
#     PRED: 4r/\sqrt{n}=w
# ----------------------------------------
#   [255/500] ED=0.0465
#     GT:   [\begin{matrix}b/d&p\\ c/d&q\end{matrix}]
#     PRED: [\begin{matrix}b/d&p\\ c/d&d&q\end{matrix}]
# ----------------------------------------
#   [256/500] EXACT
#     GT:   dm=(\frac{dy}{l})m
#     PRED: dm=(\frac{dy}{l})m
# ----------------------------------------
#   [257/500] ED=0.3333
#     GT:   a_{\epsilon}^{n}(x,y)
#     PRED: a_{e}^{n}(x,y)
# ----------------------------------------
#   [258/500] ED=0.3500
#     GT:   \mu y=\int\mu q(x)dx
#     PRED: \mu_{y}=\int mq(x)dr
# ----------------------------------------
#   [259/500] ED=0.5500
#     GT:   d_{p}^{1}
#     PRED: \overline{d_{p}}^{1}
# ----------------------------------------
#   [260/500] EXACT
#     GT:   p(x<a)=0.98
#     PRED: p(x<a)=0.98
# ----------------------------------------
#   [261/500] EXACT
#     GT:   \hat{p}
#     PRED: \hat{p}
# ----------------------------------------
#   [262/500] ED=0.2308
#     GT:   |\epsilon_{n+1}|\le m{\epsilon_{n}}^{2}
#     PRED: 1\sum_{n+1}|\le m\epsilon_{n}^{2}
# ----------------------------------------
#   [263/500] ED=0.2500
#     GT:   p=\frac{e}{t}=\frac{1}{2}a\rho v^{3}
#     PRED: p=\frac{\tau}{t}=\frac{1}{2}apv^{3}
# ----------------------------------------
#   [264/500] ED=0.1026
#     GT:   a=\frac{m}{\rho}\frac{n^{2}-1}{n^{2}+2}
#     PRED: a=\frac{m}{p}\frac{n^{2}-1}{n^{2}+2}
# ----------------------------------------
#   [265/500] EXACT
#     GT:   \int f(x,y)dx
#     PRED: \int f(x,y)dx
# ----------------------------------------
#   [266/500] ED=0.3333
#     GT:   x\mapsto xcos(2\pi x)+1
#     PRED: x\mapsto\apsto cos(2\pi x)t
# ----------------------------------------
#   [267/500] ED=0.3750
#     GT:   e=\gamma_{(u)}m_{0}c^{2}
#     PRED: e=v_{(v)}m_{o}c^{t}
# ----------------------------------------
#   [268/500] EXACT
#     GT:   \frac{dh}{dt}=0
#     PRED: \frac{dh}{dt}=0
# ----------------------------------------
#   [269/500] EXACT
#     GT:   \int_{1}^{3}(27-x^{3})dx
#     PRED: \int_{1}^{3}(27-x^{3})dx
# ----------------------------------------
#   [270/500] EXACT
#     GT:   \int_{s}1ds
#     PRED: \int_{s}1ds
# ----------------------------------------
#   [271/500] EXACT
#     GT:   \omega=\frac{d\theta}{dt}=\frac{v}{r}
#     PRED: \omega=\frac{d\theta}{dt}=\frac{v}{r}
# ----------------------------------------
#   [272/500] EXACT
#     GT:   \tilde{e}=\gamma(-,e)
#     PRED: \tilde{e}=\gamma(-,e)
# ----------------------------------------
#   [273/500] ED=0.3333
#     GT:   f_{\alpha}(x)=-f_{\alpha}(\tilde{x})
#     PRED: f_{d}(x)=-f_{d}(\tilde{x})
# ----------------------------------------
#   [274/500] EXACT
#     GT:   \sqrt{\theta}
#     PRED: \sqrt{\theta}
# ----------------------------------------
#   [275/500] EXACT
#     GT:   \psi
#     PRED: \psi
# ----------------------------------------
#   [276/500] ED=0.5417
#     GT:   n^{1/h}\le|b\cap[1,n]|
#     PRED: n^{y_{n}}\le|bn[1,n\}\}|
# ----------------------------------------
#   [277/500] ED=0.2162
#     GT:   \int_{\mathbb{r}}f(x-y)g(y)dy
#     PRED: \int_{\mathbb{\mathbb{r}}f(x-y)g(y)dy
# ----------------------------------------
#   [278/500] EXACT
#     GT:   1-2-3
#     PRED: 1-2-3
# ----------------------------------------
#   [279/500] ED=0.0227
#     GT:   \sum_{n=0}^{n}(\begin{matrix}n\\ n\end{matrix})^{2}=(\begin{matrix}2n\\ n\end{ma
#     PRED: \sum_{n=0}^{n}(\begin{matrix}n\\ n\end{matrix})^{2}=(\begin{matrix}2n\\\\ n\end{
# ----------------------------------------
#   [280/500] ED=0.0345
#     GT:   \chi_{imp}=\frac{c}{t+\theta}
#     PRED: \chi_{1mp}=\frac{c}{t+\theta}
# ----------------------------------------
#   [281/500] ED=0.1270
#     GT:   \frac{b_{2}-1}{b_{1}b_{2}}=\frac{1}{b_{1}}-\frac{1}{b_{1}b_{2}}
#     PRED: \frac{b_{2}-1}{b_{2}b_{1}}=\frac{1}{b_{1}}-\frac{-1}{b_{2}}
# ----------------------------------------
#   [282/500] ED=0.1250
#     GT:   k=\int|\kappa|ds
#     PRED: k=\int1\kappa/ds
# ----------------------------------------
#   [283/500] ED=0.3438
#     GT:   \int_{d}^{\infty}e^{f(x)}dx
#     PRED: \int_{\alpha}^{\alpha}e^{f(x)}dx
# ----------------------------------------
#   [284/500] EXACT
#     GT:   e(k)=\hat{x}(k)-x(k)
#     PRED: e(k)=\hat{x}(k)-x(k)
# ----------------------------------------
#   [285/500] ED=0.3182
#     GT:   p=\{p_{\theta}|\theta\in\theta\}
#     PRED: p=\{p_{\theta}|\in\theta\theta\theta\theta\}
# ----------------------------------------
#   [286/500] EXACT
#     GT:   i=\int xcos(x)dx
#     PRED: i=\int xcos(x)dx
# ----------------------------------------
#   [287/500] ED=0.1000
#     GT:   dn(m,z)/dm
#     PRED: dn(m,2)/dm
# ----------------------------------------
#   [288/500] ED=0.0408
#     GT:   \frac{4}{12}\times\frac{23}{12}=0.63\dot{8}ft^{2}
#     PRED: \frac{4}{12}\times\frac{23}{12}=0.63\dot{8}^{2}
# ----------------------------------------
#   [289/500] EXACT
#     GT:   \tilde{b}_{5}
#     PRED: \tilde{b}_{5}
# ----------------------------------------
#   [290/500] ED=0.4634
#     GT:   m=[\begin{matrix}a&b-a\\ 0&b\end{matrix}]
#     PRED: m=[\begin{matrix}a&b-a-
# ----------------------------------------
#   [291/500] EXACT
#     GT:   \hat{y}\in\{-1,1\}
#     PRED: \hat{y}\in\{-1,1\}
# ----------------------------------------
#   [292/500] EXACT
#     GT:   \hat{h}=\hat{h}(\hat{p})
#     PRED: \hat{h}=\hat{h}(\hat{p})
# ----------------------------------------
#   [293/500] EXACT
#     GT:   f=p-\frac{\partial v}{\partial r}
#     PRED: f=p-\frac{\partial v}{\partial r}
# ----------------------------------------
#   [294/500] ED=0.2121
#     GT:   \sum_{l}l^{2}4^{-2l}e^{-4\beta l}
#     PRED: \sum_{l}l^{2}4^{-2l}e^{-4}
# ----------------------------------------
#   [295/500] EXACT
#     GT:   30<\epsilon_{r}<50
#     PRED: 30<\epsilon_{r}<50
# ----------------------------------------
#   [296/500] ED=0.0435
#     GT:   fx/so(1,3)\rightarrow x
#     PRED: 7x/so(1,3)\rightarrow x
# ----------------------------------------
#   [297/500] EXACT
#     GT:   \frac{\partial q^{i}}{\partial x_{j}}
#     PRED: \frac{\partial q^{i}}{\partial x_{j}}
# ----------------------------------------
#   [298/500] EXACT
#     GT:   \tilde{t}_{i}
#     PRED: \tilde{t}_{i}
# ----------------------------------------
#   [299/500] ED=0.1579
#     GT:   ra=\{ra|r\in r\}
#     PRED: r_{a}=\{ra|r\in r\}
# ----------------------------------------
#   [300/500] ED=0.0833
#     GT:   \tilde{u}(x)
#     PRED: \tilde{x}(x)
# ----------------------------------------
#   [301/500] ED=0.3125
#     GT:   value=\lambda v.(\lambda h.hv)
#     PRED: ualee=\lambda u\cdot(\lambda hv)
# ----------------------------------------
#   [302/500] ED=0.2000
#     GT:   \sqrt{(}t)
#     PRED: \sqrt{(t)}
# ----------------------------------------
#   [303/500] EXACT
#     GT:   \prod_{i=n-r+1}^{n}i
#     PRED: \prod_{i=n-r+1}^{n}i
# ----------------------------------------
#   [304/500] ED=0.0769
#     GT:   \tilde{g}_{n}
#     PRED: \tilde{g}_{m}
# ----------------------------------------
#   [305/500] EXACT
#     GT:   \frac{df}{dz}=g
#     PRED: \frac{df}{dz}=g
# ----------------------------------------
#   [306/500] ED=0.2000
#     GT:   f=\tilde{f}i
#     PRED: f=\tilde{f}_{i}
# ----------------------------------------
#   [307/500] EXACT
#     GT:   e_{p,m}=\frac{1}{2}li^{2}
#     PRED: e_{p,m}=\frac{1}{2}li^{2}
# ----------------------------------------
#   [308/500] EXACT
#     GT:   (c-r)
#     PRED: (c-r)
# ----------------------------------------
#   [309/500] EXACT
#     GT:   i\notin x
#     PRED: i\notin x
# ----------------------------------------
#   [310/500] EXACT
#     GT:   \sqrt{0}
#     PRED: \sqrt{0}
# ----------------------------------------
#   [311/500] ED=0.1250
#     GT:   t^{*}=\frac{(t-t_{o})}{(t_{s}-t_{o})}
#     PRED: \tau^{*}=\frac{(t-t_{0})}{(t_{s}-t_{0})}
# ----------------------------------------
#   [312/500] EXACT
#     GT:   t(p)=\frac{1-z_{a}}{1+z_{a}}
#     PRED: t(p)=\frac{1-z_{a}}{1+z_{a}}
# ----------------------------------------
#   [313/500] ED=0.3333
#     GT:   \tilde{\chi}
#     PRED: \tilde{x}
# ----------------------------------------
#   [314/500] EXACT
#     GT:   \int cos^{2}xdx
#     PRED: \int cos^{2}xdx
# ----------------------------------------
#   [315/500] EXACT
#     GT:   o()
#     PRED: o()
# ----------------------------------------
#   [316/500] EXACT
#     GT:   \sqrt{t}
#     PRED: \sqrt{t}
# ----------------------------------------
#   [317/500] ED=0.1304
#     GT:   b^{\prime}\in(\begin{matrix}c\\ b\end{matrix})
#     PRED: b^{1}\in(\begin{matrix}c\\ b\end{matrix})
# ----------------------------------------
#   [318/500] EXACT
#     GT:   \omega=\rho+i\tilde{\rho}(\rho)
#     PRED: \omega=\rho+i\tilde{\rho}(\rho)
# ----------------------------------------
#   [319/500] ED=0.0625
#     GT:   m(a)=\int_{a}xdn
#     PRED: m(a)=\int_{a}xdr
# ----------------------------------------
#   [320/500] EXACT
#     GT:   q(\sqrt{13})
#     PRED: q(\sqrt{13})
# ----------------------------------------
#   [321/500] EXACT
#     GT:   c(\vec{n})
#     PRED: c(\vec{n})
# ----------------------------------------
#   [322/500] EXACT
#     GT:   ss\{\begin{matrix}2\\ 4\end{matrix}\}
#     PRED: ss\{\begin{matrix}2\\ 4\end{matrix}\}
# ----------------------------------------
#   [323/500] ED=0.6154
#     GT:   c_{\tilde{y}}
#     PRED: c_{y}
# ----------------------------------------
#   [324/500] EXACT
#     GT:   \{(-1)^{\pi}\}
#     PRED: \{(-1)^{\pi}\}
# ----------------------------------------
#   [325/500] EXACT
#     GT:   \frac{\partial}{\partial\theta}
#     PRED: \frac{\partial}{\partial\theta}
# ----------------------------------------
#   [326/500] EXACT
#     GT:   \{1,2,3\}\notin\{1,2,3\}
#     PRED: \{1,2,3\}\notin\{1,2,3\}
# ----------------------------------------
#   [327/500] EXACT
#     GT:   \mu_{0}\epsilon_{0}=1/c^{2}
#     PRED: \mu_{0}\epsilon_{0}=1/c^{2}
# ----------------------------------------
#   [328/500] EXACT
#     GT:   u=2\sqrt{-\frac{p}{3}}
#     PRED: u=2\sqrt{-\frac{p}{3}}
# ----------------------------------------
#   [329/500] ED=0.1860
#     GT:   \frac{\partial}{\partial z}p_{c}^{p}(z_{0})
#     PRED: \frac{\partial}{\partial t}p_{c}^{p}1
# ----------------------------------------
#   [330/500] ED=0.1667
#     GT:   \frac{1}{2}v^{2}=u(x)
#     PRED: \frac{1}{2}v^{2}=ul_{x})
# ----------------------------------------
#   [331/500] EXACT
#     GT:   \tilde{d}_{6}
#     PRED: \tilde{d}_{6}
# ----------------------------------------
#   [332/500] ED=0.0938
#     GT:   \int_{t-r}^{t}e(t^{\prime})dt
#     PRED: \int_{t-r}^{t}e(t^{\prime})d^{t}
# ----------------------------------------
#   [333/500] ED=0.2593
#     GT:   ai_{t}=100\times\frac{d}{n}
#     PRED: ai_{t}=10x\frac{d}{n}
# ----------------------------------------
#   [334/500] EXACT
#     GT:   \int_{0}^{t}z_{s}ds
#     PRED: \int_{0}^{t}z_{s}ds
# ----------------------------------------
#   [335/500] ED=0.0667
#     GT:   (a^{t}a)^{-1}=q
#     PRED: (a^{+}a)^{-1}=q
# ----------------------------------------
#   [336/500] ED=0.0270
#     GT:   hr\{\begin{matrix}p\\ q\end{matrix}\}
#     PRED: hv\{\begin{matrix}p\\ q\end{matrix}\}
# ----------------------------------------
#   [337/500] EXACT
#     GT:   \int_{c}^{d}f(x)dx
#     PRED: \int_{c}^{d}f(x)dx
# ----------------------------------------
#   [338/500] ED=0.0930
#     GT:   [\gamma^{\mu},\gamma^{\nu}]_{+}=2g^{\mu\nu}
#     PRED: [\gamma^{\mu},\gamma^{\nu}]+2g^{\mu\nu}
# ----------------------------------------
#   [339/500] ED=0.3636
#     GT:   j_{(z_{v})}
#     PRED: j_{(2v})
# ----------------------------------------
#   [340/500] EXACT
#     GT:   \gamma_{nl}|a|^{2}a
#     PRED: \gamma_{nl}|a|^{2}a
# ----------------------------------------
#   [341/500] EXACT
#     GT:   \prod_{n}(z-c_{n})
#     PRED: \prod_{n}(z-c_{n})
# ----------------------------------------
#   [342/500] EXACT
#     GT:   \tilde{\pi}
#     PRED: \tilde{\pi}
# ----------------------------------------
#   [343/500] EXACT
#     GT:   q(\theta^{(t)}|\theta^{(t)})
#     PRED: q(\theta^{(t)}|\theta^{(t)})
# ----------------------------------------
#   [344/500] EXACT
#     GT:   (i+2^{-n}m)^{2^{n}}
#     PRED: (i+2^{-n}m)^{2^{n}}
# ----------------------------------------
#   [345/500] EXACT
#     GT:   \int_{0}^{3}|x^{2}-4|dx
#     PRED: \int_{0}^{3}|x^{2}-4|dx
# ----------------------------------------
#   [346/500] EXACT
#     GT:   \tilde{l}
#     PRED: \tilde{l}
# ----------------------------------------
#   [347/500] ED=0.4211
#     GT:   \underline{\underline{k}}=\underline{\underline{a^{t}ka}}
#     PRED: \underline{k}=\underline{a^{t}ka}
# ----------------------------------------
#   [348/500] ED=0.2308
#     GT:   -\vec{\omega}\times\vec{r}
#     PRED: -\vec{w}\times\vec{r}
# ----------------------------------------
#   [349/500] EXACT
#     GT:   \int_{1}^{3}(27-x^{3})dx
#     PRED: \int_{1}^{3}(27-x^{3})dx
# ----------------------------------------
#   [350/500] EXACT
#     GT:   ff\in l^{1}(r^{n})
#     PRED: ff\in l^{1}(r^{n})
# ----------------------------------------
#   [351/500] ED=0.5000
#     GT:   \mu_{g}(h_{1},h_{2})=(-1)^{k}p^{(\begin{matrix}k\\ 2\end{matrix})}
#     PRED: \mu_{g}(h_{1},h_{2})=(-1)^{k}p^{10}
# ----------------------------------------
#   [352/500] EXACT
#     GT:   f(t)\in p^{(m)}(a_{0})
#     PRED: f(t)\in p^{(m)}(a_{0})
# ----------------------------------------
#   [353/500] EXACT
#     GT:   2cos(\frac{2\pi}{7})
#     PRED: 2cos(\frac{2\pi}{7})
# ----------------------------------------
#   [354/500] ED=0.2188
#     GT:   (y^{\prime},x^{\prime})\sim(y,x)
#     PRED: (y^{1},x^{\prime})\sim (y,x)
# ----------------------------------------
#   [355/500] EXACT
#     GT:   x^{a}lnx=\frac{lnx}{x^{-a}}
#     PRED: x^{a}lnx=\frac{lnx}{x^{-a}}
# ----------------------------------------
#   [356/500] ED=0.6452
#     GT:   \frac{dx}{du}du
#     PRED: \frac{\partial x}{\partial n}dh
# ----------------------------------------
#   [357/500] EXACT
#     GT:   \overline{d}
#     PRED: \overline{d}
# ----------------------------------------
#   [358/500] EXACT
#     GT:   4.\overline{2}
#     PRED: 4.\overline{2}
# ----------------------------------------
#   [359/500] ED=0.7059
#     GT:   \overline{op_{i}}
#     PRED: op_{1}
# ----------------------------------------
#   [360/500] EXACT
#     GT:   \overline{y}^{n}\notin q
#     PRED: \overline{y}^{n}\notin q
# ----------------------------------------
#   [361/500] EXACT
#     GT:   2^{2^{\aleph_{0}}}
#     PRED: 2^{2^{\aleph_{0}}}
# ----------------------------------------
#   [362/500] ED=0.0833
#     GT:   (m+1)m^{n+1}
#     PRED: (m+1)m^{w+1}
# ----------------------------------------
#   [363/500] EXACT
#     GT:   \prod_{i\in i}s_{i}
#     PRED: \prod_{i\in i}s_{i}
# ----------------------------------------
#   [364/500] ED=0.2895
#     GT:   \epsilon_{\circ}=8.85\times10^{-12}f/m
#     PRED: \xi_{0}=8.85\times10^{-12}f/m
# ----------------------------------------
#   [365/500] ED=0.3684
#     GT:   th_{\pi_{2}^{0}}(n)
#     PRED: th_{n_{2}}(n)
# ----------------------------------------
#   [366/500] ED=0.2600
# ...
#     GT:   (v^{\prime}-1)^{m}=v^{k}
#     PRED: (v^{\prime}-1)^{m}=v^{k}
# ----------------------------------------
#   [385/500] ED=0.2727
#     GT:   p(\cdot;\theta+\delta)
#     PRED: p(:\theta+\delta)
# ----------------------------------------
#   [386/500] ED=0.3462
#     GT:   \langle w^{\prime},r^{\prime},\vdash^{\prime}\rangle
#     PRED: \langle w^{1},r^{1},1+^{\prime}\rangle
# ----------------------------------------
#   [387/500] EXACT
#     GT:   \prod_{i=a}^{b}f(i)
#     PRED: \prod_{i=a}^{b}f(i)
# ----------------------------------------
#   [388/500] ED=0.1190
#     GT:   t_{1}s_{2}\overline{t_{1}s_{2}}^{-1}=(123)
#     PRED: trs_{2}\overline{t_{1}s_{2}}^{-1}=(1233)
# ----------------------------------------
#   [389/500] EXACT
#     GT:   (\begin{matrix}4\\ 7\end{matrix})
#     PRED: (\begin{matrix}4\\ 7\end{matrix})
# ----------------------------------------
#   [390/500] EXACT
#     GT:   \int_{0}^{1}-ln(x)f(x)dx
#     PRED: \int_{0}^{1}-ln(x)f(x)dx
# ----------------------------------------
#   [391/500] ED=0.4474
#     GT:   f_{\xi}(x)=\langle\xi|\pi(x)\xi\rangle
#     PRED: f_{3}(x)=\beta/\pi(x)\zeta)\rangle
# ----------------------------------------
#   [392/500] EXACT
#     GT:   \int\frac{dy}{y}
#     PRED: \int\frac{dy}{y}
# ----------------------------------------
#   [393/500] ED=0.4545
#     GT:   o(n^{log_{2}3})
#     PRED: \sigma(n^{10g_{2}^{3})
# ----------------------------------------
#   [394/500] EXACT
#     GT:   (\begin{matrix}1&2\\ 2&4\end{matrix})
#     PRED: (\begin{matrix}1&2\\ 2&4\end{matrix})
# ----------------------------------------
#   [395/500] ED=0.0417
#     GT:   e=\sqrt{h^{2}+(a-b)^{2}}
#     PRED: e=\sqrt{4^{2}+(a-b)^{2}}
# ----------------------------------------
#   [396/500] ED=0.5217
#     GT:   \hat{\zeta}_{0}(\omega)
#     PRED: \hat{s}_{o}(w)
# ----------------------------------------
#   [397/500] ED=0.4167
#     GT:   0,c_{i},-c_{i},c_{i}^{*}
#     PRED: 0,c_{i}=c_{i}\frac{c}{2}
# ----------------------------------------
#   [398/500] EXACT
#     GT:   \varphi
#     PRED: \varphi
# ----------------------------------------
#   [399/500] EXACT
#     GT:   p_{max}=\frac{1}{4}p_{max}q_{max}
#     PRED: p_{max}=\frac{1}{4}p_{max}q_{max}
# ----------------------------------------
#   [400/500] ED=0.1220
#     GT:   [\begin{matrix}x&=&p\\ y&=&p\end{matrix}]
#     PRED: [\begin{matrix}x=\\\ y=p\end{matrix}]
# ----------------------------------------
#   [401/500] EXACT
#     GT:   -a(e-1)
#     PRED: -a(e-1)
# ----------------------------------------
#   [402/500] ED=0.3846
#     GT:   m^{+}\oplus l
#     PRED: m^{+}\theta l
# ----------------------------------------
#   [403/500] EXACT
#     GT:   ||f_{n}(x)||_{b}\le g(x)
#     PRED: ||f_{n}(x)||_{b}\le g(x)
# ----------------------------------------
#   [404/500] EXACT
#     GT:   \frac{2}{\frac{1}{60}+\frac{1}{40}}=48
#     PRED: \frac{2}{\frac{1}{60}+\frac{1}{40}}=48
# ----------------------------------------
#   [405/500] EXACT
#     GT:   i(x;y)\le h(x)
#     PRED: i(x;y)\le h(x)
# ----------------------------------------
#   [406/500] ED=0.5556
#     GT:   \hat{z}
#     PRED: \tilde{z}
# ----------------------------------------
#   [407/500] ED=0.6087
#     GT:   s\approx l_{isco}+s_{1}
#     PRED: s\approx17510+5s
# ----------------------------------------
#   [408/500] ED=0.0667
#     GT:   p_{i}\#=\prod_{j=1}^{i}p_{j}
#     PRED: p_{i\#}\#=\prod_{j=1}^{i}p_{j}
# ----------------------------------------
#   [409/500] EXACT
#     GT:   \int_{\gamma}dz=0
#     PRED: \int_{\gamma}dz=0
# ----------------------------------------
#   [410/500] ED=0.2667
#     GT:   \chi_{0.50}^{2}
#     PRED: x_{0.50}^{2}
# ----------------------------------------
#   [411/500] EXACT
#     GT:   \hat{b}_{i}
#     PRED: \hat{b}_{i}
# ----------------------------------------
#   [412/500] ED=0.3478
#     GT:   \tilde{e}_{i}l\subset l
#     PRED: \tilde{e}_{i}lcl
# ----------------------------------------
#   [413/500] ED=0.1818
#     GT:   y_{i,j}=\sqrt{x_{i,j}}
#     PRED: y_{i,j}=\sqrt{xi_{n}}
# ----------------------------------------
#   [414/500] EXACT
#     GT:   (\begin{matrix}m\\ r\end{matrix})_{q}
#     PRED: (\begin{matrix}m\\ r\end{matrix})_{q}
# ----------------------------------------
#   [415/500] ED=0.9167
#     GT:   e
#     PRED: \overline{e}
# ----------------------------------------
#   [416/500] EXACT
#     GT:   v(t)=i\frac{dl(t)}{dt}
#     PRED: v(t)=i\frac{dl(t)}{dt}
# ----------------------------------------
#   [417/500] ED=0.4138
#     GT:   r=\sum_{a\in\sigma}v(a)r_{a}
#     PRED: r=\prod_{a\in c}\prod(a)r_{a}
# ----------------------------------------
#   [418/500] ED=0.1077
#     GT:   c_{h}\ge\frac{t}{\chi_{t}}(\frac{\partial m}{\partial t})_{h}^{2}
#     PRED: c_{h}\ge\frac{t}{xt}(\frac{\partial m}{\partial t})_{h}^{2}
# ----------------------------------------
#   [419/500] EXACT
#     GT:   n_{\alpha}^{l}
#     PRED: n_{\alpha}^{l}
# ----------------------------------------
#   [420/500] ED=0.1613
#     GT:   \kappa=a_{p}^{-1}(\overline{r})
#     PRED: k=a_{p}^{-1}(\overline{r})
# ----------------------------------------
#   [421/500] EXACT
#     GT:   r_{0,1}=2.405
#     PRED: r_{0,1}=2.405
# ----------------------------------------
#   [422/500] EXACT
#     GT:   \hat{w}(f)
#     PRED: \hat{w}(f)
# ----------------------------------------
#   [423/500] ED=0.0233
#     GT:   \underline{p}(cl_{1}^{\le})=\{x_{1},x_{5}\}
#     PRED: \underline{p}(cl_{1}^{\le})=\{x_{1},x_{t}\}
# ----------------------------------------
#   [424/500] EXACT
#     GT:   \sqrt{a^{2}+b^{2}}=c
#     PRED: \sqrt{a^{2}+b^{2}}=c
# ----------------------------------------
#   [425/500] ED=0.1923
#     GT:   \underline{p}(cl_{1}^{\le})=\{x_{1},x_{5}\}
#     PRED: \underline{p}(cl_{1}\frac{\le}{1})=\{x_{1},x_{5}\}\}
# ----------------------------------------
#   [426/500] ED=0.0833
#     GT:   \infty k\delta(s)\hat{z}
#     PRED: \int k\delta(s)\hat{z}
# ----------------------------------------
#   [427/500] ED=0.1538
#     GT:   1019(4.163\%)
#     PRED: 1019(4.163/0)
# ----------------------------------------
#   [428/500] EXACT
#     GT:   \{\begin{matrix}3\\ 7\end{matrix}\}
#     PRED: \{\begin{matrix}3\\ 7\end{matrix}\}
# ----------------------------------------
#   [429/500] EXACT
#     GT:   b(1-a-d)=0
#     PRED: b(1-a-d)=0
# ----------------------------------------
#   [430/500] ED=0.4130
#     GT:   \frac{\partial n}{\partial t}=-\nabla\cdot j+w
#     PRED: \frac{2n}{2t}=-\nabla\cdot j+jw
# ----------------------------------------
#   [431/500] EXACT
#     GT:   \int_{a}^{b}f(x)dx
#     PRED: \int_{a}^{b}f(x)dx
# ----------------------------------------
#   [432/500] ED=0.1250
#     GT:   m(l)_{n}=m_{n+l}
#     PRED: m(1)_{n}=m_{n+}
# ----------------------------------------
#   [433/500] ED=0.5217
#     GT:   pr(r_{i}<\underline{r})
#     PRED: pr(r_{i}<r)
# ----------------------------------------
#   [434/500] EXACT
#     GT:   c_{x\tilde{y}}
#     PRED: c_{x\tilde{y}}
# ----------------------------------------
#   [435/500] ED=0.9000
#     GT:   l
#     PRED: \mathbb{l}
# ----------------------------------------
#   [436/500] ED=0.0345
#     GT:   l=\frac{1}{k}l=i-\frac{1}{k}a
#     PRED: l=\frac{1}{k}l=1-\frac{1}{k}a
# ----------------------------------------
#   [437/500] ED=0.1600
#     GT:   \sigma_{y=0},\sigma_{y=1}
#     PRED: \sigma_{y=0,\sum_{y=1}
# ----------------------------------------
#   [438/500] ED=0.6667
#     GT:   \hat{1}
#     PRED: \tilde{t}
# ----------------------------------------
#   [439/500] EXACT
#     GT:   \frac{n}{2\pi}sin\frac{2\pi}{n}
#     PRED: \frac{n}{2\pi}sin\frac{2\pi}{n}
# ----------------------------------------
#   [440/500] ED=0.3750
#     GT:   \partial_{t}u=\delta u+\xi
#     PRED: \partial_{t}u=\delta u+\epsilon^{\prime}
# ----------------------------------------
#   [441/500] ED=0.4615
#     GT:   \phi=\bigwedge_{r}\phi_{r}
#     PRED: \phi=\lambda\phi_{c}
# ----------------------------------------
#   [442/500] EXACT
#     GT:   \hat{l}x(x)=\lambda x(x)
#     PRED: \hat{l}x(x)=\lambda x(x)
# ----------------------------------------
#   [443/500] EXACT
#     GT:   \{\begin{matrix}3\\ 5\end{matrix}\}
#     PRED: \{\begin{matrix}3\\ 5\end{matrix}\}
# ----------------------------------------
#   [444/500] EXACT
#     GT:   12^{2}+35^{2}=37^{2}
#     PRED: 12^{2}+35^{2}=37^{2}
# ----------------------------------------
#   [445/500] EXACT
#     GT:   \overline{z}
#     PRED: \overline{z}
# ----------------------------------------
#   [446/500] ED=0.2000
#     GT:   \frac{da}{dt}=[a,h]+\frac{\partial a}{\partial t}
#     PRED: \frac{da}{dt}=[\lambda\cdot h]+\frac{\partial a}{\partial t}
# ----------------------------------------
#   [447/500] ED=0.6429
#     GT:   a]=\{x\le a\}
#     PRED: d[x\le a_{a}\}
# ----------------------------------------
#   [448/500] ED=0.0952
#     GT:   \sigma_{1}\mapsto(-t)
#     PRED: \sigma_{q}\mapsto(t)
# ----------------------------------------
#   [449/500] EXACT
#     GT:   (\begin{matrix}i&-1\\ i&1\end{matrix})
#     PRED: (\begin{matrix}i&-1\\ i&1\end{matrix})
# ----------------------------------------
#   [450/500] ED=0.1628
#     GT:   \hat{q}=2^{-1/2}(\hat{a}^{\dagger}+\hat{a})
#     PRED: \hat{q}=2^{-1/2}(\hat{a}^{t}+\hat{a})
# ----------------------------------------
#   [451/500] EXACT
#     GT:   \frac{dn}{dt}
#     PRED: \frac{dn}{dt}
# ----------------------------------------
#   [452/500] ED=0.1556
#     GT:   2\pi ib|db|=i\frac{d\sigma}{d\omega}d\omega
#     PRED: z\pi ib|db|=i\frac{d\sigma}{d\mathbba}d\omega
# ----------------------------------------
#   [453/500] EXACT
#     GT:   (\begin{matrix}1&d\\ 0&1\end{matrix})
#     PRED: (\begin{matrix}1&d\\ 0&1\end{matrix})
# ----------------------------------------
#   [454/500] ED=0.0769
#     GT:   \int f(x)dx=1
#     PRED: \int r(x)dx=1
# ----------------------------------------
#   [455/500] ED=0.0400
#     GT:   v_{-}=be^{\frac{-1}{rc}t}
#     PRED: v_{-}=be^{\frac{-1}{rc}}
# ----------------------------------------
#   [456/500] EXACT
#     GT:   \hat{l}^{2}
#     PRED: \hat{l}^{2}
# ----------------------------------------
#   [457/500] EXACT
#     GT:   \tilde{v}
#     PRED: \tilde{v}
# ----------------------------------------
#   [458/500] ED=0.0541
#     GT:   p(r)=\frac{1}{z}e^{-\frac{f(r)}{kt}}
#     PRED: p(r)=\frac{1}{2}e^{-\frac{-f(r)}{kt}}
# ----------------------------------------
#   [459/500] ED=0.1250
#     GT:   f^{2}=k_{1}k_{2}\frac{m_{1}m_{2}}{r^{2}}
#     PRED: f^{2}=k,k_{v}\frac{m_{1}m_{2}}{r^{2}}
# ----------------------------------------
#   [460/500] EXACT
#     GT:   (\begin{matrix}0\\ 1\end{matrix})
#     PRED: (\begin{matrix}0\\ 1\end{matrix})
# ----------------------------------------
#   [461/500] EXACT
#     GT:   \frac{\partial x}{\partial\theta}
#     PRED: \frac{\partial x}{\partial\theta}
# ----------------------------------------
#   [462/500] ED=0.1333
#     GT:   k([\overline{x}])=i^{r-1}([y])
#     PRED: k([\overline{x}])=i^{r-1}(co,]
# ----------------------------------------
#   [463/500] ED=0.1739
#     GT:   [a,\overline{q}]=\frac{1}{2}\overline{q}
#     PRED: \{a,\overline{q}]=\frac{1}{2}\overline{\alpha}
# ----------------------------------------
#   [464/500] EXACT
#     GT:   \tilde{t}_{i}
#     PRED: \tilde{t}_{i}
# ----------------------------------------
#   [465/500] ED=0.3830
#     GT:   m_{j}\sim\rho^{\frac{3}{2}(\gamma-\frac{4}{3})}
#     PRED: m_{j}\approx\frac{3/2(r-\frac{4)}{3})
# ----------------------------------------
#   [466/500] EXACT
#     GT:   \sqrt{(}t)
#     PRED: \sqrt{(}t)
# ----------------------------------------
#   [467/500] EXACT
#     GT:   t=\sqrt{n_{0}/2^{k}}
#     PRED: t=\sqrt{n_{0}/2^{k}}
# ----------------------------------------
#   [468/500] EXACT
#     GT:   (=\hat{\beta}\hat{\alpha})
#     PRED: (=\hat{\beta}\hat{\alpha})
# ----------------------------------------
#   [469/500] EXACT
#     GT:   (\begin{matrix}1&t\\ 0&1\end{matrix})
#     PRED: (\begin{matrix}1&t\\ 0&1\end{matrix})
# ----------------------------------------
#   [470/500] ED=0.0625
#     GT:   \frac{(2b^{2}+2c^{2}-a^{2})}{4}
#     PRED: \frac{(210^{2}+2c^{2}-a^{2})}{4}
# ----------------------------------------
#   [471/500] EXACT
#     GT:   \int\sigma_{x}da=0
#     PRED: \int\sigma_{x}da=0
# ----------------------------------------
#   [472/500] ED=0.6744
#     GT:   h[w_{1},...,w_{n}]|j|
#     PRED: h[\omega_{1},\cdot\cdot\cdot,\omega_{n}][j)
# ----------------------------------------
#   [473/500] EXACT
#     GT:   \frac{du}{ds}=0
#     PRED: \frac{du}{ds}=0
# ----------------------------------------
#   [474/500] ED=0.1111
#     GT:   \overline{x}\sim n(\mu,\sigma^{2}/n)
#     PRED: \overline{x}\sim n(\mu,\beta^{2}/n)
# ----------------------------------------
#   [475/500] ED=0.2250
#     GT:   \hat{t}(x)^{-1}\hat{h}\hat{t}(x)=\hat{h}
#     PRED: \hat{t}(x)^{4}\hat{h}(x)=\hat{h}
# ----------------------------------------
#   [476/500] ED=0.2444
#     GT:   (d^{\nabla})^{2}\sigma=f^{\nabla}\wedge\sigma
#     PRED: (d^{\nabla})^{2}\prod=f^{\nabla}1\sigma
# ----------------------------------------
#   [477/500] ED=0.0250
#     GT:   z=(\begin{matrix}z&0\\ w&-z\end{matrix})
#     PRED: z=(\begin{matrix}z&0\\ m&-z\end{matrix})
# ----------------------------------------
#   [478/500] EXACT
#     GT:   p(a_{1})\le p(a_{1})
#     PRED: p(a_{1})\le p(a_{1})
# ----------------------------------------
#   [479/500] ED=0.5000
#     GT:   \int dx=x+c
#     PRED: \int\partial x=x+c
# ----------------------------------------
#   [480/500] EXACT
#     GT:   (\begin{matrix}0&0\\ 0&1\end{matrix})
#     PRED: (\begin{matrix}0&0\\ 0&1\end{matrix})
# ----------------------------------------
#   [481/500] ED=0.3600
#     GT:   \gamma_{nl}|a|^{2}a
#     PRED: \gamma_{ne}/a\int a/^{2}a
# ----------------------------------------
#   [482/500] ED=0.2917
#     GT:   \int_{v_{1}}^{v_{2}}pdv
#     PRED: \int_{v1}^{v_{2}}p^{2}dv
# ----------------------------------------
#   [483/500] ED=0.2333
#     GT:   c^{n}=\bigoplus_{i=1}^{k}y_{i}
#     PRED: c^{n}=\beta_{i=1}^{k}y_{i}
# ----------------------------------------
#   [484/500] EXACT
#     GT:   \tilde{x}\rightarrow x
#     PRED: \tilde{x}\rightarrow x
# ----------------------------------------
#   [485/500] EXACT
#     GT:   \sqrt{g}
#     PRED: \sqrt{g}
# ----------------------------------------
#   [486/500] ED=0.2545
#     GT:   -\frac{p\dot{r}}{r^{2}}=-\epsilon sin\theta\dot{\theta}
#     PRED: -\frac{p^{\dot{r}}{r^{2}}=-\epsilon sin\theta
# ----------------------------------------
#   [487/500] ED=0.0263
#     GT:   15*(\begin{matrix}66\\ 8\end{matrix})
#     PRED: 15*(\begin{matrix}666\\ 8\end{matrix})
# ----------------------------------------
#   [488/500] ED=0.0882
#     GT:   \frac{k_{i}}{k_{d}}=\omega_{0}^{2}
#     PRED: \frac{k_{i}}{kd}=\omega_{0}^{2}
# ----------------------------------------
#   [489/500] EXACT
#     GT:   =k\int_{r}^{\infty}\rho dr
#     PRED: =k\int_{r}^{\infty}\rho dr
# ----------------------------------------
#   [490/500] EXACT
#     GT:   \frac{\partial}{\partial z}f(\overline{z},z)
#     PRED: \frac{\partial}{\partial z}f(\overline{z},z)
# ----------------------------------------
#   [491/500] ED=0.0370
#     GT:   w_{r}=\alpha s+\beta aw_{p}
#     PRED: w_{r}=\alpha s+\beta aw_{r}
# ----------------------------------------
#   [492/500] ED=0.4091
#     GT:   (pf)^{\wedge}=q\hat{f}
#     PRED: (pf)^{n}=q^{\hat{f}}
# ----------------------------------------
#   [493/500] ED=0.3182
#     GT:   n=\frac{i-r}{||i-r||}
#     PRED: x=\frac{i-r}{1i-r^{1}}
# ----------------------------------------
#   [494/500] ED=0.2353
#     GT:   t_{2}=t_{1}e^{\mu_{s}\beta}
#     PRED: t_{\partial}=t_{1}e^{\mu_{s}\beta}
# ----------------------------------------
#   [495/500] ED=0.2105
#     GT:   \int_{0}^{1}g_{n}=1
#     PRED: \int_{0}^{1}gm=1
# ----------------------------------------
#   [496/500] ED=0.2903
#     GT:   \frac{1}{min_{i}h_{c}(o)-t_{i}}
#     PRED: \frac{1}{minc(0)-t_{i}}
# ----------------------------------------
#   [497/500] ED=0.3137
#     GT:   \dot{y}=\frac{1}{c}\overline{h}(0,y,0)
#     PRED: \dot{y}=\frac{1}{c}\overline{h}(\partial,y_{1}\rho)
# ----------------------------------------
#   [498/500] ED=0.5806
#     GT:   \frac{dx}{dt}=c
#     PRED: \frac{\partial x}{\partial t}=c
# ----------------------------------------
#   [499/500] ED=0.5974
#     GT:   (\begin{matrix}\alpha&\beta\\ \overline{\beta}&\overline{\alpha}\end{matrix})
#     PRED: (\frac{\alpha}{\beta},\frac{\beta}{\alpha})
# ----------------------------------------
#   [500/500] ED=0.0750
#     GT:   p=(\begin{matrix}a+1\\ 1\\ \end{matrix})
#     PRED: p=(\begin{matrix}a+1\\ 1\end{matrix})
# ----------------------------------------
#
# ============================================================
# Transformer results
# Exact match: 49.20% (246/500)
# Avg normalized edit: 0.1244

# %% [markdown]
# ## Eval 3 — GPT-5.2 Vision Baseline (Few-Shot)

# %%
import os, json, re, time, base64
from io import BytesIO
from PIL import Image, ImageOps, ImageFilter
from openai import OpenAI
from dotenv import load_dotenv

load_dotenv("../.env")
api_key = os.getenv("OPENAI_API_KEY")
assert api_key, "Set OPENAI_API_KEY in ../.env before running."
client = OpenAI(api_key=api_key)

MODEL = "gpt-5.2"
NUM_FEW_SHOT = 8
GPT_N = 500

# --- LaTeX normalization (applied to BOTH GT and prediction) ---
def normalize_latex(s):
    """Normalize LaTeX for fairer comparison."""
    s = s.strip().lower()
    s = re.sub(r'^\$+|\$+$', '', s)
    s = re.sub(r'\\begin\{equation\}|\\end\{equation\}', '', s)
    s = re.sub(r'\s+', ' ', s).strip()
    s = re.sub(r'\s*([{}()^_])\s*', r'\1', s)
    s = re.sub(r'(\\[a-zA-Z]+)\s+\{', r'\1{', s)
    s = s.replace('\\left', '').replace('\\right', '')
    s = re.sub(r'\\[,;:!]', '', s)
    return s

def preprocess_for_gpt(pil_image, target_size=512):
    """Clean up handwriting image for better GPT vision recognition."""
    img = pil_image.convert("L")
    arr = np.array(img)
    threshold = 200
    arr = np.where(arr < threshold, 0, 255).astype(np.uint8)
    img = Image.fromarray(arr)
    inv = ImageOps.invert(img)
    bbox = inv.getbbox()
    if bbox:
        padding = 20
        x0 = max(0, bbox[0] - padding)
        y0 = max(0, bbox[1] - padding)
        x1 = min(img.width, bbox[2] + padding)
        y1 = min(img.height, bbox[3] + padding)
        img = img.crop((x0, y0, x1, y1))
    w, h = img.size
    side = max(w, h)
    padded = Image.new("L", (side, side), 255)
    padded.paste(img, ((side - w) // 2, (side - h) // 2))
    padded = padded.resize((target_size, target_size), Image.LANCZOS)
    return padded.convert("RGB")

def encode_image(pil_image):
    buf = BytesIO()
    pil_image.save(buf, format="PNG")
    return base64.b64encode(buf.getvalue()).decode("utf-8")

# --- Pick diverse few-shot examples (spread across train set) ---
train_len = len(ds["train"])
few_shot_indices = [int(i * train_len / NUM_FEW_SHOT) for i in range(NUM_FEW_SHOT)]
few_shot_samples = [ds["train"][i] for i in few_shot_indices]
few_shot_b64 = [
    (encode_image(preprocess_for_gpt(s["image"])), normalize_latex(s["latex"]))
    for s in few_shot_samples
]

print("Few-shot examples:")
for idx, (_, latex) in zip(few_shot_indices, few_shot_b64):
    print(f"  [{idx}] {latex[:80]}")
print()

SYSTEM_PROMPT = (
    "You are an expert at reading handwritten mathematical equations and converting them to LaTeX. "
    "Return ONLY the raw LaTeX string, nothing else — no dollar signs, no code fences, no explanation. "
    "IMPORTANT RULES: "
    "1. Output everything in lowercase. "
    "2. Do NOT use \\left or \\right — just use bare ( ) [ ] delimiters. "
    "3. Do NOT use \\mathbb, \\operatorname, \\mathrm, \\text, or \\lvert/\\rvert. "
    "4. Do NOT add spacing commands like \\, \\; \\: \\! or \\quad. "
    "5. Use simple notation: x_1 not x_{1} when subscript is a single character. "
    "6. Use \\frac{a}{b} for fractions, not a/b or \\dfrac. "
    "7. Pay very careful attention to each character — distinguish similar-looking symbols "
    "(e.g., w vs \\omega, v vs \\nu, p vs \\rho, x vs \\times). "
    "8. If you see a plain letter, output the plain letter (w, not \\omega). "
    "9. Match the EXACT style of the examples provided."
)

def strip_code_fences(text):
    return re.sub(r"^```(?:latex)?\n?|\n?```$", "", text, flags=re.MULTILINE).strip()

def predict_latex(pil_image):
    processed = preprocess_for_gpt(pil_image)
    messages = []
    for b64, latex in few_shot_b64:
        messages.append({
            "role": "user",
            "content": [
                {"type": "input_text", "text": "Convert this handwritten equation to LaTeX:"},
                {"type": "input_image", "image_url": f"data:image/png;base64,{b64}"},
            ],
        })
        messages.append({"role": "assistant", "content": latex})
    b64_test = encode_image(processed)
    messages.append({
        "role": "user",
        "content": [
            {"type": "input_text", "text": "Convert this handwritten equation to LaTeX:"},
            {"type": "input_image", "image_url": f"data:image/png;base64,{b64_test}"},
        ],
    })
    response = client.responses.create(
        model=MODEL,
        instructions=SYSTEM_PROMPT,
        input=messages,
        temperature=0,
    )
    return strip_code_fences(response.output_text.strip())

# --- Use tokenizer round-trip for GT (same as LSTM/Transformer evals) ---
gpt_gt_normalized = []
for i in range(GPT_N):
    gt_roundtrip = lstm_decode(tokens_val[i].tolist())
    gpt_gt_normalized.append(normalize_latex(gt_roundtrip))

gpt_exact = 0
gpt_edit = 0.0

print(f"Evaluating {MODEL} ({NUM_FEW_SHOT}-shot) on {GPT_N} val samples...")
print(f"Using LaTeX normalization + tokenizer GT round-trip")
print("-" * 60)

for i in range(GPT_N):
    ground_truth = gpt_gt_normalized[i]
    try:
        raw_pred = predict_latex(ds_test[i]["image"])
        prediction = normalize_latex(raw_pred)
    except Exception as e:
        print(f"  [{i+1}/{GPT_N}] ERROR: {e}")
        prediction = ""

    is_exact = prediction == ground_truth
    edit_dist = normalized_edit_distance(prediction, ground_truth)
    if is_exact: gpt_exact += 1
    gpt_edit += edit_dist

    status = "EXACT" if is_exact else f"edit_dist={edit_dist:.4f}"
    print(f"  [{i+1:2d}/{GPT_N}] {status}")
    print(f"    GT:   {ground_truth[:80]}")
    print(f"    PRED: {prediction[:80]}")
    print("-" * 40)

    if i < GPT_N - 1:
        time.sleep(0.5)

print("=" * 60)
print(f"{MODEL} results ({NUM_FEW_SHOT}-shot, normalized)")
print(f"Exact match: {gpt_exact/GPT_N:.2%} ({gpt_exact}/{GPT_N})")
print(f"Avg normalized edit: {gpt_edit/GPT_N:.4f}")
# Out:
# Few-shot examples:
#   [0] v(\tilde{\beta})
#   [28733] \int vds
#   [57466] d=\frac{a\pm\sqrt{a^{2}-b^{2}c}}{2}
#   [86199] q=\int_{v}j^{0}dv
#   [114932] \frac{dy_{1}}{dt}=-ay_{1}
#   [143665] \frac{\partial s^{*}(p)}{\partial p}
#   [172398] \frac{v_{e}}{c}=0,00009935
#   [201131] \kappa(a,z):=\overline{f_{a}(z)}
#
# Evaluating gpt-5.2 (8-shot) on 500 val samples...
# Using LaTeX normalization + tokenizer GT round-trip
# ------------------------------------------------------------
#   [ 1/500] EXACT
#     GT:   \frac{\partial\psi}{\partial t}=p\psi
#     PRED: \frac{\partial\psi}{\partial t}=p\psi
# ----------------------------------------
#   [ 2/500] edit_dist=0.4706
#     GT:   c_{0}=d/v_{blood}
#     PRED: c_{0}=d/\sqrt{6}
# ----------------------------------------
#   [ 3/500] edit_dist=0.4390
#     GT:   e^{2}/\hbar c\approx1/137
#     PRED: \frac{e^{2}}{\hbar c}\approx\frac{1}{137}
# ----------------------------------------
#   [ 4/500] edit_dist=0.5455
#     GT:   nassoc(s,\overline{s})
#     PRED: massoc(s,s)
# ----------------------------------------
#   [ 5/500] edit_dist=0.5000
#     GT:   eq.1\frac{dv}{dx}=w
#     PRED: e_{2}\cdot\frac{dv}{dx}=\omega
# ----------------------------------------
#   [ 6/500] edit_dist=0.9231
#     GT:   \underline{r}
#     PRED: \gamma
# ----------------------------------------
#   [ 7/500] edit_dist=0.7273
#     GT:   \hat{k}_{g}
#     PRED: \int<g
# ----------------------------------------
#   [ 8/500] edit_dist=0.0870
#     GT:   \int_{0}^{1}f(r)g(r)rdr
#     PRED: \int_{0}^{3}f(r)g(r)dr
# ----------------------------------------
#   [ 9/500] edit_dist=0.0909
#     GT:   \sigma_{b}=p\cdot\hat{n}_{out}
#     PRED: \sigma_{b}=\phi\cdot\hat{n}_{out}
# ----------------------------------------
#   [10/500] edit_dist=0.1579
#     GT:   w_{i}^{*}=\frac{rgq_{bi}}{f_{i}u*^{3}}
#     PRED: w_{i}^{*}=\frac{rgqci}{f_{i}u^{*3}}
# ----------------------------------------
#   [11/500] edit_dist=0.2222
#     GT:   zarrow-z^{5}+z_{0}
#     PRED: z\to-z^{5}+z_{0}
# ----------------------------------------
#   [12/500] EXACT
#     GT:   1/(d_{i}d_{j})^{1/2}
#     PRED: 1/(d_{i}d_{j})^{1/2}
# ----------------------------------------
#   [13/500] edit_dist=0.4524
#     GT:   t_{r}^{\prime}=t-\frac{1}{c}|r-r^{\prime}|
#     PRED: t_{v}'=t-\frac{1}{c}|r-r'|
# ----------------------------------------
#   [14/500] edit_dist=0.1622
#     GT:   \frac{\partial h}{\partial z_{j}^{-}}
#     PRED: \frac{\partial m}{\partial z_{p}}
# ----------------------------------------
#   [15/500] edit_dist=0.8235
#     GT:   {j^{\lambda}}^{y}
#     PRED: u\cdot xy
# ----------------------------------------
#   [16/500] edit_dist=0.7000
#     GT:   r_{i}arrow r=\prod r_{i}
#     PRED: r_{\lambda}\to r=t|r_{\lambda}
# ----------------------------------------
#   [17/500] EXACT
#     GT:   \int_{0}^{1}\phi(p)dp=1
#     PRED: \int_{0}^{1}\phi(p)dp=1
# ----------------------------------------
#   [18/500] EXACT
#     GT:   h(x)=1_{(0,\infty)}(x)
#     PRED: h(x)=1_{(0,\infty)}(x)
# ----------------------------------------
#   [19/500] edit_dist=0.6154
#     GT:   \tilde{x}_{0}
#     PRED: \sqrt{x}0
# ----------------------------------------
#   [20/500] edit_dist=0.3333
#     GT:   \sqrt{n}/ln(\sqrt{n})
#     PRED: \frac{\sqrt{n}}{\ln(\sqrt{n})}
# ----------------------------------------
#   [21/500] edit_dist=0.7500
#     GT:   a^{\prime}=\lambda_{1}a+\lambda_{2}b
#     PRED: a'=y_1a+y_2b
# ----------------------------------------
#   [22/500] edit_dist=0.2128
#     GT:   \lambda=\mu_{1}^{2}+\cdot\cdot\cdot+\mu_{k}^{2}
#     PRED: \lambda=\mu_{1}^{2}+\cdots+\mu_{k}^{2}
# ----------------------------------------
#   [23/500] edit_dist=0.1053
#     GT:   \int_{0}^{t}z_{s}ds
#     PRED: \int_{0}^{2}z_{5}ds
# ----------------------------------------
#   [24/500] edit_dist=0.1429
#     GT:   d_{x}(p+ta)=0
#     PRED: p_{x}(p+t+a)=0
# ----------------------------------------
#   [25/500] edit_dist=0.3529
#     GT:   \delta t=\dot{q}r
#     PRED: \delta t=qr
# ----------------------------------------
#   [26/500] edit_dist=0.3333
#     GT:   h_{1}(g;z)=0
#     PRED: h(g;z)=0
# ----------------------------------------
#   [27/500] edit_dist=0.4444
#     GT:   \prod_{i=0}^{k-1}(x-i)^{n}
#     PRED: \sum_{i=0}^{k-1}\frac{1}{y}(x-i)^{w}
# ----------------------------------------
#   [28/500] EXACT
#     GT:   v(r)=\frac{1}{2}m_{0}\omega^{2}r^{2}
#     PRED: v(r)=\frac{1}{2}m_{0}\omega^{2}r^{2}
# ----------------------------------------
#   [29/500] edit_dist=0.1176
#     GT:   z_{l}=r_{l}(\omega)+jx_{l}(\omega)
#     PRED: z_{2}=r_{2}(\omega)+jz_{2}(\omega)
# ----------------------------------------
#   [30/500] EXACT
#     GT:   \partial_{t}l=\frac{1}{2}\nabla^{2}l
#     PRED: \partial_{t}l=\frac{1}{2}\nabla^{2}l
# ----------------------------------------
#   [31/500] EXACT
#     GT:   \hat{r}\cdot\hat{e}_{3}
#     PRED: \hat{r}\cdot\hat{e}_{3}
# ----------------------------------------
#   [32/500] edit_dist=0.2609
#     GT:   c_{1},c_{2},...\in k
#     PRED: c_{1},c_{2},\ldots\in k
# ----------------------------------------
#   [33/500] edit_dist=0.5385
#     GT:   \overline{op_{1}}^{\prime}
#     PRED: \overline{\varphi_{1}}
# ----------------------------------------
#   [34/500] EXACT
#     GT:   a=(a_{ij})
#     PRED: a=(a_{ij})
# ----------------------------------------
#   [35/500] EXACT
#     GT:   \varphi\vdash\neg\psi
#     PRED: \varphi\vdash\neg\psi
# ----------------------------------------
#   [36/500] edit_dist=0.0455
#     GT:   \sqrt{n}/ln(\sqrt{n})
#     PRED: \sqrt{n}/\ln(\sqrt{n})
# ----------------------------------------
#   [37/500] EXACT
#     GT:   a=\{a_{ij}\}_{i,j=0}^{p-1}
#     PRED: a=\{a_{ij}\}_{i,j=0}^{p-1}
# ----------------------------------------
#   [38/500] EXACT
#     GT:   c=\frac{6000}{200-2x}
#     PRED: c=\frac{6000}{200-2x}
# ----------------------------------------
#   [39/500] EXACT
#     GT:   \frac{\partial w}{\partial t}=f_{e}\cdot v
#     PRED: \frac{\partial w}{\partial t}=f_{e}\cdot v
# ----------------------------------------
#   [40/500] edit_dist=0.1220
#     GT:   a=(\begin{matrix}1&-2\\ 1&-1\end{matrix})
#     PRED: a=\begin{pmatrix}1&-2\\1&-1\end{pmatrix}
# ----------------------------------------
#   [41/500] edit_dist=0.8788
#     GT:   (\begin{matrix}4\\ 2\end{matrix})
#     PRED: (4,2)
# ----------------------------------------
#   [42/500] edit_dist=0.0312
#     GT:   \frac{x}{2\pi}=\frac{y}{2\pi r}=
#     PRED: \frac{x}{2\pi}=\frac{y}{2\pi r}
# ----------------------------------------
#   [43/500] edit_dist=0.0476
#     GT:   f(r)=-\frac{k}{r^{3}}
#     PRED: f(r)=-\frac{k}{r^{2}}
# ----------------------------------------
#   [44/500] EXACT
#     GT:   \lambda_{2}=3-\sqrt{5}
#     PRED: \lambda_{2}=3-\sqrt{5}
# ----------------------------------------
#   [45/500] EXACT
#     GT:   \tilde{q}
#     PRED: \tilde{q}
# ----------------------------------------
#   [46/500] edit_dist=0.2667
#     GT:   gh^{\top}=p-p=0
#     PRED: gh^{t}-p-p=0
# ----------------------------------------
#   [47/500] edit_dist=0.8333
#     GT:   -s
#     PRED: -\zeta
# ----------------------------------------
#   [48/500] EXACT
#     GT:   \sqrt{-7}
#     PRED: \sqrt{-7}
# ----------------------------------------
#   [49/500] edit_dist=0.0455
#     GT:   x=y=\frac{i}{\sqrt{2}}
#     PRED: x=y-\frac{i}{\sqrt{2}}
# ----------------------------------------
#   [50/500] edit_dist=0.0323
#     GT:   \frac{\partial u}{\partial t}=0
#     PRED: \frac{\partial u}{\partial t}=c
# ----------------------------------------
#   [51/500] EXACT
#     GT:   g=\int_{0}^{t}k(t)x(t)dt
#     PRED: g=\int_{0}^{t}k(t)x(t)dt
# ----------------------------------------
#   [52/500] edit_dist=0.8158
#     GT:   (\begin{matrix}2n-2\\ n-2\end{matrix})
#     PRED: (2h-2h-2)
# ----------------------------------------
#   [53/500] edit_dist=0.8378
#     GT:   tr\{\begin{matrix}4\\ 3\end{matrix}\}
#     PRED: tv\{3\}
# ----------------------------------------
#   [54/500] EXACT
#     GT:   \sqrt{-1}
#     PRED: \sqrt{-1}
# ----------------------------------------
#   [55/500] edit_dist=0.7105
#     GT:   n=(\begin{matrix}2k-1\\ k\end{matrix})
#     PRED: h=(\frac{2k-1}{k})
# ----------------------------------------
#   [56/500] edit_dist=0.1154
#     GT:   e^{2}=p\cdot p+{m_{0}}^{2}
#     PRED: e^{2}=p\cdotp p+m_{0}^{2}
# ----------------------------------------
#   [57/500] EXACT
#     GT:   \sqrt{i}
#     PRED: \sqrt{i}
# ----------------------------------------
#   [58/500] edit_dist=0.6364
#     GT:   i_{f}(f)
#     PRED: i\subset(f)
# ----------------------------------------
#   [59/500] edit_dist=0.4412
#     GT:   \dot{\varphi}^{2}+\dot{\psi}^{2}=1
#     PRED: \phi^{2}+\psi^{2}=1
# ----------------------------------------
#   [60/500] edit_dist=0.3500
#     GT:   \hat{t},\hat{\omega}
#     PRED: \hat{f},\hat{w}
# ----------------------------------------
#   [61/500] edit_dist=0.1429
#     GT:   f(x)=|x|^{k+1}
#     PRED: f(x)=|x|^{4-1}
# ----------------------------------------
#   [62/500] edit_dist=0.7576
#     GT:   (\begin{matrix}m\\ n\end{matrix})
#     PRED: \binom{m}{n}
# ----------------------------------------
#   [63/500] EXACT
#     GT:   [a_{j},a_{k}^{*}]=\delta_{j,k}
#     PRED: [a_{j},a_{k}^{*}]=\delta_{j,k}
# ----------------------------------------
#   [64/500] edit_dist=0.1379
#     GT:   f(g^{a}h^{c},g^{b}h^{d},\tau)
#     PRED: f(g^{a}h^{c},g^{b}h^{d},7)
# ----------------------------------------
#   [65/500] edit_dist=0.1765
#     GT:   \{\tilde{e}_{k}\}
#     PRED: \{\tilde{e}k\}
# ----------------------------------------
#   [66/500] edit_dist=0.0526
#     GT:   (2^{r}+1)|(2^{k}+1)
#     PRED: (2^{r}+1)(2^{k}+1)
# ----------------------------------------
#   [67/500] edit_dist=0.5814
#     GT:   \rho^{\prime\prime}=\sum_{n}p_{n}\rho p_{n}
#     PRED: p''=\sum p_{n}\rho^{p_{n}}
# ----------------------------------------
#   [68/500] EXACT
#     GT:   \int_{a}^{b}f(x)dx
#     PRED: \int_{a}^{b}f(x)dx
# ----------------------------------------
#   [69/500] edit_dist=0.8750
#     GT:   \mathbb{o}
#     PRED: \circlearrowleft
# ----------------------------------------
#   [70/500] EXACT
#     GT:   r^{(3)}=h^{ij}r_{ij}^{(3)}
#     PRED: r^{(3)}=h^{ij}r_{ij}^{(3)}
# ----------------------------------------
#   [71/500] EXACT
#     GT:   e_{c}=\frac{v_{m}}{e_{m}}+\frac{v_{f}}{e_{f}}
#     PRED: e_{c}=\frac{v_{m}}{e_{m}}+\frac{v_{f}}{e_{f}}
# ----------------------------------------
#   [72/500] edit_dist=0.7465
#     GT:   (\begin{matrix}m-1\\ k-1\end{matrix})/(\begin{matrix}n\\ k\end{matrix})
#     PRED: \frac{m-1}{k-1}/\binom{n}{k}
# ----------------------------------------
#   [73/500] edit_dist=0.2344
#     GT:   ra_{x}^{*}=\frac{g\beta q_{o}^{\prime\prime}}{\nu\alpha k}x^{4}
#     PRED: r_{x}^{*}=\frac{g\beta_{t}^{\prime\prime}}{\nu\alpha_{t}}\times4
# ----------------------------------------
#   [74/500] edit_dist=0.3077
#     GT:   \hat{f}(t)
#     PRED: \hat{\int}(t)
# ----------------------------------------
#   [75/500] edit_dist=0.2708
#     GT:   y=\frac{1}{2}laea_{y}(\frac{\lambda}{2},\varphi)
#     PRED: y=\frac{1}{2}(aeay(\frac{x}{z},\varphi))
# ----------------------------------------
#   [76/500] edit_dist=0.7273
#     GT:   aarrow_{amb}^{*}b
#     PRED: a\supseteq a^{*}\cap b
# ----------------------------------------
#   [77/500] edit_dist=0.4545
#     GT:   (-b+\sqrt{b^{2}-4c})/2
#     PRED: 1-1+\sqrt{r-x_{2}}/2
# ----------------------------------------
#   [78/500] EXACT
#     GT:   (\frac{x_{i}-\overline{x}}{s_{x}})
#     PRED: (\frac{x_{i}-\overline{x}}{s_{x}})
# ----------------------------------------
#   [79/500] edit_dist=0.2400
#     GT:   (b-a)e^{n(f(x_{0})-\eta)}
#     PRED: (b-a)e^{g(f(x_{1})-y)}
# ----------------------------------------
#   [80/500] edit_dist=0.6316
#     GT:   \gamma_{\chi}^{\mu}
#     PRED: y_{x}^{m}
# ----------------------------------------
#   [81/500] edit_dist=0.5455
#     GT:   \frac{dy}{dx}=x+y
#     PRED: \frac{\partial y}{\partial x}=x+y
# ----------------------------------------
#   [82/500] edit_dist=0.2069
#     GT:   \sum c(s_{i})\cdot x_{i}\le b
#     PRED: \sum c(s_{i})x_{i}\le b
# ----------------------------------------
#   [83/500] EXACT
#     GT:   m
#     PRED: m
# ----------------------------------------
#   [84/500] EXACT
#     GT:   l=10\cdot0.5=5
#     PRED: l=10\cdot0.5=5
# ----------------------------------------
#   [85/500] edit_dist=0.5882
#     GT:   \tilde{e}_{i}^{3}
#     PRED: \hat{f}^{3}
# ----------------------------------------
#   [86/500] EXACT
#     GT:   (u_{\alpha})_{\alpha\in a_{n}}
#     PRED: (u_{\alpha})_{\alpha\in a_{n}}
# ----------------------------------------
#   [87/500] edit_dist=0.6053
#     GT:   \tilde{o}(log(n)^{10.5})
#     PRED: \overline{\sigma}(\log(\lambda)^{10}s)
# ----------------------------------------
#   [88/500] edit_dist=0.3636
#     GT:   d_{(j_{u})}
#     PRED: d(j_{v})
# ----------------------------------------
#   [89/500] edit_dist=0.0769
#     GT:   \tilde{d}_{4}
#     PRED: \tilde{d}_{t}
# ----------------------------------------
#   [90/500] EXACT
#     GT:   e^{-\beta\hat{h}}
#     PRED: e^{-\beta\hat{h}}
# ----------------------------------------
#   [91/500] EXACT
#     GT:   s=\int ldt
#     PRED: s=\int ldt
# ----------------------------------------
#   [92/500] edit_dist=0.3077
#     GT:   \sum(\overline{x}-x_{i})=0
#     PRED: \sum(\bar{x}-x_{c})=0
# ----------------------------------------
#   [93/500] edit_dist=0.3333
#     GT:   \frac{dy}{y}=-f(t)dt
#     PRED: \frac{dy}{y}=-\lambda dt
# ----------------------------------------
#   [94/500] edit_dist=0.2250
#     GT:   m=\frac{m}{\sqrt{1-v^{2}/c^{2}}}
#     PRED: m=\frac{m}{\sqrt{1-\frac{v^{2}}{c^{2}}}}
# ----------------------------------------
#   [95/500] edit_dist=0.0189
#     GT:   \frac{f_{r}}{f_{s}}=\frac{v_{r}\cdot x}{v_{s}\cdot x}
#     PRED: \frac{f_{r}}{f_{s}}=\frac{v_{r}\cdot x}{v_{s}\cdot y}
# ----------------------------------------
#   [96/500] EXACT
#     GT:   c_{1}:=\{z:|z|=r_{1}\}
#     PRED: c_{1}:=\{z:|z|=r_{1}\}
# ----------------------------------------
#   [97/500] edit_dist=0.7000
#     GT:   \hat{\sigma}_{/j,/j}
#     PRED: \sum i_{j},j_{j}
# ----------------------------------------
#   [98/500] edit_dist=0.6500
#     GT:   (a\times b)^{\sigma}
#     PRED: (a<b)^{0}
# ----------------------------------------
#   [99/500] EXACT
#     GT:   y=20+3\epsilon_{4}+4\epsilon_{8}
#     PRED: y=20+3\epsilon_{4}+4\epsilon_{8}
# ----------------------------------------
#   [100/500] EXACT
#     GT:   \lambda(y_{i})<c
#     PRED: \lambda(y_{i})<c
# ----------------------------------------
#   [101/500] edit_dist=0.2857
#     GT:   |\frac{y_{1}+y_{2}}{2}-x|^{2}\ge\delta^{2}
#     PRED: (\frac{y_1+y_2}{2}-x)^{2}\ge 8^{2}
# ----------------------------------------
#   [102/500] EXACT
#     GT:   |\overline{bl}|=\frac{\pi}{2}r
#     PRED: |\overline{bl}|=\frac{\pi}{2}r
# ----------------------------------------
#   [103/500] edit_dist=0.3585
#     GT:   [\begin{matrix}2&2&4\\ 3&5\\ 6&6\\ 8\end{matrix}]
#     PRED: \begin{bmatrix}2&2&4\\\frac{3}{6}&5&f\\0\end{bmatrix}
# ----------------------------------------
#   [104/500] EXACT
#     GT:   r=\sqrt{\frac{a}{\pi}}
#     PRED: r=\sqrt{\frac{a}{\pi}}
# ----------------------------------------
#   [105/500] edit_dist=0.2941
#     GT:   (\eta,\sigma)\in p_{1}\times\sigma
#     PRED: (n,z)\in p_{1}\times\sigma
# ----------------------------------------
#   [106/500] edit_dist=0.0556
#     GT:   h_{1}(t^{2};z_{2})
#     PRED: h_{1}(t^{2},z_{2})
# ----------------------------------------
#   [107/500] edit_dist=0.8000
#     GT:   \mathbb{o}
#     PRED: \phi
# ----------------------------------------
#   [108/500] EXACT
#     GT:   \tilde{g}_{33}
#     PRED: \tilde{g}_{33}
# ----------------------------------------
#   [109/500] edit_dist=0.4000
#     GT:   \int_{e}|f|<\epsilon
#     PRED: \int_{e}|f|<c
# ----------------------------------------
#   [110/500] EXACT
#     GT:   [0]=\emptyset
#     PRED: [0]=\emptyset
# ----------------------------------------
#   [111/500] EXACT
#     GT:   =\frac{1}{(1+z)^{2}}
#     PRED: =\frac{1}{(1+z)^{2}}
# ----------------------------------------
#   [112/500] edit_dist=0.8108
#     GT:   (\begin{matrix}n+1\\ 3\end{matrix})+1
#     PRED: (n+1_{3})+()
# ----------------------------------------
#   [113/500] edit_dist=0.7838
#     GT:   \{\begin{matrix}3\\ 5/2\end{matrix}\}
#     PRED: \{3,\frac{5}{2}\}
# ----------------------------------------
#   [114/500] EXACT
#     GT:   \frac{\partial^{2}z}{\partial t^{2}}
#     PRED: \frac{\partial^{2}z}{\partial t^{2}}
# ----------------------------------------
#   [115/500] edit_dist=0.0645
#     GT:   \int_{0}^{\infty}e^{ax}cosxdx
#     PRED: \int_{0}^{\infty}e^{ax}\cos xdx
# ----------------------------------------
#   [116/500] edit_dist=0.3077
#     GT:   \tilde{s}_{i}
#     PRED: \tilde{s}.
# ----------------------------------------
#   [117/500] edit_dist=0.2000
#     GT:   [\begin{matrix}a&b\\ c&d\\ \end{matrix}]
#     PRED: \begin{bmatrix}a&b\\c&d\end{bmatrix}
# ----------------------------------------
#   [118/500] edit_dist=0.7576
#     GT:   (\begin{matrix}n\\ q\end{matrix})
#     PRED: \binom{n}{q}
# ----------------------------------------
#   [119/500] edit_dist=0.2105
#     GT:   y^{l}=y_{1:ymid}
#     PRED: y^{l}=y_{1}:y\midid
# ----------------------------------------
#   [120/500] edit_dist=0.8889
#     GT:   \tilde{y}
#     PRED: \gamma
# ----------------------------------------
#   [121/500] edit_dist=0.6667
#     GT:   2^{m},2^{m},1
#     PRED: \partial^{n},\partial^{n},1
# ----------------------------------------
#   [122/500] edit_dist=0.2000
#     GT:   tan\theta=\frac{|v|^{2}}{|g|r}
#     PRED: \tan\theta=\frac{lv^{2}}{lgl}
# ----------------------------------------
#   [123/500] edit_dist=0.5294
#     GT:   \tilde{f}(k)
#     PRED: \overline{f}(v-1)
# ----------------------------------------
#   [124/500] edit_dist=0.3077
#     GT:   \tilde{e}^{a}
#     PRED: \tilde{e}\sim
# ----------------------------------------
#   [125/500] edit_dist=0.1667
#     GT:   e[(x-\mu_{x})^{2}]
#     PRED: e[(x-\mu x)^{2}]
# ----------------------------------------
#   [126/500] edit_dist=0.8718
#     GT:   [x_{w}y_{w}z_{w}1]^{t}
#     PRED: \overline{[x\omega y\omega z\omega n']}
# ----------------------------------------
#   [127/500] EXACT
#     GT:   x,x-20
#     PRED: x,x-20
# ----------------------------------------
#   [128/500] EXACT
#     GT:   -\sqrt{x}
#     PRED: -\sqrt{x}
# ----------------------------------------
#   [129/500] edit_dist=0.1111
#     GT:   \tilde{q}
#     PRED: \tilde{g}
# ----------------------------------------
#   [130/500] edit_dist=0.6875
#     GT:   \overline{r_{f}}
#     PRED: r\sqrt{f}
# ----------------------------------------
#   [131/500] edit_dist=0.8857
#     GT:   (\begin{matrix}n+1\\ k\end{matrix})
#     PRED: (h+1<)
# ----------------------------------------
#   [132/500] EXACT
#     GT:   \int_{-2}^{6}\frac{dx}{x}
#     PRED: \int_{-2}^{6}\frac{dx}{x}
# ----------------------------------------
#   [133/500] edit_dist=0.5294
#     GT:   e_{i}\frac{x^{i}}{i!}
#     PRED: \epsilon\frac{x^{\wedge}}{\wedge!}
# ----------------------------------------
#   [134/500] edit_dist=0.9091
#     GT:   (\begin{matrix}p\\ r\end{matrix})
#     PRED: (p)
# ----------------------------------------
#   [135/500] edit_dist=0.2778
#     GT:   o(kn+1.274^{k})
#     PRED: o(k^{n})+1.274^{k}
# ----------------------------------------
#   [136/500] edit_dist=0.0625
#     GT:   \frac{d^{2}u}{dy^{2}}=\frac{1}{\mu}\frac{dp}{dx}
#     PRED: \frac{d^{2}u}{dy^{2}}=\frac{1}{r}\frac{dp}{dx}
# ----------------------------------------
#   [137/500] edit_dist=0.8158
#     GT:   (\begin{matrix}1&0\\ 1&-1\end{matrix})
#     PRED: (\lambda\ 0\ \lambda\ -\lambda)
# ----------------------------------------
#   [138/500] edit_dist=0.0667
#     GT:   o((n+r)log(n))
#     PRED: o((n+r)\log(n))
# ----------------------------------------
#   [139/500] EXACT
#     GT:   0.5<\frac{a}{l}<2
#     PRED: 0.5<\frac{a}{l}<2
# ----------------------------------------
#   [140/500] EXACT
#     GT:   \frac{dy}{dx}-y=x
#     PRED: \frac{dy}{dx}-y=x
# ----------------------------------------
#   [141/500] EXACT
#     GT:   \hat{e}
#     PRED: \hat{e}
# ----------------------------------------
#   [142/500] edit_dist=0.6923
#     GT:   f(d^{\prime},r,w^{\prime})
#     PRED: f(d',r,w')
# ----------------------------------------
#   [143/500] edit_dist=0.6410
#     GT:   c(k)=(\begin{matrix}2k\\ k\end{matrix})
#     PRED: c(k)=\binom{2k}{k}
# ----------------------------------------
#   [144/500] EXACT
#     GT:   i(\theta)=p_{i}(\theta)q_{i}(\theta)
#     PRED: i(\theta)=p_{i}(\theta)q_{i}(\theta)
# ----------------------------------------
#   [145/500] edit_dist=0.6944
#     GT:   (\begin{matrix}7\\ 3\end{matrix})=35
#     PRED: \binom{7}{3}=35
# ----------------------------------------
#   [146/500] edit_dist=0.1818
#     GT:   h(r)=r^{2}\cdot loglog\frac{1}{r}
#     PRED: h(r)=r^{2}\log\log\frac{1}{r}
# ----------------------------------------
#   [147/500] edit_dist=0.4615
#     GT:   \tilde{z}_{0}
#     PRED: \sim z_{0}
# ----------------------------------------
#   [148/500] edit_dist=0.1220
#     GT:   x=[\begin{matrix}w+ix\\ y+iz\end{matrix}]
#     PRED: x=\begin{pmatrix}w+ix\\y+iz\end{pmatrix}
# ----------------------------------------
#   [149/500] edit_dist=0.2105
#     GT:   \overline{\omega}=exp(-i2\pi/3)
#     PRED: \overline{\omega}=\exp(-\lambda2\pi/3)
# ----------------------------------------
#   [150/500] EXACT
#     GT:   \frac{\partial\rho}{\partial t}+\nabla\cdot(\rho v)=0
#     PRED: \frac{\partial\rho}{\partial t}+\nabla\cdot(\rho v)=0
# ----------------------------------------
#   [151/500] edit_dist=0.3400
#     GT:   lim_{iarrow\infty}c_{i}t_{a,r_{i}\#}\mu=\nu
#     PRED: \lim_{i\to\infty}c_{i}\overline{t}a,r_{i}\#\mu=\nu
# ----------------------------------------
#   [152/500] edit_dist=0.2432
#     GT:   p_{avg}=\frac{1}{2}r_{a}i_{\circ}^{2}
#     PRED: p_{iy}=\frac{1}{2}r_{r}i_{0}^{2}
# ----------------------------------------
#   [153/500] edit_dist=0.3636
#     GT:   f(n):=n!
#     PRED: f(n):=n^{1}
# ----------------------------------------
#   [154/500] edit_dist=0.1622
#     GT:   [\begin{matrix}a\\ b\\ c\end{matrix}]
#     PRED: \begin{bmatrix}a\\b\\c\end{bmatrix}
# ----------------------------------------
#   [155/500] edit_dist=0.2727
#     GT:   \hat{k}_{g}
#     PRED: \hat{k}g
# ----------------------------------------
#   [156/500] edit_dist=0.4098
#     GT:   \sum_{j=0}^{n}(-1)^{j}(\begin{matrix}n\\ j\end{matrix})p(j)=0
#     PRED: \sum_{j=0}^{n}(-1)^{j}\binom{n}{j}p(j)=0
# ----------------------------------------
#   [157/500] edit_dist=0.0455
#     GT:   x=y=\frac{i}{\sqrt{2}}
#     PRED: x=y=\frac{1}{\sqrt{2}}
# ----------------------------------------
#   [158/500] edit_dist=0.3333
#     GT:   \hat{y}\in\{-1,1\}
#     PRED: y\in\{-1,1\}
# ----------------------------------------
#   [159/500] edit_dist=0.1111
#     GT:   gf(q)^{n}
#     PRED: gf(e)^{n}
# ----------------------------------------
#   [160/500] edit_dist=0.7805
#     GT:   (\begin{matrix}a&b/2\\ b/2&c\end{matrix})
#     PRED: (a\ \frac{b}{2}\ \frac{b}{2}\ c)
# ----------------------------------------
#   [161/500] edit_dist=0.8056
#     GT:   s\{\begin{matrix}5\\ 4\end{matrix}\}
#     PRED: s\{5,4\}
# ----------------------------------------
#   [162/500] edit_dist=0.0588
#     GT:   \underline{x}(t)
#     PRED: \underline{xc}(t)
# ----------------------------------------
#   [163/500] edit_dist=0.2500
#     GT:   [0,
#     PRED: [0,]
# ----------------------------------------
#   [164/500] edit_dist=0.7463
#     GT:   (\begin{matrix}6\\ 2\end{matrix})(\begin{matrix}43\\ 4\end{matrix})
#     PRED: \binom{6}{2}\binom{43}{4}
# ----------------------------------------
#   [165/500] edit_dist=0.4400
#     GT:   j=1,2,\cdot\cdot\cdot,k-1
#     PRED: j=1,2,\ldots,k-1
# ----------------------------------------
#   [166/500] edit_dist=0.4528
#     GT:   \overline{op_{1}}^{\prime}=\overline{op_{1}^{\prime}}
#     PRED: \overline{\sigma p_{1}'}=\overline{op_{1}'}
# ----------------------------------------
#   [167/500] EXACT
#     GT:   s\notin t
#     PRED: s\notin t
# ----------------------------------------
#   [168/500] edit_dist=0.0500
#     GT:   0\le f(\vec{r})\le1
#     PRED: 0\le f(\vec{r})\le 1
# ----------------------------------------
#   [169/500] EXACT
#     GT:   e=\sum_{n=-\infty}^{\infty}e[n]^{2}
#     PRED: e=\sum_{n=-\infty}^{\infty}e[n]^{2}
# ----------------------------------------
#   [170/500] EXACT
#     GT:   \int_{a}^{b}[f(x)-g(x)]dx
#     PRED: \int_{a}^{b}[f(x)-g(x)]dx
# ----------------------------------------
#   [171/500] edit_dist=0.2000
#     GT:   \{\hat{f}_{n}\}_{n=1}^{\infty}
#     PRED: \{f_{n}\}_{n=1}^{\infty}
# ----------------------------------------
#   [172/500] EXACT
#     GT:   x\mapsto\{\langle e_{k},x\rangle\}_{k\in n}
#     PRED: x\mapsto\{\langle e_{k},x\rangle\}_{k\in n}
# ----------------------------------------
#   [173/500] EXACT
#     GT:   \int\psi\psi^{*}dv=n_{s}
#     PRED: \int\psi\psi^{*}dv=n_{s}
# ----------------------------------------
#   [174/500] edit_dist=0.5789
#     GT:   \prod_{i=1}^{4}i=24
#     PRED: \frac{4}{\pi}i=24
# ----------------------------------------
#   [175/500] edit_dist=0.0667
#     GT:   (x,y,z,az^{4})
#     PRED: (x,y,z,a z^{4})
# ----------------------------------------
#   [176/500] edit_dist=0.8333
#     GT:   s\{\begin{matrix}4\\ 3\end{matrix}\}
#     PRED: s\{x\}
# ----------------------------------------
#   [177/500] edit_dist=0.0204
#     GT:   r_{1}r_{3}=\frac{r_{a}r_{b}^{2}r_{c}}{r_{t}^{2}}
#     PRED: r_{1}r_{3}=\frac{r_{a}r_{b}^{2}r_{c}}{r_{t}^{2}t}
# ----------------------------------------
#   [178/500] edit_dist=0.0357
#     GT:   \tilde{p}(x_{1},...,x_{n-1})
#     PRED: \tilde{p}(x_{n},...,x_{n-1})
# ----------------------------------------
#   [179/500] edit_dist=0.3784
#     GT:   d:\phi\mapsto\frac{1}{i}\phi^{\prime}
#     PRED: d:\phi\to\frac{1}{1}\phi'
# ----------------------------------------
#   [180/500] EXACT
#     GT:   \prod_{k=1}^{n}f(k)
#     PRED: \prod_{k=1}^{n}f(k)
# ----------------------------------------
#   [181/500] EXACT
#     GT:   \sqrt{x}/lnx
#     PRED: \sqrt{x}/lnx
# ----------------------------------------
#   [182/500] EXACT
#     GT:   y
#     PRED: y
# ----------------------------------------
#   [183/500] edit_dist=0.3623
#     GT:   s_{k}=(\begin{matrix}m\\ k\end{matrix})\frac{(m-k)!}{m!}=\frac{1}{k!}
#     PRED: s_{k}=\binom{m}{k}\frac{(m-k)!}{m!}=\frac{1}{k!}
# ----------------------------------------
#   [184/500] edit_dist=0.4500
#     GT:   angle(x_{1}):=\theta
#     PRED: angle(x_1)=0
# ----------------------------------------
#   [185/500] EXACT
#     GT:   x_{0}\in m(t_{0})
#     PRED: x_{0}\in m(t_{0})
# ----------------------------------------
#   [186/500] edit_dist=0.3125
#     GT:   e_{n}=\hbar\omega(n+\frac{1}{2})
#     PRED: e_{n}=hw(n+\frac{1}{2})
# ----------------------------------------
#   [187/500] edit_dist=0.6818
#     GT:   (pf)^{\wedge}=q\hat{f}
#     PRED: (pf)'=qf
# ----------------------------------------
#   [188/500] EXACT
#     GT:   \sqrt{x}
#     PRED: \sqrt{x}
# ----------------------------------------
#   [189/500] edit_dist=0.3077
#     GT:   \tilde{b}_{3}
#     PRED: \tilde{b}
# ----------------------------------------
#   [190/500] EXACT
#     GT:   x\notin n
#     PRED: x\notin n
# ----------------------------------------
#   [191/500] edit_dist=0.0588
#     GT:   \overline{k_{q}}
#     PRED: \overline{k_{qv}}
# ----------------------------------------
#   [192/500] edit_dist=0.1351
#     GT:   [\begin{matrix}0&1\\ 1&0\end{matrix}]
#     PRED: \begin{bmatrix}0&1\\1&0\end{bmatrix}
# ----------------------------------------
#   [193/500] edit_dist=0.7179
#     GT:   (d,(\begin{matrix}d+1\\ 2\end{matrix}))
#     PRED: (d,\frac{d+1}{2})
# ----------------------------------------
#   [194/500] EXACT
#     GT:   x_{0}=\frac{s^{2}-1}{s^{2}+1}
#     PRED: x_{0}=\frac{s^{2}-1}{s^{2}+1}
# ----------------------------------------
#   [195/500] EXACT
#     GT:   x=\pm\sqrt[m]{a^{n}}
#     PRED: x=\pm\sqrt[m]{a^{n}}
# ----------------------------------------
#   [196/500] edit_dist=0.0208
#     GT:   y=\frac{1}{2}laea_{y}(\frac{\lambda}{2},\varphi)
#     PRED: y=\frac{1}{2}laeq_{y}(\frac{\lambda}{2},\varphi)
# ----------------------------------------
#   [197/500] edit_dist=0.2581
#     GT:   m=(\begin{matrix}-i&i\\ exp(it)&exp(-it)\end{matrix})
#     PRED: m=\begin{pmatrix}-i&i\\e^{\exp(i4)}&e^{\exp(-i4)}\end{pmatrix}
# ----------------------------------------
#   [198/500] edit_dist=0.1316
#     GT:   (\begin{matrix}0&1\\ -1&0\end{matrix})
#     PRED: \begin{pmatrix}0&1\\-1&0\end{pmatrix}
# ----------------------------------------
#   [199/500] edit_dist=0.1176
#     GT:   \frac{d\mu}{dn}
#     PRED: \frac{d\mu}{d\nu}
# ----------------------------------------
#   [200/500] EXACT
#     GT:   i_{2}=\int f(\theta)d^{3}x
#     PRED: i_{2}=\int f(\theta)d^{3}x
# ----------------------------------------
#   [201/500] edit_dist=0.2857
#     GT:   s\notin
#     PRED: s\not=
# ----------------------------------------
#   [202/500] edit_dist=0.4167
#     GT:   \hat{f}(x)
#     PRED: \tilde{f}(x)
# ----------------------------------------
#   [203/500] edit_dist=0.0769
#     GT:   h(x)|x^{n}-1
#     PRED: h(x)|x^{n}-1|
# ----------------------------------------
#   [204/500] edit_dist=0.7917
#     GT:   l=n_{l}-n_{\overline{l}}
#     PRED: l=n\lambda-n\lambda
# ----------------------------------------
#   [205/500] edit_dist=0.3333
#     GT:   z(n;t)=o(n^{2-1/t})
#     PRED: z(n;t)=o(n^{2-\frac{1}{t}})
# ----------------------------------------
#   [206/500] edit_dist=0.3333
#     GT:   \frac{p}{q}\cdot\pi^{2m}
#     PRED: \frac{p}{2}\cdot\frac{2m}{\pi}
# ----------------------------------------
#   [207/500] EXACT
#     GT:   \int x^{k}d\mu(x)=m_{k}
#     PRED: \int x^{k}d\mu(x)=m_{k}
# ----------------------------------------
#   [208/500] EXACT
#     GT:   \int_{0}^{t}\lambda(t)dt=1
#     PRED: \int_{0}^{t}\lambda(t)dt=1
# ----------------------------------------
#   [209/500] edit_dist=0.2222
#     GT:   \delta(\omega\cdot x_{1,2})
#     PRED: \delta(w\cdot x_{1,2})
# ----------------------------------------
#   [210/500] edit_dist=0.2857
#     GT:   \frac{dy}{dx}=0
#     PRED: \frac{d_{y}}{d_{x}}=0
# ----------------------------------------
#   [211/500] edit_dist=0.6000
#     GT:   t_{n}n!=n^{n-2}n!
#     PRED: \top h^{1}=h^{r-2}h!
# ----------------------------------------
#   [212/500] EXACT
#     GT:   \{x_{i},x_{j}\}\notin e
#     PRED: \{x_{i},x_{j}\}\notin e
# ----------------------------------------
#   [213/500] edit_dist=0.1351
#     GT:   lim\frac{x}{y}=\frac{limx}{limy}
#     PRED: \lim\frac{x}{y}=\frac{\lim x}{\lim y}
# ----------------------------------------
#   [214/500] EXACT
#     GT:   c(c^{m},c^{n\times n})=0
#     PRED: c(c^{m},c^{n\times n})=0
# ----------------------------------------
#   [215/500] edit_dist=0.0968
#     GT:   p_{n}\#=\prod_{k=1}^{n}p_{k}
#     PRED: p_{n}^{\#}=\prod_{k=1}^{n}p_{k}
# ----------------------------------------
#   [216/500] edit_dist=0.0984
#     GT:   \lambda_{1}=(\begin{matrix}0&1&0\\ 1&0&0\\ 0&0&0\end{matrix})
#     PRED: \lambda_{1}=\begin{pmatrix}0&1&0\\1&0&0\\0&0&0\end{pmatrix}
# ----------------------------------------
#   [217/500] EXACT
#     GT:   h(g,u_{l})=[l:k]
#     PRED: h(g,u_{l})=[l:k]
# ----------------------------------------
#   [218/500] edit_dist=0.3333
#     GT:   \int\int_{x}\int_{y}^{z}
#     PRED: \iint x\int_{i}^{z}v
# ----------------------------------------
#   [219/500] edit_dist=0.8108
#     GT:   (\begin{matrix}c_{i}\\ i\end{matrix})
#     PRED: (c_{i})
# ----------------------------------------
#   [220/500] edit_dist=0.6230
#     GT:   \sum_{i=n}^{m}\frac{(\begin{matrix}i\\ n\end{matrix})}{2^{i}}
#     PRED: \sum_{i=1}^{n}\frac{i}{2}
# ----------------------------------------
#   [221/500] edit_dist=0.0909
#     GT:   (f^{+})_{+}
#     PRED: (f^{+})^{+}
# ----------------------------------------
#   [222/500] edit_dist=0.8788
#     GT:   [\begin{matrix}0\\ 1\end{matrix}]
#     PRED: [0,1]
# ----------------------------------------
#   [223/500] edit_dist=0.2308
#     GT:   \hat{\nu}_{i}
#     PRED: \hat{v}_{i}
# ----------------------------------------
#   [224/500] EXACT
#     GT:   10^{-12}w/\sqrt{hz}
#     PRED: 10^{-12}w/\sqrt{hz}
# ----------------------------------------
#   [225/500] EXACT
#     GT:   x_{n}=m^{n}x_{0}
#     PRED: x_{n}=m^{n}x_{0}
# ----------------------------------------
#   [226/500] edit_dist=0.4286
#     GT:   h(e^{i\omega})
#     PRED: h(e^{iw})
# ----------------------------------------
#   [227/500] edit_dist=0.1613
#     GT:   v_{y}\sqrt{v_{x}^{2}+v_{y}^{2}}
#     PRED: v\sqrt{v_{z}^{2}+v_{y}^{2}}
# ----------------------------------------
#   [228/500] edit_dist=0.1667
#     GT:   o(|\omega|k^{2}log(1/\epsilon))
#     PRED: \theta(|\omega|k^{2}log(1/\epsilon))
# ----------------------------------------
#   [229/500] EXACT
#     GT:   \{0,1,-1\}
#     PRED: \{0,1,-1\}
# ----------------------------------------
#   [230/500] edit_dist=0.2500
#     GT:   e_{p}=k_{b}t
#     PRED: e_{p}=kbt
# ----------------------------------------
#   [231/500] edit_dist=0.2000
#     GT:   c(1-\frac{r_{s}}{r})
#     PRED: c(1-\frac{s}{r})
# ----------------------------------------
#   [232/500] edit_dist=0.1250
#     GT:   \delta_{0}logf=-kf^{2}
#     PRED: \delta_{c}\log f=-kf^{2}
# ----------------------------------------
#   [233/500] edit_dist=0.7143
#     GT:   \hat{l}
#     PRED: \cap
# ----------------------------------------
#   [234/500] EXACT
#     GT:   p^{-1}fp
#     PRED: p^{-1}fp
# ----------------------------------------
#   [235/500] edit_dist=0.1064
#     GT:   m=[\begin{matrix}m_{1}&0\\ 0&m_{2}\end{matrix}]
#     PRED: m=\begin{bmatrix}m_{1}&0\\0&m_{2}\end{bmatrix}
# ----------------------------------------
#   [236/500] edit_dist=0.9000
#     GT:   [\begin{matrix}x&0\\ 0&y\\ \end{matrix}]
#     PRED: (x0,0y)
# ----------------------------------------
#   [237/500] EXACT
#     GT:   e\cap\overline{e}=\delta\otimes c
#     PRED: e\cap\overline{e}=\delta\otimes c
# ----------------------------------------
#   [238/500] edit_dist=0.1667
#     GT:   f[x,y]/(xy)
#     PRED: f[x,y]((xy))
# ----------------------------------------
#   [239/500] EXACT
#     GT:   \tilde{m}=m//g
#     PRED: \tilde{m}=m//g
# ----------------------------------------
#   [240/500] edit_dist=0.4667
#     GT:   \int_{a}^{b}f(x)dx
#     PRED: \int_{a}^{b}f(\lambda)d\lambda
# ----------------------------------------
#   [241/500] EXACT
#     GT:   s=\int ldx_{3}
#     PRED: s=\int ldx_{3}
# ----------------------------------------
#   [242/500] edit_dist=0.6400
#     GT:   ff\in l^{1}(r^{n})
#     PRED: \overline{f}\in l'(r^{b})
# ----------------------------------------
#   [243/500] edit_dist=0.7576
#     GT:   (\begin{matrix}n\\ c\end{matrix})
#     PRED: \binom{n}{c}
# ----------------------------------------
#   [244/500] edit_dist=0.1562
#     GT:   g_{kl}=2\chi\delta n\overline{n}
#     PRED: g_{kq}=2x\delta n\overline{n}
# ----------------------------------------
#   [245/500] EXACT
#     GT:   y=a\frac{d-c}{a-b}+c
#     PRED: y=a\frac{d-c}{a-b}+c
# ----------------------------------------
#   [246/500] edit_dist=0.7073
#     GT:   [\frac{\alpha}{\pi}]=[\frac{\alpha}{\theta}]
#     PRED: \begin{bmatrix}\alpha\\\pi\end{bmatrix}=\begin{bmatrix}\alpha\\\theta\end{bmatri
# ----------------------------------------
#   [247/500] edit_dist=0.2174
#     GT:   dir(\alpha/k\cdot1_{k})
#     PRED: d,r(\alpha/k\cdot2k)
# ----------------------------------------
#   [248/500] edit_dist=0.3750
#     GT:   \int ldt
#     PRED: \int<d(
# ----------------------------------------
#   [249/500] edit_dist=0.5000
#     GT:   d_{e}(x_{e}+1)
#     PRED: de(2e+1)
# ----------------------------------------
#   [250/500] edit_dist=0.8571
#     GT:   \{\begin{matrix}3\\ 3\end{matrix}\}
#     PRED: \{3\}
# ----------------------------------------
#   [251/500] edit_dist=0.4444
#     GT:   \delta e^{tot}=q+w
#     PRED: \delta e^{-t_{0}t}=qt\omega
# ----------------------------------------
#   [252/500] edit_dist=0.7857
#     GT:   d_{e}(x_{e}+1)
#     PRED: \alpha e(xe+1)
# ----------------------------------------
#   [253/500] EXACT
#     GT:   |z|=\sqrt{a^{2}+b^{2}}
#     PRED: |z|=\sqrt{a^{2}+b^{2}}
# ----------------------------------------
#   [254/500] edit_dist=0.5385
#     GT:   4\sigma/\sqrt{n}=w
#     PRED: \frac{4\delta}{\sqrt{h}}=w
# ----------------------------------------
#   [255/500] edit_dist=0.8049
#     GT:   [\begin{matrix}b/d&p\\ c/d&q\end{matrix}]
#     PRED: [\frac{b}{d}\ p;\frac{c}{d}\ q]
# ----------------------------------------
#   [256/500] EXACT
#     GT:   dm=(\frac{dy}{l})m
#     PRED: dm=(\frac{dy}{l})m
# ----------------------------------------
#   [257/500] edit_dist=0.3103
#     GT:   a_{\epsilon}^{n}(x,y)
#     PRED: a_{\varepsilon}^{\wedge}(x,y)
# ----------------------------------------
#   [258/500] edit_dist=0.3500
#     GT:   \mu y=\int\mu q(x)dx
#     PRED: my=\int mg(x)dx
# ----------------------------------------
#   [259/500] edit_dist=0.5556
#     GT:   d_{p}^{1}
#     PRED: d'_{p}
# ----------------------------------------
#   [260/500] edit_dist=0.3125
#     GT:   p(x<a)=0.98
#     PRED: p(x<\alpha)=0.98
# ----------------------------------------
#   [261/500] EXACT
#     GT:   \hat{p}
#     PRED: \hat{p}
# ----------------------------------------
#   [262/500] edit_dist=0.2564
#     GT:   |\epsilon_{n+1}|\le m{\epsilon_{n}}^{2}
#     PRED: (\epsilon n+1)(\le m\epsilon n)^{2}
# ----------------------------------------
#   [263/500] edit_dist=0.3250
#     GT:   p=\frac{e}{t}=\frac{1}{2}a\rho v^{3}
#     PRED: p=\frac{\tilde{e}}{t}=\frac{1}{2}apv^{3}
# ----------------------------------------
#   [264/500] edit_dist=0.2195
#     GT:   a=\frac{m}{\rho}\frac{n^{2}-1}{n^{2}+2}
#     PRED: \alpha=\frac{m}{p}\frac{n^{2}-1}{n^{2}+2}
# ----------------------------------------
#   [265/500] EXACT
#     GT:   \int f(x,y)dx
#     PRED: \int f(x,y)dx
# ----------------------------------------
#   [266/500] edit_dist=0.1304
#     GT:   x\mapsto xcos(2\pi x)+1
#     PRED: x\mapsto x\cos(2\pi x)h
# ----------------------------------------
#   [267/500] edit_dist=0.1667
#     GT:   e=\gamma_{(u)}m_{0}c^{2}
#     PRED: e=\gamma(v)m_{0}c^{2}
# ----------------------------------------
#   [268/500] EXACT
#     GT:   \frac{dh}{dt}=0
#     PRED: \frac{dh}{dt}=0
# ----------------------------------------
#   [269/500] edit_dist=0.0417
#     GT:   \int_{1}^{3}(27-x^{3})dx
#     PRED: \int_{1}^{7}(27-x^{3})dx
# ----------------------------------------
#   [270/500] EXACT
#     GT:   \int_{s}1ds
#     PRED: \int_{s}1ds
# ----------------------------------------
#   [271/500] EXACT
#     GT:   \omega=\frac{d\theta}{dt}=\frac{v}{r}
#     PRED: \omega=\frac{d\theta}{dt}=\frac{v}{r}
# ----------------------------------------
#   [272/500] EXACT
#     GT:   \tilde{e}=\gamma(-,e)
#     PRED: \tilde{e}=\gamma(-,e)
# ----------------------------------------
#   [273/500] edit_dist=0.3333
#     GT:   f_{\alpha}(x)=-f_{\alpha}(\tilde{x})
#     PRED: f_{2}(x)=-f_{2}(\tilde{x})
# ----------------------------------------
#   [274/500] EXACT
#     GT:   \sqrt{\theta}
#     PRED: \sqrt{\theta}
# ----------------------------------------
#   [275/500] EXACT
#     GT:   \psi
#     PRED: \psi
# ----------------------------------------
#   [276/500] edit_dist=0.5000
#     GT:   n^{1/h}\le|b\cap[1,n]|
#     PRED: n^{\gamma h}\le|bn([i,n])|
# ----------------------------------------
#   [277/500] EXACT
#     GT:   \int_{\mathbb{r}}f(x-y)g(y)dy
#     PRED: \int_{\mathbb{r}}f(x-y)g(y)dy
# ----------------------------------------
#   [278/500] EXACT
#     GT:   1-2-3
#     PRED: 1-2-3
# ----------------------------------------
#   [279/500] edit_dist=0.5814
#     GT:   \sum_{n=0}^{n}(\begin{matrix}n\\ n\end{matrix})^{2}=(\begin{matrix}2n\\ n\end{ma
#     PRED: \sum_{n=0}^{n}\binom{n}{n}^{2}=\binom{2n}{n}
# ----------------------------------------
#   [280/500] edit_dist=0.1875
#     GT:   \chi_{imp}=\frac{c}{t+\theta}
#     PRED: \lambda_{imp}=\frac{c}{t+\theta}
# ----------------------------------------
#   [281/500] edit_dist=0.0606
#     GT:   \frac{b_{2}-1}{b_{1}b_{2}}=\frac{1}{b_{1}}-\frac{1}{b_{1}b_{2}}
#     PRED: \frac{b_{1}^{-1}}{b_{1}b_{2}}=\frac{1}{b_{1}}-\frac{1}{b_{1}b_{2}}
# ----------------------------------------
#   [282/500] edit_dist=0.5000
#     GT:   k=\int|\kappa|ds
#     PRED: k=\int lkd s
# ----------------------------------------
#   [283/500] EXACT
#     GT:   \int_{d}^{\infty}e^{f(x)}dx
#     PRED: \int_{d}^{\infty}e^{f(x)}dx
# ----------------------------------------
#   [284/500] edit_dist=0.0500
#     GT:   e(k)=\hat{x}(k)-x(k)
#     PRED: p(k)=\hat{x}(k)-x(k)
# ----------------------------------------
#   [285/500] EXACT
#     GT:   p=\{p_{\theta}|\theta\in\theta\}
#     PRED: p=\{p_{\theta}|\theta\in\theta\}
# ----------------------------------------
#   [286/500] edit_dist=0.0588
#     GT:   i=\int xcos(x)dx
#     PRED: i=\int x\cos(x)dx
# ----------------------------------------
#   [287/500] EXACT
#     GT:   dn(m,z)/dm
#     PRED: dn(m,z)/dm
# ----------------------------------------
#   [288/500] edit_dist=0.3673
#     GT:   \frac{4}{12}\times\frac{23}{12}=0.63\dot{8}ft^{2}
#     PRED: \frac{4}{12}x\frac{2^{3}}{12}=0.63b(c^{2}
# ----------------------------------------
#   [289/500] edit_dist=0.2941
#     GT:   \tilde{b}_{5}
#     PRED: \tilde{b}_{s}^{-}
# ----------------------------------------
#   [290/500] edit_dist=0.1220
#     GT:   m=[\begin{matrix}a&b-a\\ 0&b\end{matrix}]
#     PRED: m=\begin{bmatrix}a&b-a\\0&b\end{bmatrix}
# ----------------------------------------
#   [291/500] EXACT
#     GT:   \hat{y}\in\{-1,1\}
#     PRED: \hat{y}\in\{-1,1\}
# ----------------------------------------
#   [292/500] EXACT
#     GT:   \hat{h}=\hat{h}(\hat{p})
#     PRED: \hat{h}=\hat{h}(\hat{p})
# ----------------------------------------
#   [293/500] EXACT
#     GT:   f=p-\frac{\partial v}{\partial r}
#     PRED: f=p-\frac{\partial v}{\partial r}
# ----------------------------------------
#   [294/500] edit_dist=0.0294
#     GT:   \sum_{l}l^{2}4^{-2l}e^{-4\beta l}
#     PRED: \sum_{l}l^{2}4^{-2l}-e^{-4\beta l}
# ----------------------------------------
#   [295/500] edit_dist=0.1429
#     GT:   30<\epsilon_{r}<50
#     PRED: 30<\varepsilon_{r}<50
# ----------------------------------------
#   [296/500] edit_dist=0.2941
#     GT:   fx/so(1,3)arrow x
#     PRED: f:x/so(1,3)\to x
# ----------------------------------------
#   [297/500] edit_dist=0.0270
#     GT:   \frac{\partial q^{i}}{\partial x_{j}}
#     PRED: \frac{\partial q^{i}}{\partial x^{j}}
# ----------------------------------------
#   [298/500] EXACT
#     GT:   \tilde{t}_{i}
#     PRED: \tilde{t}_{i}
# ----------------------------------------
#   [299/500] edit_dist=0.3636
#     GT:   ra=\{ra|r\in r\}
#     PRED: r_{a}=\{t_{a}|t\in r\}
# ----------------------------------------
#   [300/500] EXACT
#     GT:   \tilde{u}(x)
#     PRED: \tilde{u}(x)
# ----------------------------------------
#   [301/500] edit_dist=0.2188
#     GT:   value=\lambda v.(\lambda h.hv)
#     PRED: value=\lambda v(\lambda h\omega)
# ----------------------------------------
#   [302/500] edit_dist=0.2000
#     GT:   \sqrt{(}t)
#     PRED: \sqrt{(t)}
# ----------------------------------------
#   [303/500] edit_dist=0.9000
#     GT:   \prod_{i=n-r+1}^{n}i
#     PRED: i=\frac{h}{11}=h-r+1
# ----------------------------------------
#   [304/500] edit_dist=0.0769
#     GT:   \tilde{g}_{n}
#     PRED: \tilde{g}_{m}
# ----------------------------------------
#   [305/500] edit_dist=0.1250
#     GT:   \frac{df}{dz}=g
#     PRED: \frac{df}{dt}=-g
# ----------------------------------------
#   [306/500] EXACT
#     GT:   f=\tilde{f}i
#     PRED: f=\tilde{f}i
# ----------------------------------------
#   [307/500] EXACT
#     GT:   e_{p,m}=\frac{1}{2}li^{2}
#     PRED: e_{p,m}=\frac{1}{2}li^{2}
# ----------------------------------------
#   [308/500] EXACT
#     GT:   (c-r)
#     PRED: (c-r)
# ----------------------------------------
#   [309/500] EXACT
#     GT:   i\notin x
#     PRED: i\notin x
# ----------------------------------------
#   [310/500] edit_dist=0.4615
#     GT:   \sqrt{0}
#     PRED: \sqrt{\sigma}
# ----------------------------------------
#   [311/500] edit_dist=0.0541
#     GT:   t^{*}=\frac{(t-t_{o})}{(t_{s}-t_{o})}
#     PRED: t^{*}=\frac{(t-t_{0})}{(t_{s}-t_{0})}
# ----------------------------------------
#   [312/500] edit_dist=0.2821
#     GT:   t(p)=\frac{1-z_{a}}{1+z_{a}}
#     PRED: \overline{t(p)}=\frac{1-z_{a}}{1+z_{a}}
# ----------------------------------------
#   [313/500] edit_dist=0.8333
#     GT:   \tilde{\chi}
#     PRED: \sim x
# ----------------------------------------
#   [314/500] edit_dist=0.0667
#     GT:   \int cos^{2}xdx
#     PRED: \int\cos^{2}xdx
# ----------------------------------------
#   [315/500] EXACT
#     GT:   o()
#     PRED: o()
# ----------------------------------------
#   [316/500] EXACT
#     GT:   \sqrt{t}
#     PRED: \sqrt{t}
# ----------------------------------------
#   [317/500] edit_dist=0.6957
#     GT:   b^{\prime}\in(\begin{matrix}c\\ b\end{matrix})
#     PRED: b^{1}\in(\beta)
# ----------------------------------------
#   [318/500] EXACT
#     GT:   \omega=\rho+i\tilde{\rho}(\rho)
#     PRED: \omega=\rho+i\tilde{\rho}(\rho)
# ----------------------------------------
#   [319/500] edit_dist=0.0625
#     GT:   m(a)=\int_{a}xdn
#     PRED: m(a)=\int_{a}xdm
# ----------------------------------------
#   [320/500] EXACT
#     GT:   q(\sqrt{13})
#     PRED: q(\sqrt{13})
# ----------------------------------------
#   [321/500] edit_dist=0.3000
#     GT:   c(\vec{n})
#     PRED: c(\hat{n})
# ----------------------------------------
#   [322/500] edit_dist=0.7297
#     GT:   ss\{\begin{matrix}2\\ 4\end{matrix}\}
#     PRED: \{\{\frac{2}{4}\}
# ----------------------------------------
#   [323/500] edit_dist=0.2308
#     GT:   c_{\tilde{y}}
#     PRED: c\tilde{y}
# ----------------------------------------
#   [324/500] EXACT
#     GT:   \{(-1)^{\pi}\}
#     PRED: \{(-1)^{\pi}\}
# ----------------------------------------
#   [325/500] edit_dist=0.1290
#     GT:   \frac{\partial}{\partial\theta}
#     PRED: \frac{\partial}{\partial\phi}
# ----------------------------------------
#   [326/500] EXACT
#     GT:   \{1,2,3\}\notin\{1,2,3\}
#     PRED: \{1,2,3\}\notin\{1,2,3\}
# ----------------------------------------
#   [327/500] edit_dist=0.2571
#     GT:   \mu_{0}\epsilon_{0}=1/c^{2}
#     PRED: \mu_{0}\epsilon_{0}=\frac{1}{c^{2}}
# ----------------------------------------
#   [328/500] edit_dist=0.3103
#     GT:   u=2\sqrt{-\frac{p}{3}}
#     PRED: u<\partial\sqrt{-\frac{p}{3}}
# ----------------------------------------
#   [329/500] edit_dist=0.5349
#     GT:   \frac{\partial}{\partial z}p_{c}^{p}(z_{0})
#     PRED: \frac{\partial\psi^{2}}{\partial x}c(
# ----------------------------------------
#   [330/500] edit_dist=0.0476
#     GT:   \frac{1}{2}v^{2}=u(x)
#     PRED: \frac{1}{2}v^{2}=w(x)
# ----------------------------------------
#   [331/500] edit_dist=0.3077
#     GT:   \tilde{d}_{6}
#     PRED: \tilde{d}b
# ----------------------------------------
#   [332/500] edit_dist=0.3448
#     GT:   \int_{t-r}^{t}e(t^{\prime})dt
#     PRED: \int_{t-r}^{t}e(t')dt'
# ----------------------------------------
#   [333/500] edit_dist=0.1667
#     GT:   ai_{t}=100\times\frac{d}{n}
#     PRED: a_{i}^{t}=100\times\frac{2}{n}
# ----------------------------------------
#   [334/500] EXACT
#     GT:   \int_{0}^{t}z_{s}ds
#     PRED: \int_{0}^{t}z_{s}ds
# ----------------------------------------
#   [335/500] EXACT
#     GT:   (a^{t}a)^{-1}=q
#     PRED: (a^{t}a)^{-1}=q
# ----------------------------------------
#   [336/500] edit_dist=0.8378
#     GT:   hr\{\begin{matrix}p\\ q\end{matrix}\}
#     PRED: hv\{q\}
# ----------------------------------------
#   [337/500] EXACT
#     GT:   \int_{c}^{d}f(x)dx
#     PRED: \int_{c}^{d}f(x)dx
# ----------------------------------------
#   [338/500] EXACT
#     GT:   [\gamma^{\mu},\gamma^{\nu}]_{+}=2g^{\mu\nu}
#     PRED: [\gamma^{\mu},\gamma^{\nu}]_{+}=2g^{\mu\nu}
# ----------------------------------------
#   [339/500] edit_dist=0.5455
#     GT:   j_{(z_{v})}
#     PRED: j(zv)
# ----------------------------------------
#   [340/500] edit_dist=0.1579
#     GT:   \gamma_{nl}|a|^{2}a
#     PRED: \gamma nl|a|^{2}a
# ----------------------------------------
#   [341/500] EXACT
#     GT:   \prod_{n}(z-c_{n})
#     PRED: \prod_{n}(z-c_{n})
# ----------------------------------------
#   [342/500] edit_dist=0.7273
#     GT:   \tilde{\pi}
#     PRED: \pi
# ----------------------------------------
#   [343/500] EXACT
#     GT:   q(\theta^{(t)}|\theta^{(t)})
#     PRED: q(\theta^{(t)}|\theta^{(t)})
# ----------------------------------------
#   [344/500] edit_dist=0.1579
#     GT:   (i+2^{-n}m)^{2^{n}}
#     PRED: (i+2^{-n}m)^{2n}
# ----------------------------------------
#   [345/500] edit_dist=0.0417
#     GT:   \int_{0}^{3}|x^{2}-4|dx
#     PRED: \int_{0}^{3}|x|^{2}-4|dx
# ----------------------------------------
#   [346/500] edit_dist=0.5556
#     GT:   \tilde{l}
#     PRED: \lceil
# ----------------------------------------
#   [347/500] edit_dist=0.8421
#     GT:   \underline{\underline{k}}=\underline{\underline{a^{t}ka}}
#     PRED: k=a^{t}ka
# ----------------------------------------
#   [348/500] edit_dist=0.2308
#     GT:   -\vec{\omega}\times\vec{r}
#     PRED: -\vec{w}\times\vec{r}
# ----------------------------------------
#   [349/500] EXACT
#     GT:   \int_{1}^{3}(27-x^{3})dx
#     PRED: \int_{1}^{3}(27-x^{3})dx
# ----------------------------------------
#   [350/500] edit_dist=0.2778
#     GT:   ff\in l^{1}(r^{n})
#     PRED: f\in l'(r^{n})
# ----------------------------------------
#   [351/500] edit_dist=0.5758
#     GT:   \mu_{g}(h_{1},h_{2})=(-1)^{k}p^{(\begin{matrix}k\\ 2\end{matrix})}
#     PRED: mg(h_{1},h_{2})=(-1)^{k}p(k)
# ----------------------------------------
#   [352/500] EXACT
#     GT:   f(t)\in p^{(m)}(a_{0})
#     PRED: f(t)\in p^{(m)}(a_{0})
# ----------------------------------------
#   [353/500] edit_dist=0.0476
#     GT:   2cos(\frac{2\pi}{7})
#     PRED: 2\cos(\frac{2\pi}{7})
# ----------------------------------------
#   [354/500] edit_dist=0.5625
#     GT:   (y^{\prime},x^{\prime})\sim(y,x)
#     PRED: (y',x')\sim(y,x)
# ...
#   [386/500] edit_dist=0.6154
#     GT:   \langle w^{\prime},r^{\prime},\vdash^{\prime}\rangle
#     PRED: \langle w',r',h'\rangle
# ----------------------------------------
#   [387/500] edit_dist=0.0526
#     GT:   \prod_{i=a}^{b}f(i)
#     PRED: \prod_{i=a}^{6}f(i)
# ----------------------------------------
#   [388/500] edit_dist=0.5476
#     GT:   t_{1}s_{2}\overline{t_{1}s_{2}}^{-1}=(123)
#     PRED: t_{1s2}t_{5n}^{-1}=(tz)
# ----------------------------------------
#   [389/500] edit_dist=0.7879
#     GT:   (\begin{matrix}4\\ 7\end{matrix})
#     PRED: (\frac{4}{7})
# ----------------------------------------
#   [390/500] edit_dist=0.0400
#     GT:   \int_{0}^{1}-ln(x)f(x)dx
#     PRED: \int_{0}^{1}-\ln(x)f(x)dx
# ----------------------------------------
#   [391/500] edit_dist=0.2941
#     GT:   f_{\xi}(x)=\langle\xi|\pi(x)\xi\rangle
#     PRED: f_{\xi}(g\xi)=\langle\xi|\overline{l(x|\xi)}\rangle
# ----------------------------------------
#   [392/500] EXACT
#     GT:   \int\frac{dy}{y}
#     PRED: \int\frac{dy}{y}
# ----------------------------------------
#   [393/500] edit_dist=0.5556
#     GT:   o(n^{log_{2}3})
#     PRED: \sigma(h\log_{2}3)
# ----------------------------------------
#   [394/500] edit_dist=0.8108
#     GT:   (\begin{matrix}1&2\\ 2&4\end{matrix})
#     PRED: (1\ 2;2\ 4)
# ----------------------------------------
#   [395/500] edit_dist=0.0417
#     GT:   e=\sqrt{h^{2}+(a-b)^{2}}
#     PRED: e=\sqrt{1^{2}+(a-b)^{2}}
# ----------------------------------------
#   [396/500] edit_dist=0.4783
#     GT:   \hat{\zeta}_{0}(\omega)
#     PRED: \hat{s}_{0}(w)
# ----------------------------------------
#   [397/500] edit_dist=0.0833
#     GT:   0,c_{i},-c_{i},c_{i}^{*}
#     PRED: 0,c_{1},-c_{i}c_{i}^{*}
# ----------------------------------------
#   [398/500] EXACT
#     GT:   \varphi
#     PRED: \varphi
# ----------------------------------------
#   [399/500] EXACT
#     GT:   p_{max}=\frac{1}{4}p_{max}q_{max}
#     PRED: p_{max}=\frac{1}{4}p_{max}q_{max}
# ----------------------------------------
#   [400/500] edit_dist=0.8049
#     GT:   [\begin{matrix}x&=&p\\ y&=&p\end{matrix}]
#     PRED: [x=\gamma,y=p]
# ----------------------------------------
#   [401/500] EXACT
#     GT:   -a(e-1)
#     PRED: -a(e-1)
# ----------------------------------------
#   [402/500] edit_dist=0.6154
#     GT:   m^{+}\oplus l
#     PRED: m+\theta l
# ----------------------------------------
#   [403/500] edit_dist=0.0833
#     GT:   ||f_{n}(x)||_{b}\le g(x)
#     PRED: ||f_n(x)||_{b}\le g(x)
# ----------------------------------------
#   [404/500] EXACT
#     GT:   \frac{2}{\frac{1}{60}+\frac{1}{40}}=48
#     PRED: \frac{2}{\frac{1}{60}+\frac{1}{40}}=48
# ----------------------------------------
#   [405/500] edit_dist=0.1333
#     GT:   i(x;y)\le h(x)
#     PRED: i(x,y)\leq h(x)
# ----------------------------------------
#   [406/500] edit_dist=0.1429
#     GT:   \hat{z}
#     PRED: \hat{?}
# ----------------------------------------
#   [407/500] edit_dist=0.7826
#     GT:   s\approx l_{isco}+s_{1}
#     PRED: s\in l^{1}(0+\beta)
# ----------------------------------------
#   [408/500] edit_dist=0.0714
#     GT:   p_{i}\#=\prod_{j=1}^{i}p_{j}
#     PRED: p_{i\#}=\prod_{j=1}^{i}p_{j}
# ----------------------------------------
#   [409/500] EXACT
#     GT:   \int_{\gamma}dz=0
#     PRED: \int_{\gamma}dz=0
# ----------------------------------------
#   [410/500] edit_dist=0.7333
#     GT:   \chi_{0.50}^{2}
#     PRED: x^{2}0.50
# ----------------------------------------
#   [411/500] edit_dist=0.4545
#     GT:   \hat{b}_{i}
#     PRED: \hat{p}
# ----------------------------------------
#   [412/500] edit_dist=0.4783
#     GT:   \tilde{e}_{i}l\subset l
#     PRED: e_{j}\in l\subset l
# ----------------------------------------
#   [413/500] EXACT
#     GT:   y_{i,j}=\sqrt{x_{i,j}}
#     PRED: y_{i,j}=\sqrt{x_{i,j}}
# ----------------------------------------
#   [414/500] edit_dist=0.6486
#     GT:   (\begin{matrix}m\\ r\end{matrix})_{q}
#     PRED: \binom{m}{r}_{q}
# ----------------------------------------
#   [415/500] edit_dist=0.8750
#     GT:   e
#     PRED: \epsilon
# ----------------------------------------
#   [416/500] EXACT
#     GT:   v(t)=i\frac{dl(t)}{dt}
#     PRED: v(t)=i\frac{dl(t)}{dt}
# ----------------------------------------
#   [417/500] EXACT
#     GT:   r=\sum_{a\in\sigma}v(a)r_{a}
#     PRED: r=\sum_{a\in\sigma}v(a)r_{a}
# ----------------------------------------
#   [418/500] edit_dist=0.0923
#     GT:   c_{h}\ge\frac{t}{\chi_{t}}(\frac{\partial m}{\partial t})_{h}^{2}
#     PRED: c_{h}>\frac{t}{\chi t}(\frac{\partial m}{\partial t})_{h}^{2}
# ----------------------------------------
#   [419/500] EXACT
#     GT:   n_{\alpha}^{l}
#     PRED: n_{\alpha}^{l}
# ----------------------------------------
#   [420/500] edit_dist=0.1613
#     GT:   \kappa=a_{p}^{-1}(\overline{r})
#     PRED: k=a_{p}^{-1}(\overline{r})
# ----------------------------------------
#   [421/500] edit_dist=0.0769
#     GT:   r_{0,1}=2.405
#     PRED: r_{0,1}=2.403
# ----------------------------------------
#   [422/500] EXACT
#     GT:   \hat{w}(f)
#     PRED: \hat{w}(f)
# ----------------------------------------
#   [423/500] edit_dist=0.4651
#     GT:   \underline{p}(cl_{1}^{\le})=\{x_{1},x_{5}\}
#     PRED: p(c(\leq_{1}))=\{x_{1},x_{5}\}
# ----------------------------------------
#   [424/500] edit_dist=0.3000
#     GT:   \sqrt{a^{2}+b^{2}}=c
#     PRED: \sqrt{x^{2}+r}=c
# ----------------------------------------
#   [425/500] edit_dist=0.4419
#     GT:   \underline{p}(cl_{1}^{\le})=\{x_{1},x_{5}\}
#     PRED: p(c_{i}\leq l)=\{x_{1},x_{5}\}
# ----------------------------------------
#   [426/500] EXACT
#     GT:   \infty k\delta(s)\hat{z}
#     PRED: \infty k\delta(s)\hat{z}
# ----------------------------------------
#   [427/500] EXACT
#     GT:   1019(4.163\%)
#     PRED: 1019(4.163\%)
# ----------------------------------------
#   [428/500] edit_dist=0.2000
#     GT:   \{\begin{matrix}3\\ 7\end{matrix}\}
#     PRED: \begin{pmatrix}3\\7\end{pmatrix}
# ----------------------------------------
#   [429/500] edit_dist=0.2500
#     GT:   b(1-a-d)=0
#     PRED: b(1-a-d)\ge0
# ----------------------------------------
#   [430/500] EXACT
#     GT:   \frac{\partial n}{\partial t}=-\nabla\cdot j+w
#     PRED: \frac{\partial n}{\partial t}=-\nabla\cdot j+w
# ----------------------------------------
#   [431/500] edit_dist=0.2222
#     GT:   \int_{a}^{b}f(x)dx
#     PRED: \int a^{b}+f(x)dx
# ----------------------------------------
#   [432/500] edit_dist=0.1250
#     GT:   m(l)_{n}=m_{n+l}
#     PRED: m(1)_{n}=m_{n+1}
# ----------------------------------------
#   [433/500] edit_dist=0.6957
#     GT:   pr(r_{i}<\underline{r})
#     PRED: p_{r}(r_{2}<r)
# ----------------------------------------
#   [434/500] edit_dist=0.7857
#     GT:   c_{x\tilde{y}}
#     PRED: c\times\bar{y}
# ----------------------------------------
#   [435/500] EXACT
#     GT:   l
#     PRED: l
# ----------------------------------------
#   [436/500] edit_dist=0.0345
#     GT:   l=\frac{1}{k}l=i-\frac{1}{k}a
#     PRED: l=\frac{1}{k}l=z-\frac{1}{k}a
# ----------------------------------------
#   [437/500] edit_dist=0.2400
#     GT:   \sigma_{y=0},\sigma_{y=1}
#     PRED: \sum_{y=0},\sum_{y=1}
# ----------------------------------------
#   [438/500] edit_dist=0.7500
#     GT:   \hat{1}
#     PRED: \uparrow
# ----------------------------------------
#   [439/500] edit_dist=0.0312
#     GT:   \frac{n}{2\pi}sin\frac{2\pi}{n}
#     PRED: \frac{n}{2\pi}\sin\frac{2\pi}{n}
# ----------------------------------------
#   [440/500] EXACT
#     GT:   \partial_{t}u=\delta u+\xi
#     PRED: \partial_{t}u=\delta u+\xi
# ----------------------------------------
#   [441/500] edit_dist=0.5769
#     GT:   \phi=\bigwedge_{r}\phi_{r}
#     PRED: \phi=\lambda\phi
# ----------------------------------------
#   [442/500] EXACT
#     GT:   \hat{l}x(x)=\lambda x(x)
#     PRED: \hat{l}x(x)=\lambda x(x)
# ----------------------------------------
#   [443/500] edit_dist=0.8286
#     GT:   \{\begin{matrix}3\\ 5\end{matrix}\}
#     PRED: \{3,5\}
# ----------------------------------------
#   [444/500] EXACT
#     GT:   12^{2}+35^{2}=37^{2}
#     PRED: 12^{2}+35^{2}=37^{2}
# ----------------------------------------
#   [445/500] edit_dist=0.9167
#     GT:   \overline{z}
#     PRED: \sum
# ----------------------------------------
#   [446/500] edit_dist=0.2727
#     GT:   \frac{da}{dt}=[a,h]+\frac{\partial a}{\partial t}
#     PRED: \frac{d\lambda}{dt}=[\lambda,h]+\frac{\partial\lambda}{\partial t}
# ----------------------------------------
#   [447/500] edit_dist=0.1429
#     GT:   a]=\{x\le a\}
#     PRED: d]=\{x\leq a\}
# ----------------------------------------
#   [448/500] edit_dist=0.0476
#     GT:   \sigma_{1}\mapsto(-t)
#     PRED: \sigma_{s}\mapsto(-t)
# ----------------------------------------
#   [449/500] edit_dist=0.8158
#     GT:   (\begin{matrix}i&-1\\ i&1\end{matrix})
#     PRED: (i:-\frac{1}{1})
# ----------------------------------------
#   [450/500] EXACT
#     GT:   \hat{q}=2^{-1/2}(\hat{a}^{\dagger}+\hat{a})
#     PRED: \hat{q}=2^{-1/2}(\hat{a}^{\dagger}+\hat{a})
# ----------------------------------------
#   [451/500] EXACT
#     GT:   \frac{dn}{dt}
#     PRED: \frac{dn}{dt}
# ----------------------------------------
#   [452/500] edit_dist=0.5581
#     GT:   2\pi ib|db|=i\frac{d\sigma}{d\omega}d\omega
#     PRED: 2\pi i\int_{b}|db|=i\frac{d\phi}{ds}ds
# ----------------------------------------
#   [453/500] edit_dist=0.8378
#     GT:   (\begin{matrix}1&d\\ 0&1\end{matrix})
#     PRED: (1\ d;0\ 1)
# ----------------------------------------
#   [454/500] edit_dist=0.5455
#     GT:   \int f(x)dx=1
#     PRED: \int r(\phi)d\lambda=1
# ----------------------------------------
#   [455/500] edit_dist=0.0800
#     GT:   v_{-}=be^{\frac{-1}{rc}t}
#     PRED: v_{-}=be^{-\frac{1}{rc}t}
# ----------------------------------------
#   [456/500] EXACT
#     GT:   \hat{l}^{2}
#     PRED: \hat{l}^{2}
# ----------------------------------------
#   [457/500] edit_dist=0.9000
#     GT:   \tilde{v}
#     PRED: \checkmark
# ----------------------------------------
#   [458/500] EXACT
#     GT:   p(r)=\frac{1}{z}e^{-\frac{f(r)}{kt}}
#     PRED: p(r)=\frac{1}{z}e^{-\frac{f(r)}{kt}}
# ----------------------------------------
#   [459/500] edit_dist=0.5750
#     GT:   f^{2}=k_{1}k_{2}\frac{m_{1}m_{2}}{r^{2}}
#     PRED: \gamma^{2}=lk\frac{m,n}{r^{2}c^{2}}
# ----------------------------------------
#   [460/500] edit_dist=0.8788
#     GT:   (\begin{matrix}0\\ 1\end{matrix})
#     PRED: (0,1)
# ----------------------------------------
#   [461/500] EXACT
#     GT:   \frac{\partial x}{\partial\theta}
#     PRED: \frac{\partial x}{\partial\theta}
# ----------------------------------------
#   [462/500] edit_dist=0.2333
#     GT:   k([\overline{x}])=i^{r-1}([y])
#     PRED: k([\bar{x}])=i^{r-1}([y])
# ----------------------------------------
#   [463/500] edit_dist=0.6500
#     GT:   [a,\overline{q}]=\frac{1}{2}\overline{q}
#     PRED: \{a,q\}=-\frac{1}{2}q
# ----------------------------------------
#   [464/500] EXACT
#     GT:   \tilde{t}_{i}
#     PRED: \tilde{t}_{i}
# ----------------------------------------
#   [465/500] edit_dist=0.1915
#     GT:   m_{j}\sim\rho^{\frac{3}{2}(\gamma-\frac{4}{3})}
#     PRED: m_{j}\sim\rho^{3/2}(\gamma-\frac{4}{3})
# ----------------------------------------
#   [466/500] edit_dist=0.2000
#     GT:   \sqrt{(}t)
#     PRED: \sqrt{(t)}
# ----------------------------------------
#   [467/500] EXACT
#     GT:   t=\sqrt{n_{0}/2^{k}}
#     PRED: t=\sqrt{n_{0}/2^{k}}
# ----------------------------------------
#   [468/500] EXACT
#     GT:   (=\hat{\beta}\hat{\alpha})
#     PRED: (=\hat{\beta}\hat{\alpha})
# ----------------------------------------
#   [469/500] edit_dist=0.1622
#     GT:   (\begin{matrix}1&t\\ 0&1\end{matrix})
#     PRED: \begin{pmatrix}1&x\\0&1\end{pmatrix}
# ----------------------------------------
#   [470/500] EXACT
#     GT:   \frac{(2b^{2}+2c^{2}-a^{2})}{4}
#     PRED: \frac{(2b^{2}+2c^{2}-a^{2})}{4}
# ----------------------------------------
#   [471/500] EXACT
#     GT:   \int\sigma_{x}da=0
#     PRED: \int\sigma_{x}da=0
# ----------------------------------------
#   [472/500] edit_dist=0.5882
#     GT:   h[w_{1},...,w_{n}]|j|
#     PRED: h[\omega_{1},\ldots,\omega_{n}][j]
# ----------------------------------------
#   [473/500] EXACT
#     GT:   \frac{du}{ds}=0
#     PRED: \frac{du}{ds}=0
# ----------------------------------------
#   [474/500] edit_dist=0.1944
#     GT:   \overline{x}\sim n(\mu,\sigma^{2}/n)
#     PRED: \bar{x}\sim n(\mu,\sigma^{2}/n)
# ----------------------------------------
#   [475/500] edit_dist=0.2000
#     GT:   \hat{t}(x)^{-1}\hat{h}\hat{t}(x)=\hat{h}
#     PRED: \hat{t}(p)+\hat{p}\hat{t}(x)=\hat{1}
# ----------------------------------------
#   [476/500] edit_dist=0.0667
#     GT:   (d^{\nabla})^{2}\sigma=f^{\nabla}\wedge\sigma
#     PRED: (d\nabla)^{2}\sigma=f^{\nabla}\wedge\sigma
# ----------------------------------------
#   [477/500] edit_dist=0.2250
#     GT:   z=(\begin{matrix}z&0\\ w&-z\end{matrix})
#     PRED: z=\begin{pmatrix}4&9\\4&-2\end{pmatrix}
# ----------------------------------------
#   [478/500] edit_dist=0.0476
#     GT:   p(a_{1})\le p(a_{1})
#     PRED: p(a_{1})\leq p(a_{1})
# ----------------------------------------
#   [479/500] EXACT
#     GT:   \int dx=x+c
#     PRED: \int dx=x+c
# ----------------------------------------
#   [480/500] edit_dist=0.8108
#     GT:   (\begin{matrix}0&0\\ 0&1\end{matrix})
#     PRED: (0\ 0;0\ 1)
# ----------------------------------------
#   [481/500] edit_dist=0.3600
#     GT:   \gamma_{nl}|a|^{2}a
#     PRED: \gamma_{n}e|a|^{z}\lambda
# ----------------------------------------
#   [482/500] EXACT
#     GT:   \int_{v_{1}}^{v_{2}}pdv
#     PRED: \int_{v_{1}}^{v_{2}}pdv
# ----------------------------------------
#   [483/500] EXACT
#     GT:   c^{n}=\bigoplus_{i=1}^{k}y_{i}
#     PRED: c^{n}=\bigoplus_{i=1}^{k}y_{i}
# ----------------------------------------
#   [484/500] edit_dist=0.2500
#     GT:   \tilde{x}arrow x
#     PRED: \tilde{x}\to x
# ----------------------------------------
#   [485/500] EXACT
#     GT:   \sqrt{g}
#     PRED: \sqrt{g}
# ----------------------------------------
#   [486/500] edit_dist=0.2364
#     GT:   -\frac{p\dot{r}}{r^{2}}=-\epsilon sin\theta\dot{\theta}
#     PRED: -\frac{pr}{r^{2}}=-\epsilon\sin\theta\theta
# ----------------------------------------
#   [487/500] edit_dist=0.1892
#     GT:   15*(\begin{matrix}66\\ 8\end{matrix})
#     PRED: 15*\begin{pmatrix}6\\3\end{pmatrix}
# ----------------------------------------
#   [488/500] EXACT
#     GT:   \frac{k_{i}}{k_{d}}=\omega_{0}^{2}
#     PRED: \frac{k_{i}}{k_{d}}=\omega_{0}^{2}
# ----------------------------------------
#   [489/500] edit_dist=0.1111
#     GT:   =k\int_{r}^{\infty}\rho dr
#     PRED: =1<\int_{r}^{\infty}\rho dv
# ----------------------------------------
#   [490/500] edit_dist=0.1364
#     GT:   \frac{\partial}{\partial z}f(\overline{z},z)
#     PRED: \frac{\partial}{\partial z}f(\tilde{z},z)
# ----------------------------------------
#   [491/500] EXACT
#     GT:   w_{r}=\alpha s+\beta aw_{p}
#     PRED: w_{r}=\alpha s+\beta aw_{p}
# ----------------------------------------
#   [492/500] edit_dist=0.7727
#     GT:   (pf)^{\wedge}=q\hat{f}
#     PRED: (p+r)=qf
# ----------------------------------------
#   [493/500] EXACT
#     GT:   n=\frac{i-r}{||i-r||}
#     PRED: n=\frac{i-r}{||i-r||}
# ----------------------------------------
#   [494/500] edit_dist=0.4490
#     GT:   t_{2}=t_{1}e^{\mu_{s}\beta}
#     PRED: \overline{t_{2}}=\overline{t_{1}}e^{\mu_{s}\beta}
# ----------------------------------------
#   [495/500] edit_dist=0.3600
#     GT:   \int_{0}^{1}g_{n}=1
#     PRED: \int_{0}^{1}\hat{g}\sim=1
# ----------------------------------------
#   [496/500] edit_dist=0.3548
#     GT:   \frac{1}{min_{i}h_{c}(o)-t_{i}}
#     PRED: \min_{i}h_{i}(0)-t_{i}
# ----------------------------------------
#   [497/500] edit_dist=0.3947
#     GT:   \dot{y}=\frac{1}{c}\overline{h}(0,y,0)
#     PRED: y=\frac{1}{c}\bar{h}(0,yp)
# ----------------------------------------
#   [498/500] edit_dist=0.5806
#     GT:   \frac{dx}{dt}=c
#     PRED: \frac{\partial x}{\partial t}=c
# ----------------------------------------
#   [499/500] edit_dist=0.5714
#     GT:   (\begin{matrix}\alpha&\beta\\ \overline{\beta}&\overline{\alpha}\end{matrix})
#     PRED: (\frac{\alpha}{\beta}\ \frac{\beta}{\alpha})
# ----------------------------------------
#   [500/500] edit_dist=0.7000
#     GT:   p=(\begin{matrix}a+1\\ 1\\ \end{matrix})
#     PRED: p=\binom{a+1}{1}
# ----------------------------------------
# ============================================================
# gpt-5.2 results (8-shot, normalized)
# Exact match: 32.00% (160/500)
# Avg normalized edit: 0.2603

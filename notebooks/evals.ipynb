# %%
import torch
import numpy as np
import sys
import pickle
from pathlib import Path
from datasets import load_dataset

sys.path.insert(0, "models")

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
ARTIFACTS = Path("artifacts")

def normalized_edit_distance(s1, s2):
    if len(s1) == 0 and len(s2) == 0: return 0.0
    if len(s1) == 0 or  len(s2) == 0: return 1.0
    d = [[0] * (len(s2) + 1) for _ in range(len(s1) + 1)]
    for i in range(len(s1) + 1): d[i][0] = i
    for j in range(len(s2) + 1): d[0][j] = j
    for i in range(1, len(s1) + 1):
        for j in range(1, len(s2) + 1):
            cost = 0 if s1[i-1] == s2[j-1] else 1
            d[i][j] = min(d[i-1][j]+1, d[i][j-1]+1, d[i-1][j-1]+cost)
    return d[len(s1)][len(s2)] / max(len(s1), len(s2))

print(f"Device: {DEVICE}")
# Out:
# Device: cuda

# %%
N = 100
ds = load_dataset("deepcopy/MathWriting-human")
ds_test = ds["val"].select(range(N))
gt_latex = [s["latex"] for s in ds_test]
print(f"Loaded {N} samples from validation split")
print(f"Available splits: {list(ds.keys())}")
# Out:
# Loaded 100 samples from validation split
# Available splits: ['train', 'test', 'val']

# %% [markdown]
# ## Eval 1 — DINOv2 with LoRa + LSTM (Bahdanau Attention)

# %%
from vit_lora_lstm_attn import ViTLatexModelLoRA as LSTMModel

# Tokenizer + special token indices
with open(ARTIFACTS / "lstm_tokenizer.pkl", "rb") as f:
    lstm_tok = pickle.load(f)
VOCAB_SIZE = 66

LSTM_START = VOCAB_SIZE - 2
LSTM_END = VOCAB_SIZE - 1
lstm_inv_vocab = {v: k for k, v in lstm_tok.word_index.items()}
print(f"vocab_size={VOCAB_SIZE}, START={LSTM_START}, END={LSTM_END}")

def lstm_decode(seq):
    return "".join(lstm_inv_vocab.get(t, "") for t in seq
                   if t not in (0, LSTM_START, LSTM_END))

# Load model
lstm_model = LSTMModel(vocab_size=VOCAB_SIZE, lora_r=16).to(DEVICE)
ckpt = torch.load(ARTIFACTS / "lstm.pt", map_location=DEVICE, weights_only=False)
lstm_model.load_state_dict(ckpt["model"])
lstm_model.eval()
print("LSTM model loaded.")

# Preprocess: RGB 224x224, /255, ImageNet norm (matches training)
MEAN = torch.tensor([0.485, 0.456, 0.406], device=DEVICE).view(1, 3, 1, 1)
STD  = torch.tensor([0.229, 0.224, 0.225], device=DEVICE).view(1, 3, 1, 1)

lstm_images = []
for s in ds_test:
    img = np.array(s["image"].convert("RGB").resize((224, 224)), dtype=np.uint8)
    lstm_images.append(img)
lstm_images = torch.from_numpy(np.array(lstm_images)).permute(0, 3, 1, 2)  # uint8 (N,3,224,224)
print(f"Preprocessed {N} images.")
# Out:
# vocab_size=66, START=64, END=65
# LSTM model loaded.
# Preprocessed 100 images.

# %%
exact = 0
total_ed = 0.0
print(f"Evaluating LSTM on {N} test samples...")
print("-" * 60)

for i in range(N):
    img = lstm_images[i:i+1].to(DEVICE, dtype=torch.float32) / 255.0
    img = (img - MEAN) / STD
    pred_tokens  = lstm_model.generate(img, max_len=150, sos_idx=LSTM_START, eos_idx=LSTM_END)
    prediction   = lstm_decode(pred_tokens)
    ground_truth = gt_latex[i]

    is_exact  = prediction == ground_truth
    edit_dist = normalized_edit_distance(prediction, ground_truth)
    if is_exact: exact += 1
    total_ed += edit_dist

    status = "EXACT" if is_exact else f"edit_dist={edit_dist:.4f}"
    print(f"  [{i+1:2d}/{N}] {status}")
    print(f"    GT:   {ground_truth[:80]}")
    print(f"    PRED: {prediction[:80]}")
    print("-" * 40)

print("=" * 60)
print("LSTM results")
print(f"Exact match: {exact/N:.2%} ({exact}/{N})")
print(f"Avg normalized edit: {total_ed/N:.4f}")
# Out:
# Evaluating LSTM on 100 test samples...
# ------------------------------------------------------------
#   [ 1/100] edit_dist=0.0270
#     GT:   \frac{\partial\psi}{\partial t}=P\psi
#     PRED: \frac{\partial\psi}{\partial t}=p\psi
# ----------------------------------------
#   [ 2/100] edit_dist=0.4706
#     GT:   C_{0}=D/V_{blood}
#     PRED: c_{0}=d/v_{66662}
# ----------------------------------------
#   [ 3/100] edit_dist=0.5333
#     GT:   e^{2}/\hbar c\approx1/137
#     PRED: e^{2}/\hbar \tilde{\sigma}|/33
# ----------------------------------------
#   [ 4/100] edit_dist=0.7727
#     GT:   nassoc(S,\overline{S})
#     PRED: na9500c(s,s)
# ----------------------------------------
#   [ 5/100] edit_dist=0.5161
#     GT:   Eq.1\frac{dV}{dx}=w
#     PRED: e_{q}\cdot1\frac{dv}{dx}=\omega
# ----------------------------------------
#   [ 6/100] EXACT
#     GT:   \underline{r}
#     PRED: \underline{r}
# ----------------------------------------
#   [ 7/100] edit_dist=0.1818
#     GT:   \hat{K}_{G}
#     PRED: \hat{k}_{g}
# ----------------------------------------
#   [ 8/100] edit_dist=0.1304
#     GT:   \int_{0}^{1}f(r)g(r)rdr
#     PRED: \int_{0}^{7}f(r)g(t)dr
# ----------------------------------------
#   [ 9/100] edit_dist=0.3030
#     GT:   \sigma_{b}=P\cdot\hat{n}_{out}
#     PRED: \sigma_{b}=p\dilta\hat{n}_{spha}f
# ----------------------------------------
#   [10/100] edit_dist=0.3265
#     GT:   W_{i}^{*}=\frac{Rgq_{bi}}{F_{i}u*^{3}}
#     PRED: w_{i}^{*}=\frac{r_{gq}_{it}}{r_{i}u^{*}\beta^{3}}
# ----------------------------------------
#   [11/100] EXACT
#     GT:   z\rightarrow-z^{5}+z_{0}
#     PRED: z\rightarrow-z^{5}+z_{0}
# ----------------------------------------
#   [12/100] edit_dist=0.5000
#     GT:   1/(d_{i}d_{j})^{1/2}
#     PRED: l/(\partial_{i}\partial_{j})^{1/2}
# ----------------------------------------
#   [13/100] EXACT
#     GT:   t_{r}^{\prime}=t-\frac{1}{c}|r-r^{\prime}|
#     PRED: t_{r}^{\prime}=t-\frac{1}{c}|r-r^{\prime}|
# ----------------------------------------
#   [14/100] edit_dist=0.2432
#     GT:   \frac{\partial h}{\partial z_{j}^{-}}
#     PRED: \frac{\partial n}{\partial z}
# ----------------------------------------
#   [15/100] edit_dist=0.1765
#     GT:   {j^{\lambda}}^{y}
#     PRED: {j^{\lambda}y}
# ----------------------------------------
#   [16/100] edit_dist=0.1290
#     GT:   R_{i}\rightarrow R=\prod R_{i}
#     PRED: r_{i}\rightarrow h=\prod r_{ik}
# ----------------------------------------
#   [17/100] EXACT
#     GT:   \int_{0}^{1}\phi(p)dp=1
#     PRED: \int_{0}^{1}\phi(p)dp=1
# ----------------------------------------
#   [18/100] edit_dist=0.3636
#     GT:   H(x)=1_{(0,\infty)}(x)
#     PRED: h(x)=l_{(0,00)}(x)
# ----------------------------------------
#   [19/100] EXACT
#     GT:   \tilde{x}_{0}
#     PRED: \tilde{x}_{0}
# ----------------------------------------
#   [20/100] EXACT
#     GT:   \sqrt{n}/ln(\sqrt{n})
#     PRED: \sqrt{n}/ln(\sqrt{n})
# ----------------------------------------
#   [21/100] edit_dist=0.3889
#     GT:   a^{\prime}=\lambda_{1}a+\lambda_{2}b
#     PRED: a^{\prime}=\lambda,\hbar+1,b
# ----------------------------------------
#   [22/100] EXACT
#     GT:   \lambda=\mu_{1}^{2}+\cdot\cdot\cdot+\mu_{k}^{2}
#     PRED: \lambda=\mu_{1}^{2}+\cdot\cdot\cdot+\mu_{k}^{2}
# ----------------------------------------
#   [23/100] edit_dist=0.1053
#     GT:   \int_{0}^{t}Z_{s}ds
#     PRED: \int_{0}^{z}z_{s}ds
# ----------------------------------------
#   [24/100] edit_dist=0.5909
#     GT:   D_{X}(p+tA)=0
#     PRED: d_{x}(p+\frac{1}{a})=0
# ----------------------------------------
#   [25/100] edit_dist=0.2353
#     GT:   \Delta T=\dot{Q}R
#     PRED: \delta t=\dot{q}r
# ----------------------------------------
#   [26/100] edit_dist=0.2500
#     GT:   H_{1}(G;Z)=0
#     PRED: h_{1}(g;z)=0
# ----------------------------------------
#   [27/100] edit_dist=0.5294
#     GT:   \prod_{i=0}^{k-1}(x-i)^{n}
#     PRED: \frac{\frac{k-1}{4}}{i=0}(x-i)^{n}
# ----------------------------------------
#   [28/100] edit_dist=0.0278
#     GT:   V(r)=\frac{1}{2}m_{0}\omega^{2}r^{2}
#     PRED: v(r)=\frac{1}{2}m_{0}\omega^{2}r^{2}
# ----------------------------------------
#   [29/100] edit_dist=0.4000
#     GT:   Z_{L}=R_{L}(\omega)+jX_{L}(\omega)
#     PRED: b_{2}=r_{2}(\omega)+\lambda t_{z}(\omega_{z})
# ----------------------------------------
#   [30/100] edit_dist=0.0556
#     GT:   \partial_{t}L=\frac{1}{2}\nabla^{2}L
#     PRED: \partial_{t}l=\frac{1}{2}\nabla^{2}l
# ----------------------------------------
#   [31/100] EXACT
#     GT:   \hat{r}\cdot\hat{e}_{3}
#     PRED: \hat{r}\cdot\hat{e}_{3}
# ----------------------------------------
#   [32/100] edit_dist=0.1304
#     GT:   c_{1},c_{2},...\in k
#     PRED: c_{1},c_{2},...\notin k
# ----------------------------------------
#   [33/100] edit_dist=0.0769
#     GT:   \overline{op_{1}}^{\prime}
#     PRED: \overline{q_{1}}^{\prime}
# ----------------------------------------
#   [34/100] edit_dist=0.1000
#     GT:   A=(a_{ij})
#     PRED: a=(a_{ij})
# ----------------------------------------
#   [35/100] EXACT
#     GT:   \varphi\vdash\neg\psi
#     PRED: \varphi\vdash\neg\psi
# ----------------------------------------
#   [36/100] EXACT
#     GT:   \sqrt{n}/ln(\sqrt{n})
#     PRED: \sqrt{n}/ln(\sqrt{n})
# ----------------------------------------
#   [37/100] edit_dist=0.1154
#     GT:   A=\{A_{ij}\}_{i,j=0}^{p-1}
#     PRED: a=\{a_{ij}\}_{i,j=0}^{p-x}
# ----------------------------------------
#   [38/100] edit_dist=0.0476
#     GT:   C=\frac{6000}{200-2x}
#     PRED: c=\frac{6000}{200-2x}
# ----------------------------------------
#   [39/100] edit_dist=0.0714
#     GT:   \frac{\partial W}{\partial t}=F_{E}\cdot v
#     PRED: \frac{\partial w}{\partial t}=f_{e}\cdot v
# ----------------------------------------
#   [40/100] edit_dist=0.0244
#     GT:   A=(\begin{matrix}1&-2\\ 1&-1\end{matrix})
#     PRED: a=(\begin{matrix}1&-2\\ 1&-1\end{matrix})
# ----------------------------------------
#   [41/100] EXACT
#     GT:   (\begin{matrix}4\\ 2\end{matrix})
#     PRED: (\begin{matrix}4\\ 2\end{matrix})
# ----------------------------------------
#   [42/100] EXACT
#     GT:   \frac{x}{2\pi}=\frac{y}{2\pi r}=
#     PRED: \frac{x}{2\pi}=\frac{y}{2\pi r}=
# ----------------------------------------
#   [43/100] edit_dist=0.0476
#     GT:   F(r)=-\frac{k}{r^{3}}
#     PRED: f(r)=-\frac{k}{r^{3}}
# ----------------------------------------
#   [44/100] EXACT
#     GT:   \lambda_{2}=3-\sqrt{5}
#     PRED: \lambda_{2}=3-\sqrt{5}
# ----------------------------------------
#   [45/100] edit_dist=0.1111
#     GT:   \tilde{Q}
#     PRED: \tilde{q}
# ----------------------------------------
#   [46/100] edit_dist=0.4667
#     GT:   GH^{\top}=P-P=0
#     PRED: gh^{t}=p-p=0
# ----------------------------------------
#   [47/100] EXACT
#     GT:   -s
#     PRED: -s
# ----------------------------------------
#   [48/100] EXACT
#     GT:   \sqrt{-7}
#     PRED: \sqrt{-7}
# ----------------------------------------
#   [49/100] EXACT
#     GT:   x=y=\frac{i}{\sqrt{2}}
#     PRED: x=y=\frac{i}{\sqrt{2}}
# ----------------------------------------
#   [50/100] EXACT
#     GT:   \frac{\partial u}{\partial t}=0
#     PRED: \frac{\partial u}{\partial t}=0
# ----------------------------------------
#   [51/100] edit_dist=0.2759
#     GT:   G=\int_{0}^{T}k(t)x(t)dt
#     PRED: g=\int_{0}^{t}k(t)\times(t)dt
# ----------------------------------------
#   [52/100] edit_dist=0.0263
#     GT:   (\begin{matrix}2n-2\\ n-2\end{matrix})
#     PRED: (\begin{matrix}2k-2\\ n-2\end{matrix})
# ----------------------------------------
#   [53/100] EXACT
#     GT:   tr\{\begin{matrix}4\\ 3\end{matrix}\}
#     PRED: tr\{\begin{matrix}4\\ 3\end{matrix}\}
# ----------------------------------------
#   [54/100] EXACT
#     GT:   \sqrt{-1}
#     PRED: \sqrt{-1}
# ----------------------------------------
#   [55/100] edit_dist=0.0263
#     GT:   n=(\begin{matrix}2k-1\\ k\end{matrix})
#     PRED: h=(\begin{matrix}2k-1\\ k\end{matrix})
# ----------------------------------------
#   [56/100] edit_dist=0.4643
#     GT:   E^{2}=p\cdot p+{m_{0}}^{2}
#     PRED: e^{2}=\rho\rho\rho+m_{0}^{2}
# ----------------------------------------
#   [57/100] EXACT
#     GT:   \sqrt{i}
#     PRED: \sqrt{i}
# ----------------------------------------
#   [58/100] edit_dist=0.6842
#     GT:   I_{F}(f)
#     PRED: i_{\overline{k}}(f)
# ----------------------------------------
#   [59/100] edit_dist=0.3824
#     GT:   \dot{\varphi}^{2}+\dot{\psi}^{2}=1
#     PRED: \dot{e}^{2}+\psi^{2}=1
# ----------------------------------------
#   [60/100] edit_dist=0.3500
#     GT:   \hat{t},\hat{\omega}
#     PRED: \hat{h},\hat{w}
# ----------------------------------------
#   [61/100] EXACT
#     GT:   f(x)=|x|^{k+1}
#     PRED: f(x)=|x|^{k+1}
# ----------------------------------------
#   [62/100] EXACT
#     GT:   (\begin{matrix}m\\ n\end{matrix})
#     PRED: (\begin{matrix}m\\ n\end{matrix})
# ----------------------------------------
#   [63/100] edit_dist=0.1212
#     GT:   [a_{j},a_{k}^{*}]=\delta_{j,k}
#     PRED: [a_{j},a_{k}^{*}]=\delta_{jk^{k}}
# ----------------------------------------
#   [64/100] edit_dist=0.3077
#     GT:   f(g^{a}h^{c},g^{b}h^{d},\tau)
#     PRED: f(g^{a}h^{\sigma},g^{b}h^{\alpha},\tau)
# ----------------------------------------
#   [65/100] EXACT
#     GT:   \{\tilde{e}_{k}\}
#     PRED: \{\tilde{e}_{k}\}
# ----------------------------------------
#   [66/100] EXACT
#     GT:   (2^{r}+1)|(2^{k}+1)
#     PRED: (2^{r}+1)|(2^{k}+1)
# ----------------------------------------
#   [67/100] edit_dist=0.1163
#     GT:   \rho^{\prime\prime}=\sum_{n}P_{n}\rho P_{n}
#     PRED: \rho^{\prime\prime}=\sum_{n}p_{n}\rho^{p}
# ----------------------------------------
#   [68/100] EXACT
#     GT:   \int_{a}^{b}f(x)dx
#     PRED: \int_{a}^{b}f(x)dx
# ----------------------------------------
#   [69/100] edit_dist=0.1000
#     GT:   \mathbb{O}
#     PRED: \mathbb{o}
# ----------------------------------------
#   [70/100] edit_dist=0.0769
#     GT:   R^{(3)}=h^{ij}R_{ij}^{(3)}
#     PRED: r^{(3)}=h^{ij}r_{ij}^{(3)}
# ----------------------------------------
#   [71/100] edit_dist=0.1111
#     GT:   E_{c}=\frac{V_{m}}{E_{m}}+\frac{V_{f}}{E_{f}}
#     PRED: e_{c}=\frac{v_{m}}{e_{m}}+\frac{v_{f}}{f_{f}}
# ----------------------------------------
#   [72/100] edit_dist=0.0282
#     GT:   (\begin{matrix}m-1\\ k-1\end{matrix})/(\begin{matrix}N\\ k\end{matrix})
#     PRED: (\begin{matrix}m&1\\ k-1\end{matrix})/(\begin{matrix}n\\ k\end{matrix})
# ----------------------------------------
#   [73/100] edit_dist=0.2540
#     GT:   Ra_{x}^{*}=\frac{g\beta q_{o}^{\prime\prime}}{\nu\alpha k}x^{4}
#     PRED: ra_{x}^{*}=\frac{g\rho_{q_{0}}^{\prime\prime}}{v\propto k}x^{4}
# ----------------------------------------
#   [74/100] EXACT
#     GT:   \hat{f}(t)
#     PRED: \hat{f}(t)
# ----------------------------------------
#   [75/100] edit_dist=0.1042
#     GT:   y=\frac{1}{2}laea_{y}(\frac{\lambda}{2},\varphi)
#     PRED: y=\frac{1}{2}caea,(\frac{\lambda}{2},\varphi)
# ----------------------------------------
#   [76/100] edit_dist=0.5000
#     GT:   A\Rightarrow_{amb}^{*}B
#     PRED: a\rightarrow\infty_{amb}bb
# ----------------------------------------
#   [77/100] edit_dist=0.1364
#     GT:   (-b+\sqrt{b^{2}-4c})/2
#     PRED: 1-b+\sqrt{6^{2}-4c}/2
# ----------------------------------------
#   [78/100] edit_dist=0.1579
#     GT:   (\frac{x_{i}-\overline{x}}{s_{x}})
#     PRED: (\frac{x_{i}-\overline{x}}{\zeta_{*}})
# ----------------------------------------
#   [79/100] edit_dist=0.2800
#     GT:   (b-a)e^{n(f(x_{0})-\eta)}
#     PRED: (b-a)e^{n(a(x_{n})-w)-w}
# ----------------------------------------
#   [80/100] edit_dist=0.2105
#     GT:   \gamma_{\chi}^{\mu}
#     PRED: \gamma_{x}^{\mu}
# ----------------------------------------
#   [81/100] edit_dist=0.5455
#     GT:   \frac{dy}{dx}=x+y
#     PRED: \frac{\partial y}{\partial x}=x+y
# ----------------------------------------
#   [82/100] edit_dist=0.3514
#     GT:   \sum c(S_{i})\cdot x_{i}\le B
#     PRED: \sigma\sigma(c|s_{i})\cdot x_{i}\le b
# ----------------------------------------
#   [83/100] edit_dist=1.0000
#     GT:   M
#     PRED: m
# ----------------------------------------
#   [84/100] edit_dist=0.4286
#     GT:   L=10\cdot0.5=5
#     PRED: l=10.0.5=5
# ----------------------------------------
#   [85/100] edit_dist=0.0588
#     GT:   \tilde{E}_{i}^{3}
#     PRED: \tilde{e}_{i}^{3}
# ----------------------------------------
#   [86/100] edit_dist=0.4571
#     GT:   (U_{\alpha})_{\alpha\in A_{n}}
#     PRED: (u_{\alpha})\propto\infty\inf a_{n}
# ----------------------------------------
#   [87/100] edit_dist=0.1250
#     GT:   \tilde{O}(log(n)^{10.5})
#     PRED: \tilde{o}(log(n))^{105})
# ----------------------------------------
#   [88/100] edit_dist=0.1818
#     GT:   D_{(j_{u})}
#     PRED: d_{(j_{v})}
# ----------------------------------------
#   [89/100] edit_dist=0.0769
#     GT:   \tilde{D}_{4}
#     PRED: \tilde{d}_{4}
# ----------------------------------------
#   [90/100] edit_dist=0.0588
#     GT:   e^{-\beta\hat{H}}
#     PRED: e^{-\beta\hat{h}}
# ----------------------------------------
#   [91/100] edit_dist=0.2727
#     GT:   S=\int Ldt
#     PRED: s=\int lddt
# ----------------------------------------
#   [92/100] edit_dist=0.0769
#     GT:   \sum(\overline{X}-X_{i})=0
#     PRED: \sum(\overline{x}-x_{i})=0
# ----------------------------------------
#   [93/100] edit_dist=0.0476
#     GT:   \frac{dy}{y}=-f(t)dt
#     PRED: \frac{dy}{y}=-f(it)dt
# ----------------------------------------
#   [94/100] edit_dist=0.0312
#     GT:   M=\frac{m}{\sqrt{1-v^{2}/c^{2}}}
#     PRED: m=\frac{m}{\sqrt{1-v^{2}/c^{2}}}
# ----------------------------------------
#   [95/100] EXACT
#     GT:   \frac{f_{r}}{f_{s}}=\frac{v_{r}\cdot x}{v_{s}\cdot x}
#     PRED: \frac{f_{r}}{f_{s}}=\frac{v_{r}\cdot x}{v_{s}\cdot x}
# ----------------------------------------
#   [96/100] edit_dist=0.0455
#     GT:   C_{1}:=\{z:|z|=r_{1}\}
#     PRED: c_{1}:=\{z:|z|=r_{1}\}
# ----------------------------------------
#   [97/100] edit_dist=0.6364
#     GT:   \hat{\Sigma}_{/j,/j}
#     PRED: \tilde{\sum}_{j},r_{j}
# ----------------------------------------
#   [98/100] edit_dist=0.4500
#     GT:   (A\times B)^{\sigma}
#     PRED: (a\le b)^{\gamma}
# ----------------------------------------
#   [99/100] edit_dist=0.1875
#     GT:   y=20+3\epsilon_{4}+4\epsilon_{8}
#     PRED: y=20+3\epsilon_{4}+4\xi_{8}
# ----------------------------------------
#   [100/100] edit_dist=0.0625
#     GT:   \lambda(y_{i})<C
#     PRED: \lambda(y_{i})<c
# ----------------------------------------
# ============================================================
# LSTM results
# Exact match: 27.00% (27/100)
# Avg normalized edit: 0.1826

# %% [markdown]
# ## Eval 2 — DINOv2 + Transfomer

# %%
from vit_transformer_v2 import ViTLatexModelLoRA
import numpy as np

ARTIFACTS = Path("artifacts")
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# 1. Load Vocab and Tokenizer
VOCAB_SIZE = 66

with open(ARTIFACTS / "lstm_tokenizer.pkl", "rb") as f:
    tokenizer = pickle.load(f)

inv_vocab = {v: k for k, v in tokenizer.word_index.items()}
START_TOKEN = VOCAB_SIZE - 2
END_TOKEN = VOCAB_SIZE - 1

def decode(seq):
    filtered = [t for t in seq if t not in (0, START_TOKEN, END_TOKEN)]
    return "".join(inv_vocab.get(t, "") for t in filtered)

# 2. Initialize and Load Model
model = ViTLatexModelLoRA(vocab_size=VOCAB_SIZE).to(DEVICE)
checkpoint = torch.load(ARTIFACTS / "transformer.pt", map_location=DEVICE, weights_only=False)
model.load_state_dict(checkpoint["model"])
model.eval()

print(f"Model loaded and running on {DEVICE}")

# 3. Evaluation Loop
exact_matches = 0
total_edit_dist = 0.0
N = len(ds_test)

print(f"Evaluating Transformer on {N} samples...")
print("-" * 60)

# Preprocessing constants (ImageNet Norm)
MEAN = torch.tensor([0.485, 0.456, 0.406], device=DEVICE).view(1, 3, 1, 1)
STD  = torch.tensor([0.229, 0.224, 0.225], device=DEVICE).view(1, 3, 1, 1)

for i in range(N):
    # Fetch and preprocess image directly from ds_test
    raw_img = ds_test[i]["image"].convert("RGB").resize((224, 224))
    img = torch.from_numpy(np.array(raw_img)).permute(2, 0, 1).unsqueeze(0)
    
    img = img.to(DEVICE, dtype=torch.float32) / 255.0
    img = (img - MEAN) / STD
    
    with torch.no_grad():
        pred_tokens = model.generate(img, max_len=150, sos_idx=START_TOKEN, eos_idx=END_TOKEN)
    
    prediction = decode(pred_tokens)
    ground_truth = gt_latex[i]
    
    is_exact = prediction == ground_truth
    edit_dist = normalized_edit_distance(prediction, ground_truth)
    
    if is_exact:
        exact_matches += 1
    total_edit_dist += edit_dist
    
    status = "EXACT" if is_exact else f"ED={edit_dist:.4f}"
    print(f"  [{i+1:2d}/{N}] {status}")
    print(f"    GT:   {ground_truth[:80]}")
    print(f"    PRED: {prediction[:80]}")
    print("-" * 40)

print("\n" + "=" * 60)
print("Transformer results")
print(f"Exact match: {exact_matches/N:.2%} ({exact_matches}/{N})")
print(f"Avg normalized edit: {total_edit_dist/N:.4f}")
# Out:
# Model loaded and running on cuda
# Evaluating Transformer on 100 samples...
# ------------------------------------------------------------
#   [ 1/100] ED=0.0270
#     GT:   \frac{\partial\psi}{\partial t}=P\psi
#     PRED: \frac{\partial\psi}{\partial t}=p\psi
# ----------------------------------------
#   [ 2/100] ED=0.3529
#     GT:   C_{0}=D/V_{blood}
#     PRED: c_{0}=d/v_{6log}
# ----------------------------------------
#   [ 3/100] EXACT
#     GT:   e^{2}/\hbar c\approx1/137
#     PRED: e^{2}/\hbar c\approx1/137
# ----------------------------------------
#   [ 4/100] ED=0.1304
#     GT:   nassoc(S,\overline{S})
#     PRED: nasssoc(s,\overline{s})
# ----------------------------------------
#   [ 5/100] ED=0.5161
#     GT:   Eq.1\frac{dV}{dx}=w
#     PRED: e_{q}\cdot1\frac{dv}{dx}=\omega
# ----------------------------------------
#   [ 6/100] EXACT
#     GT:   \underline{r}
#     PRED: \underline{r}
# ----------------------------------------
#   [ 7/100] ED=0.1818
#     GT:   \hat{K}_{G}
#     PRED: \hat{k}_{g}
# ----------------------------------------
#   [ 8/100] ED=0.0435
#     GT:   \int_{0}^{1}f(r)g(r)rdr
#     PRED: \int_{0}^{1}f(r)g(r)dr
# ----------------------------------------
#   [ 9/100] ED=0.1333
#     GT:   \sigma_{b}=P\cdot\hat{n}_{out}
#     PRED: \sigma_{b}=p\cdot\hat{n}_{cu}f
# ----------------------------------------
#   [10/100] ED=0.3250
#     GT:   W_{i}^{*}=\frac{Rgq_{bi}}{F_{i}u*^{3}}
#     PRED: w_{i}^{*}=\frac{rg_{c_{i}}}{1-v_{i}^{*}}
# ----------------------------------------
#   [11/100] ED=0.3333
#     GT:   z\rightarrow-z^{5}+z_{0}
#     PRED: z\mapsto-z^{5}+z_{0}
# ----------------------------------------
#   [12/100] ED=0.2963
#     GT:   1/(d_{i}d_{j})^{1/2}
#     PRED: 1/(\partial_{i}d_{j})^{1/2}
# ----------------------------------------
#   [13/100] EXACT
#     GT:   t_{r}^{\prime}=t-\frac{1}{c}|r-r^{\prime}|
#     PRED: t_{r}^{\prime}=t-\frac{1}{c}|r-r^{\prime}|
# ----------------------------------------
#   [14/100] ED=0.2973
#     GT:   \frac{\partial h}{\partial z_{j}^{-}}
#     PRED: \frac{\partial n}{\partial2\rho}
# ----------------------------------------
#   [15/100] ED=0.1765
#     GT:   {j^{\lambda}}^{y}
#     PRED: {j^{\lambda}y}
# ----------------------------------------
#   [16/100] ED=0.3667
#     GT:   R_{i}\rightarrow R=\prod R_{i}
#     PRED: r_{i}\mapsto r=\prod b_{i}
# ----------------------------------------
#   [17/100] ED=0.2903
#     GT:   \int_{0}^{1}\phi(p)dp=1
#     PRED: \int_{0}^{1}\phi(p)\partial p=1
# ----------------------------------------
#   [18/100] ED=0.0909
#     GT:   H(x)=1_{(0,\infty)}(x)
#     PRED: h(x)=l_{(0,\infty)}(x)
# ----------------------------------------
#   [19/100] EXACT
#     GT:   \tilde{x}_{0}
#     PRED: \tilde{x}_{0}
# ----------------------------------------
#   [20/100] EXACT
#     GT:   \sqrt{n}/ln(\sqrt{n})
#     PRED: \sqrt{n}/ln(\sqrt{n})
# ----------------------------------------
#   [21/100] ED=0.3333
#     GT:   a^{\prime}=\lambda_{1}a+\lambda_{2}b
#     PRED: a^{\prime}=\lambda,4+\frac{1}{2}b
# ----------------------------------------
#   [22/100] ED=0.3662
#     GT:   \lambda=\mu_{1}^{2}+\cdot\cdot\cdot+\mu_{k}^{2}
#     PRED: \lambda=\mu_{1}^{2}f\cdot\cdot\cdot\cdot\cdot\cdot\cdot\mu_{\mu_{k}^{2}
# ----------------------------------------
#   [23/100] ED=0.1053
#     GT:   \int_{0}^{t}Z_{s}ds
#     PRED: \int_{0}^{7}z_{s}ds
# ----------------------------------------
#   [24/100] ED=0.3077
#     GT:   D_{X}(p+tA)=0
#     PRED: p_{x}(p+a)=0
# ----------------------------------------
#   [25/100] ED=0.4091
#     GT:   \Delta T=\dot{Q}R
#     PRED: \delta t=\dot{q}\ot{r}
# ----------------------------------------
#   [26/100] ED=0.5833
#     GT:   H_{1}(G;Z)=0
#     PRED: h,(g;z)=0
# ----------------------------------------
#   [27/100] ED=0.5625
#     GT:   \prod_{i=0}^{k-1}(x-i)^{n}
#     PRED: \frac{k-1}{4=0}^{(x-i)^{5}})^{n}
# ----------------------------------------
#   [28/100] ED=0.0278
#     GT:   V(r)=\frac{1}{2}m_{0}\omega^{2}r^{2}
#     PRED: v(r)=\frac{1}{2}m_{0}\omega^{2}r^{2}
# ----------------------------------------
#   [29/100] ED=0.3778
#     GT:   Z_{L}=R_{L}(\omega)+jX_{L}(\omega)
#     PRED: \partial_{2}=r_{2}(\omega)+j\hbar_{2}(\omega)
# ----------------------------------------
#   [30/100] ED=0.0833
#     GT:   \partial_{t}L=\frac{1}{2}\nabla^{2}L
#     PRED: \partial_{+}l=\frac{1}{2}\nabla^{2}l
# ----------------------------------------
#   [31/100] EXACT
#     GT:   \hat{r}\cdot\hat{e}_{3}
#     PRED: \hat{r}\cdot\hat{e}_{3}
# ----------------------------------------
#   [32/100] ED=0.0500
#     GT:   c_{1},c_{2},...\in k
#     PRED: c_{1},c_{2},..\in k
# ----------------------------------------
#   [33/100] ED=0.4231
#     GT:   \overline{op_{1}}^{\prime}
#     PRED: \overline{q_{1}}
# ----------------------------------------
#   [34/100] ED=0.2000
#     GT:   A=(a_{ij})
#     PRED: a=(a_{ij}
# ----------------------------------------
#   [35/100] EXACT
#     GT:   \varphi\vdash\neg\psi
#     PRED: \varphi\vdash\neg\psi
# ----------------------------------------
#   [36/100] ED=0.0476
#     GT:   \sqrt{n}/ln(\sqrt{n})
#     PRED: \sqrt{x}/ln(\sqrt{n})
# ----------------------------------------
#   [37/100] ED=0.1154
#     GT:   A=\{A_{ij}\}_{i,j=0}^{p-1}
#     PRED: a=\{a_{ij}\}_{i,j=0}^{p-x}
# ----------------------------------------
#   [38/100] ED=0.0476
#     GT:   C=\frac{6000}{200-2x}
#     PRED: c=\frac{6000}{200-2x}
# ----------------------------------------
#   [39/100] ED=0.0714
#     GT:   \frac{\partial W}{\partial t}=F_{E}\cdot v
#     PRED: \frac{\partial w}{\partial t}=f_{e}\cdot v
# ----------------------------------------
#   [40/100] ED=0.0244
#     GT:   A=(\begin{matrix}1&-2\\ 1&-1\end{matrix})
#     PRED: a=(\begin{matrix}1&-2\\ 1&-1\end{matrix})
# ----------------------------------------
#   [41/100] EXACT
#     GT:   (\begin{matrix}4\\ 2\end{matrix})
#     PRED: (\begin{matrix}4\\ 2\end{matrix})
# ----------------------------------------
#   [42/100] EXACT
#     GT:   \frac{x}{2\pi}=\frac{y}{2\pi r}=
#     PRED: \frac{x}{2\pi}=\frac{y}{2\pi r}=
# ----------------------------------------
#   [43/100] ED=0.0476
#     GT:   F(r)=-\frac{k}{r^{3}}
#     PRED: f(r)=-\frac{k}{r^{3}}
# ----------------------------------------
#   [44/100] EXACT
#     GT:   \lambda_{2}=3-\sqrt{5}
#     PRED: \lambda_{2}=3-\sqrt{5}
# ----------------------------------------
#   [45/100] ED=0.1111
#     GT:   \tilde{Q}
#     PRED: \tilde{q}
# ----------------------------------------
#   [46/100] ED=0.5333
#     GT:   GH^{\top}=P-P=0
#     PRED: ghh^{t}=p-p=0
# ----------------------------------------
#   [47/100] EXACT
#     GT:   -s
#     PRED: -s
# ----------------------------------------
#   [48/100] EXACT
#     GT:   \sqrt{-7}
#     PRED: \sqrt{-7}
# ----------------------------------------
#   [49/100] EXACT
#     GT:   x=y=\frac{i}{\sqrt{2}}
#     PRED: x=y=\frac{i}{\sqrt{2}}
# ----------------------------------------
#   [50/100] EXACT
#     GT:   \frac{\partial u}{\partial t}=0
#     PRED: \frac{\partial u}{\partial t}=0
# ----------------------------------------
#   [51/100] ED=0.2759
#     GT:   G=\int_{0}^{T}k(t)x(t)dt
#     PRED: g=\int_{0}^{t}k(t)\times(t)dt
# ----------------------------------------
#   [52/100] EXACT
#     GT:   (\begin{matrix}2n-2\\ n-2\end{matrix})
#     PRED: (\begin{matrix}2n-2\\ n-2\end{matrix})
# ----------------------------------------
#   [53/100] EXACT
#     GT:   tr\{\begin{matrix}4\\ 3\end{matrix}\}
#     PRED: tr\{\begin{matrix}4\\ 3\end{matrix}\}
# ----------------------------------------
#   [54/100] EXACT
#     GT:   \sqrt{-1}
#     PRED: \sqrt{-1}
# ----------------------------------------
#   [55/100] ED=0.0263
#     GT:   n=(\begin{matrix}2k-1\\ k\end{matrix})
#     PRED: h=(\begin{matrix}2k-1\\ k\end{matrix})
# ----------------------------------------
#   [56/100] ED=0.1154
#     GT:   E^{2}=p\cdot p+{m_{0}}^{2}
#     PRED: e^{2}=p\cdot p+m_{0}^{2}
# ----------------------------------------
#   [57/100] EXACT
#     GT:   \sqrt{i}
#     PRED: \sqrt{i}
# ----------------------------------------
#   [58/100] ED=0.6875
#     GT:   I_{F}(f)
#     PRED: \underline{i}(f)
# ----------------------------------------
#   [59/100] EXACT
#     GT:   \dot{\varphi}^{2}+\dot{\psi}^{2}=1
#     PRED: \dot{\varphi}^{2}+\dot{\psi}^{2}=1
# ----------------------------------------
#   [60/100] ED=0.0500
#     GT:   \hat{t},\hat{\omega}
#     PRED: \hat{h},\hat{\omega}
# ----------------------------------------
#   [61/100] ED=0.0714
#     GT:   f(x)=|x|^{k+1}
#     PRED: f(x)=|x|^{k-1}
# ----------------------------------------
#   [62/100] EXACT
#     GT:   (\begin{matrix}m\\ n\end{matrix})
#     PRED: (\begin{matrix}m\\ n\end{matrix})
# ----------------------------------------
#   [63/100] EXACT
#     GT:   [a_{j},a_{k}^{*}]=\delta_{j,k}
#     PRED: [a_{j},a_{k}^{*}]=\delta_{j,k}
# ----------------------------------------
#   [64/100] ED=0.2759
#     GT:   f(g^{a}h^{c},g^{b}h^{d},\tau)
#     PRED: f(g^{a}h^{c},g^{b},t)
# ----------------------------------------
#   [65/100] EXACT
#     GT:   \{\tilde{e}_{k}\}
#     PRED: \{\tilde{e}_{k}\}
# ----------------------------------------
#   [66/100] ED=0.0526
#     GT:   (2^{r}+1)|(2^{k}+1)
#     PRED: (2^{r}+1)/(2^{k}+1)
# ----------------------------------------
#   [67/100] ED=0.2326
#     GT:   \rho^{\prime\prime}=\sum_{n}P_{n}\rho P_{n}
#     PRED: p^{\prime\prime}=\sum_{n}p_{n}\rho_{n}p_{n}
# ----------------------------------------
#   [68/100] EXACT
#     GT:   \int_{a}^{b}f(x)dx
#     PRED: \int_{a}^{b}f(x)dx
# ----------------------------------------
#   [69/100] ED=0.1000
#     GT:   \mathbb{O}
#     PRED: \mathbb{c}
# ----------------------------------------
#   [70/100] ED=0.0769
#     GT:   R^{(3)}=h^{ij}R_{ij}^{(3)}
#     PRED: r^{(3)}=h^{ij}r_{ij}^{(3)}
# ----------------------------------------
#   [71/100] ED=0.1111
#     GT:   E_{c}=\frac{V_{m}}{E_{m}}+\frac{V_{f}}{E_{f}}
#     PRED: e_{c}=\frac{v_{m}}{e_{m}}+\frac{v_{f}}{k_{f}}
# ----------------------------------------
#   [72/100] ED=0.0556
#     GT:   (\begin{matrix}m-1\\ k-1\end{matrix})/(\begin{matrix}N\\ k\end{matrix})
#     PRED: (\begin{matrix}m-1\\ k-1\end{matrix})/|\begin{matrix}n\\\ k\end{matrix}|
# ----------------------------------------
#   [73/100] ED=0.4265
#     GT:   Ra_{x}^{*}=\frac{g\beta q_{o}^{\prime\prime}}{\nu\alpha k}x^{4}
#     PRED: ra_{x}^{*}=\frac{g\beta_{a_{0}^{1}}{v\alpha_{4}^{\prime}}\alpha^{4}}
# ----------------------------------------
#   [74/100] EXACT
#     GT:   \hat{f}(t)
#     PRED: \hat{f}(t)
# ----------------------------------------
#   [75/100] ED=0.0833
#     GT:   y=\frac{1}{2}laea_{y}(\frac{\lambda}{2},\varphi)
#     PRED: y=\frac{1}{2}laeag(\frac{\lambda}{2},\varphi)
# ----------------------------------------
#   [76/100] ED=0.5652
#     GT:   A\Rightarrow_{amb}^{*}B
#     PRED: a=\rightarrow\in ambb
# ----------------------------------------
#   [77/100] ED=0.0909
#     GT:   (-b+\sqrt{b^{2}-4c})/2
#     PRED: 1-b+\sqrt{b^{2}-4c}/2
# ----------------------------------------
#   [78/100] EXACT
#     GT:   (\frac{x_{i}-\overline{x}}{s_{x}})
#     PRED: (\frac{x_{i}-\overline{x}}{s_{x}})
# ----------------------------------------
#   [79/100] ED=0.2941
#     GT:   (b-a)e^{n(f(x_{0})-\eta)}
#     PRED: (b-a)e^{n(f(x_{_{_{_{_}})})-\eta)}
# ----------------------------------------
#   [80/100] EXACT
#     GT:   \gamma_{\chi}^{\mu}
#     PRED: \gamma_{\chi}^{\mu}
# ----------------------------------------
#   [81/100] ED=0.5455
#     GT:   \frac{dy}{dx}=x+y
#     PRED: \frac{\partial y}{\partial x}=x+y
# ----------------------------------------
#   [82/100] ED=0.0690
#     GT:   \sum c(S_{i})\cdot x_{i}\le B
#     PRED: \sum c(s_{i})\cdot x_{i}\le b
# ----------------------------------------
#   [83/100] ED=1.0000
#     GT:   M
#     PRED: m
# ----------------------------------------
#   [84/100] ED=0.4286
#     GT:   L=10\cdot0.5=5
#     PRED: l=10.0.5=5
# ----------------------------------------
#   [85/100] ED=0.0588
#     GT:   \tilde{E}_{i}^{3}
#     PRED: \tilde{e}_{i}^{3}
# ----------------------------------------
#   [86/100] ED=0.0667
#     GT:   (U_{\alpha})_{\alpha\in A_{n}}
#     PRED: (u_{\alpha})_{\alpha\in a_{n}}
# ----------------------------------------
#   [87/100] ED=0.4074
#     GT:   \tilde{O}(log(n)^{10.5})
#     PRED: \tilde{o}(10,(1_{n})^{10s)}
# ----------------------------------------
#   [88/100] ED=0.1818
#     GT:   D_{(j_{u})}
#     PRED: d_{(j_{v})}
# ----------------------------------------
#   [89/100] ED=0.0769
#     GT:   \tilde{D}_{4}
#     PRED: \tilde{d}_{4}
# ----------------------------------------
#   [90/100] ED=0.0588
#     GT:   e^{-\beta\hat{H}}
#     PRED: e^{-\beta\hat{\}}
# ----------------------------------------
#   [91/100] ED=0.2000
#     GT:   S=\int Ldt
#     PRED: s=\int ldt
# ----------------------------------------
#   [92/100] ED=0.0769
#     GT:   \sum(\overline{X}-X_{i})=0
#     PRED: \sum(\overline{x}-x_{i})=0
# ----------------------------------------
#   [93/100] EXACT
#     GT:   \frac{dy}{y}=-f(t)dt
#     PRED: \frac{dy}{y}=-f(t)dt
# ----------------------------------------
#   [94/100] ED=0.0312
#     GT:   M=\frac{m}{\sqrt{1-v^{2}/c^{2}}}
#     PRED: m=\frac{m}{\sqrt{1-v^{2}/c^{2}}}
# ----------------------------------------
#   [95/100] EXACT
#     GT:   \frac{f_{r}}{f_{s}}=\frac{v_{r}\cdot x}{v_{s}\cdot x}
#     PRED: \frac{f_{r}}{f_{s}}=\frac{v_{r}\cdot x}{v_{s}\cdot x}
# ----------------------------------------
#   [96/100] ED=0.0455
#     GT:   C_{1}:=\{z:|z|=r_{1}\}
#     PRED: c_{1}:=\{z:|z|=r_{1}\}
# ----------------------------------------
#   [97/100] ED=0.3077
#     GT:   \hat{\Sigma}_{/j,/j}
#     PRED: \hat{\sigma}_{/j,\int_{j}}
# ----------------------------------------
#   [98/100] ED=0.1000
#     GT:   (A\times B)^{\sigma}
#     PRED: (a\times b)^{\sigma}
# ----------------------------------------
#   [99/100] ED=0.1875
#     GT:   y=20+3\epsilon_{4}+4\epsilon_{8}
#     PRED: y=20+3\epsilon_{4}+4\xi_{8}
# ----------------------------------------
#   [100/100] ED=0.0625
#     GT:   \lambda(y_{i})<C
#     PRED: \lambda(y_{i})<c
# ----------------------------------------
#
# ============================================================
# Transformer results
# Exact match: 28.00% (28/100)
# Avg normalized edit: 0.1589

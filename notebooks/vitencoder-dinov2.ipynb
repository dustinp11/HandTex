# %% [markdown]
# # ViT Encoder + LSTM Decoder Training
# Frozen `facebook/dinov2-base` encoder with a trainable LSTM decoder for handwritten math → LaTeX.

# %%
# !pip install -q transformers datasets
# !pip -q install peft accelerate

# %%
import numpy as np
import pickle
import random
import json
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset
from torchvision import transforms
from transformers import ViTModel
from pathlib import Path
from datasets import load_from_disk, load_dataset
from peft import LoraConfig, get_peft_model
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {DEVICE}")
# Out:
# 2026-02-18 20:50:52.935911: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1771447853.254386      55 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1771447853.342348      55 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1771447854.133412      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771447854.133476      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771447854.133479      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771447854.133482      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Using device: cuda

# %% [markdown]
# ## 1. Load & preprocess dataset

# %%
for f in sorted(Path("/kaggle/input/datasets").rglob("*")):
    print(f)

# %%
print("Loading dataset...")
ds = load_dataset("deepcopy/MathWriting-human")
num_samples = 40000
ds_train = ds["train"].select(range(num_samples))

# 2. Pre-allocate Image Array (Saves RAM by avoiding copies)
# 50,000 * 256 * 256 * 4 bytes = ~13.1 GB
print(f"Pre-allocating memory for {num_samples} images...")
images_array = np.zeros((num_samples, 256, 256), dtype=np.uint8) # Uses uint8 instead of float to save RAM
latex_strings = []

# 3. Process Images & Collect Strings
print("Processing images and LaTeX strings...")
for i in range(num_samples):
    sample = ds_train[i]
    # Convert and resize directly into the array
    img = sample["image"].convert("L").resize((256, 256))
    images_array[i] = np.array(img, dtype=np.uint8)
    latex_strings.append(sample["latex"])
    
    if (i + 1) % 5000 == 0:
        print(f"Progress: {i + 1}/{num_samples}")

# 4. Setup Tokenizer
print("Fitting tokenizer...")
tokenizer = Tokenizer(char_level=True)
tokenizer.fit_on_texts(latex_strings)

# Add special tokens
tokenizer.word_index["<START>"] = len(tokenizer.word_index) + 1
tokenizer.word_index["<END>"] = len(tokenizer.word_index) + 1
tokenizer.index_word[tokenizer.word_index["<START>"]] = "<START>"
tokenizer.index_word[tokenizer.word_index["<END>"]] = "<END>"

START_ID = tokenizer.word_index["<START>"]
END_ID   = tokenizer.word_index["<END>"]

# 5. Sequence Padding
print("Tokenizing and padding sequences...")
sequences = tokenizer.texts_to_sequences(latex_strings)
sequences = [[START_ID] + seq + [END_ID] for seq in sequences]
padded_sequences = pad_sequences(sequences, padding="post")

# 6. Save Tokenizer and Vocab Info
print("Saving metadata...")
with open("/kaggle/working/latex_tokenizer256.pkl", "wb") as f:
    pickle.dump(tokenizer, f)

vocab_size = len(tokenizer.word_index) + 1
with open("/kaggle/working/vocab_size.txt", "w") as f:
    f.write(str(vocab_size))

# 7. Convert to Tensors and Save (Disk usage check: ~13.5GB total)
print("Converting to Tensors...")
# torch.from_numpy avoids a RAM copy
images_tensor = torch.from_numpy(images_array).unsqueeze(1) 
tokens_tensor = torch.tensor(padded_sequences, dtype=torch.long)

print("Saving tensors to disk (this takes a minute)...")
torch.save(images_tensor, "/kaggle/working/images_train256.pt")
torch.save(tokens_tensor, "/kaggle/working/tokens_train256.pt")

print("Done!")
print(f"Final Vocab Size: {vocab_size}")
print(f"Image Tensor Shape: {images_tensor.shape}")
# Out:
# Loading dataset...
# README.md: 0.00B [00:00, ?B/s]
# data/train-00000-of-00003-ab0ae6b9fa4a3f(…):   0%|          | 0.00/373M [00:00<?, ?B/s]
# data/train-00001-of-00003-589d2b65116e09(…):   0%|          | 0.00/374M [00:00<?, ?B/s]
# data/train-00002-of-00003-42472859069c07(…):   0%|          | 0.00/373M [00:00<?, ?B/s]
# data/test-00000-of-00001-694f317d8b63419(…):   0%|          | 0.00/44.9M [00:00<?, ?B/s]
# data/val-00000-of-00001-184984e66f80ed7a(…):   0%|          | 0.00/81.6M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/229864 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/7644 [00:00<?, ? examples/s]
# Generating val split:   0%|          | 0/15674 [00:00<?, ? examples/s]
# Pre-allocating memory for 40000 images...
# Processing images and LaTeX strings...
# Progress: 5000/40000
# Progress: 10000/40000
# Progress: 15000/40000
# Progress: 20000/40000
# Progress: 25000/40000
# Progress: 30000/40000
# Progress: 35000/40000
# Progress: 40000/40000
# Fitting tokenizer...
# Tokenizing and padding sequences...
# Saving metadata...
# Converting to Tensors...
# Saving tensors to disk (this takes a minute)...
# Done!
# Final Vocab Size: 66
# Image Tensor Shape: torch.Size([40000, 1, 256, 256])

# %%
ds = load_dataset("deepcopy/MathWriting-human")

ds_val = ds["val"].select(range(5000))

images, sequences = [], []

def preprocess_image(img, target_size=(256, 256)):
    img = img.convert("L")  # convert to grayscale
    img = img.resize(target_size)
    img = np.array(img) / 255.0  # normalize to [0, 1]
    return img

for sample in ds_val:
    img = preprocess_image(sample["image"])
    images.append(img)
    sequences.append(sample["latex"])

images = np.array(images)
with open("/kaggle/working/latex_tokenizer256.pkl", "rb") as f:
    tokenizer = pickle.load(f)

START_ID = tokenizer.word_index["<START>"]
END_ID   = tokenizer.word_index["<END>"]

seqs = tokenizer.texts_to_sequences(sequences)
seqs = [[START_ID] + s + [END_ID] for s in seqs]

padded_sequences = pad_sequences(seqs, padding="post")
images = images[..., np.newaxis]

images_tensor = torch.tensor(images, dtype=torch.float32).permute(0, 3, 1, 2)
tokens_tensor = torch.tensor(padded_sequences, dtype=torch.long)

torch.save(images_tensor, "/kaggle/working/images_val256.pt")
torch.save(tokens_tensor, "/kaggle/working/tokens_val256.pt")
print(1)
# Out:
# 1

# %% [markdown]
# ## 2. Model definition

# %%
class Decoder(nn.Module):
    def __init__(self, vocab_size, embed_dim=256, hidden_dim=512, encoder_dim=768):
        super().__init__()
        self.embedding = nn.Embedding(vocab_size, embed_dim)
        self.lstm = nn.LSTM(embed_dim, hidden_dim, batch_first=True)
        self.fc = nn.Linear(hidden_dim, vocab_size)
        self.enc_to_h = nn.Linear(encoder_dim, hidden_dim)

    def forward(self, x, encoder_features=None, hidden_state=None):
        x = self.embedding(x)
        if hidden_state is None:
            if encoder_features is not None:
                h0 = torch.tanh(self.enc_to_h(encoder_features)).unsqueeze(0)
                c0 = torch.zeros_like(h0)
                output, hidden = self.lstm(x, (h0, c0))
            else:
                output, hidden = self.lstm(x)
        else:
            output, hidden = self.lstm(x, hidden_state)
        logits = self.fc(output)
        return logits, hidden

# %%
class BahdanauAttention(nn.Module):
    """
    Additive attention:
      score(h, e_i) = v^T tanh(W_h h + W_e e_i)
    """
    def __init__(self, hidden_dim, encoder_dim, attn_dim=None):
        super().__init__()
        if attn_dim is None:
            attn_dim = hidden_dim
        self.W_h = nn.Linear(hidden_dim, attn_dim, bias=False)
        self.W_e = nn.Linear(encoder_dim, attn_dim, bias=False)
        self.v   = nn.Linear(attn_dim, 1, bias=False)

    def forward(self, h, enc_mem, enc_mask=None):
        """
        h:        (B, H)
        enc_mem:  (B, N, D)
        enc_mask: (B, N) with 1 for valid, 0 for pad (optional)

        returns:
          context: (B, D)
          alpha:   (B, N)
        """
        # (B, 1, A) + (B, N, A) -> (B, N, A)
        energy = torch.tanh(self.W_h(h).unsqueeze(1) + self.W_e(enc_mem))
        scores = self.v(energy).squeeze(-1)  # (B, N)

        if enc_mask is not None:
            scores = scores.masked_fill(enc_mask == 0, -1e9)

        alpha = F.softmax(scores, dim=-1)    # (B, N)
        context = torch.bmm(alpha.unsqueeze(1), enc_mem).squeeze(1)  # (B, D)
        return context, alpha


class AttnDecoder(nn.Module):
    def __init__(self, vocab_size, embed_dim=256, hidden_dim=512, encoder_dim=768, dropout=0.1):
        super().__init__()
        self.embedding = nn.Embedding(vocab_size, embed_dim)
        self.attn = BahdanauAttention(hidden_dim, encoder_dim, attn_dim=hidden_dim)

        # Step-wise LSTM so we can inject attention context every timestep
        self.lstm_cell = nn.LSTMCell(embed_dim + encoder_dim, hidden_dim)

        self.fc = nn.Linear(hidden_dim, vocab_size)
        self.dropout = nn.Dropout(dropout)

        # Optional: init decoder hidden state from encoder (pooled)
        self.enc_to_h = nn.Linear(encoder_dim, hidden_dim)
        self.enc_to_c = nn.Linear(encoder_dim, hidden_dim)

    def init_hidden(self, enc_mem):
        """
        enc_mem: (B, N, D)
        """
        pooled = enc_mem.mean(dim=1)  # (B, D)
        h0 = torch.tanh(self.enc_to_h(pooled))
        c0 = torch.tanh(self.enc_to_c(pooled))
        return (h0, c0)

    def forward(self, x, enc_mem=None, hidden_state=None, enc_mask=None):
        """
        x:       (B, T) token ids (teacher forcing input sequence)
        enc_mem: (B, N, D) ViT patch tokens (memory)
        hidden_state: (h, c) each (B, H) or None

        returns:
          logits: (B, T, vocab)
          hidden: (h, c)
        """
        B, T = x.shape
        emb = self.dropout(self.embedding(x))  # (B, T, E)

        if hidden_state is None:
            if enc_mem is None:
                # fallback: start from zeros
                h = torch.zeros(B, self.lstm_cell.hidden_size, device=x.device)
                c = torch.zeros_like(h)
            else:
                h, c = self.init_hidden(enc_mem)
        else:
            h, c = hidden_state

        logits_steps = []

        for t in range(T):
            if enc_mem is not None:
                context, _ = self.attn(h, enc_mem, enc_mask=enc_mask)  # (B, D)
            else:
                # no encoder: zero context
                context = torch.zeros(B, self.enc_to_h.in_features, device=x.device)

            lstm_in = torch.cat([emb[:, t, :], context], dim=-1)  # (B, E+D)
            h, c = self.lstm_cell(lstm_in, (h, c))
            logits_steps.append(self.fc(h).unsqueeze(1))  # (B, 1, vocab)

        logits = torch.cat(logits_steps, dim=1)  # (B, T, vocab)
        return logits, (h, c)

# %%
class ViTLatexModel(nn.Module):
    def __init__(self, vocab_size, embed_dim=256, hidden_dim=512):
        super().__init__()
        from transformers import AutoModel
        self.encoder = AutoModel.from_pretrained("facebook/dinov2-base")
        print(self.encoder.config.hidden_size)
        for param in self.encoder.parameters():
            param.requires_grad = False
        encoder_dim = self.encoder.config.hidden_size  # 768
        self.decoder = AttnDecoder(vocab_size, embed_dim, hidden_dim, encoder_dim)
        #self.decoder = Decoder(vocab_size, embed_dim, hidden_dim, encoder_dim)
    
    def forward(self, images, targets):
        enc = self.encoder(images).last_hidden_state  # (B, 1+N, D)
        enc_mem = enc[:, 1:, :]                       # (B, N, D)  <-- ATTENTION MEMORY

        logits, _ = self.decoder(targets, enc_mem=enc_mem)
        return logits

    
    @torch.no_grad()
    def generate(self, image, max_len=100, sos_idx=1, eos_idx=2):
        self.eval()
        enc = self.encoder(image).last_hidden_state    # (B, 1+N, D)
        enc_mem = enc[:, 1:, :]                         # (B, N, D)

        token = torch.tensor([[sos_idx]], device=image.device)
        output_tokens = []
        hidden = None

        for _ in range(max_len):
            logits, hidden = self.decoder(token, enc_mem=enc_mem, hidden_state=hidden)
            next_token = logits[:, -1, :].argmax(dim=-1, keepdim=True)

            if next_token.item() == eos_idx:
                break

            output_tokens.append(next_token.item())
            token = next_token

        return output_tokens
        
        # self.eval()
        # encoder_out = self.encoder(image).last_hidden_state[:, 0, :]
        # token = torch.tensor([[sos_idx]], device=image.device)
        # output_tokens = []
        # hidden = None
        # for i in range(max_len):
        #     if i == 0:
        #         logits, hidden = self.decoder(token, encoder_features=encoder_out)
        #     else:
        #         logits, hidden = self.decoder(token, hidden_state=hidden)
        #     next_token = logits[:, -1, :].argmax(dim=-1, keepdim=True)
        #     if next_token.item() == eos_idx:
        #         break
        #     output_tokens.append(next_token.item())
        #     token = next_token
        # return output_tokens

# %%
def list_linear_suffixes(model):
    suffixes = set()
    examples = []
    for name, mod in model.named_modules():
        if isinstance(mod, nn.Linear):
            suf = name.split(".")[-1]
            suffixes.add(suf)
            if len(examples) < 30:
                examples.append(name)
    print("Unique Linear suffixes:", sorted(suffixes))
    print("\nExample Linear module names:")
    for e in examples:
        print("  ", e)

# %%
class ViTLatexModelLoRA(nn.Module):
    def __init__(self, vocab_size, embed_dim=256, hidden_dim=512, lora_r=16, lora_alpha=32, lora_dropout=0.05):
        super().__init__()
        from transformers import AutoModel
        self.encoder = AutoModel.from_pretrained("facebook/dinov2-base")

        # IMPORTANT: do NOT freeze everything after LoRA; LoRA will keep base frozen + adapters trainable.
        # (Freezing before LoRA is fine, but not necessary.)

        # Choose target modules after you inspect names.
        # Start with common ViT block names:
        target_modules = ["query", "key", "value", "dense", "fc1", "fc2"]
        
        lora_cfg = LoraConfig(
            r=lora_r,
            lora_alpha=lora_alpha,
            lora_dropout=lora_dropout,
            bias="none",
            target_modules=target_modules,
            task_type="FEATURE_EXTRACTION",  # safe default for encoder-only usage
        )
        self.encoder = get_peft_model(self.encoder, lora_cfg)

        encoder_dim = self.encoder.config.hidden_size  # 768
        self.decoder = AttnDecoder(vocab_size, embed_dim, hidden_dim, encoder_dim)

    def forward(self, images, input_tokens):
        enc = self.encoder(pixel_values=images).last_hidden_state
        enc_mem = enc[:, 1:, :]  # (B, N, D)
        logits, _ = self.decoder(input_tokens, enc_mem=enc_mem)
        return logits

    @torch.no_grad()
    def generate(self, image, max_len=150, sos_idx=1, eos_idx=2):
        self.eval()

        # image: (1, 3, H, W) already normalized in your eval loop
        enc = self.encoder(pixel_values=image).last_hidden_state
        enc_mem = enc[:, 1:, :]  # (1, N, D)

        token = torch.tensor([[sos_idx]], device=image.device)
        output_tokens = []
        hidden = None

        for _ in range(max_len):
            logits, hidden = self.decoder(token, enc_mem=enc_mem, hidden_state=hidden)
            next_token = logits[:, -1, :].argmax(dim=-1, keepdim=True)  # (1,1)

            if next_token.item() == eos_idx:
                break

            output_tokens.append(next_token.item())
            token = next_token

        return output_tokens

# %% [markdown]
# ## 3. Training

# %%
# Load vocab size
with open("/kaggle/working/vocab_size.txt") as f:
    VOCAB_SIZE = int(f.read().strip())

# Hyperparameters
BATCH_SIZE = 16
EPOCHS = 10
LEARNING_RATE = 1e-3

# Load pre-processed tensors (just load, don't convert yet)
images_tensor = torch.load("/kaggle/working/images_train256.pt")  # (40000, 1, 256, 256)
tokens_tensor = torch.load("/kaggle/working/tokens_train256.pt")  # (40000, seq_len)

print(f"Images: {images_tensor.shape}, Tokens: {tokens_tensor.shape}, Vocab size: {VOCAB_SIZE}")

# Create dataset and loader
dataset = TensorDataset(images_tensor, tokens_tensor)
loader = DataLoader(dataset, batch_size=BATCH_SIZE, shuffle=True)

# Initialize model
model = ViTLatexModelLoRA(vocab_size=VOCAB_SIZE).to(DEVICE)

trainable = sum(p.numel() for p in model.parameters() if p.requires_grad)
total = sum(p.numel() for p in model.parameters())
print(f"Trainable params: {trainable:,} / {total:,}")

criterion = nn.CrossEntropyLoss(ignore_index=0)
#optimizer = torch.optim.Adam(model.decoder.parameters(), lr=LEARNING_RATE)

optimizer = torch.optim.AdamW(
    [
        {"params": model.decoder.parameters(), "lr": 1e-3},
        {"params": model.encoder.parameters(), "lr": 1e-4},  # LoRA adapters
    ],
    weight_decay=0.01
)

mean = torch.tensor([0.485, 0.456, 0.406], device=DEVICE).view(1,3,1,1)
std  = torch.tensor([0.229, 0.224, 0.225], device=DEVICE).view(1,3,1,1)

# Training loop
for epoch in range(EPOCHS):
    model.train()
    total_loss = 0
    
    for batch_idx, (imgs, seqs) in enumerate(loader):
        # Convert grayscale to RGB
        imgs = imgs.float() / 255.0
        imgs = imgs.repeat(1, 3, 1, 1).to(DEVICE)  # (B, 1, 256, 256) -> (B, 3, 256, 256)
        imgs = (imgs - mean) / std
        
        seqs = seqs.to(DEVICE)
        
        # Teacher forcing
        input_tokens = seqs[:, :-1]   # (B, seq_len-1)
        target_tokens = seqs[:, 1:]   # (B, seq_len-1)
        
        optimizer.zero_grad()
        
        # Forward pass
        logits = model(imgs, input_tokens)  # (B, seq_len-1, vocab_size)
        
        # Compute loss
        loss = criterion(
            logits.reshape(-1, VOCAB_SIZE),  # (B * (seq_len-1), vocab_size)
            target_tokens.reshape(-1)         # (B * (seq_len-1))
        )
        
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
        
        optimizer.step()
        
        total_loss += loss.item()
        
        # Print every 100 batches
        if batch_idx % 100 == 0:
            print(f"  Batch {batch_idx}/{len(loader)} | Loss: {loss.item():.4f}")
    
    print(f"Epoch {epoch + 1}/{EPOCHS} | Avg Loss: {total_loss / len(loader):.4f}")

# Save model
#SAVE_PATH = "/kaggle/working/dinov2_model256.pt"
SAVE_PATH = "/kaggle/working/dinov2_attn_lora256.pt"
torch.save({
    "model": model.state_dict()
}, SAVE_PATH)

print(f"Model saved to {SAVE_PATH}")

# %% [markdown]
# ## 4. Evals

# %%
def normalized_edit_distance(s1, s2):
    if len(s1) == 0 and len(s2) == 0:
        return 0.0
    if len(s1) == 0 or len(s2) == 0:
        return 1.0
    
    # Levenshtein distance
    d = [[0] * (len(s2) + 1) for _ in range(len(s1) + 1)]
    for i in range(len(s1) + 1):
        d[i][0] = i
    for j in range(len(s2) + 1):
        d[0][j] = j
    
    for i in range(1, len(s1) + 1):
        for j in range(1, len(s2) + 1):
            cost = 0 if s1[i-1] == s2[j-1] else 1
            d[i][j] = min(d[i-1][j] + 1, d[i][j-1] + 1, d[i-1][j-1] + cost)
    
    return d[len(s1)][len(s2)] / max(len(s1), len(s2))

# %%
import torch
from pickle import load

DATA = "/kaggle/input/datasets/ronaldtran/run1-output"

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

with open(f"/kaggle/working/vocab_size.txt") as f:
    VOCAB_SIZE = int(f.read().strip())

START_TOKEN = VOCAB_SIZE - 2
END_TOKEN = VOCAB_SIZE - 1
MAX_LEN = 150

# Load model
model = ViTLatexModelLoRA(vocab_size=VOCAB_SIZE).to(DEVICE)
checkpoint = torch.load(f"{DATA}/dinov2_attn_lora256.pt", map_location=DEVICE)
model.load_state_dict(checkpoint["model"])
model.eval()

# Load validation data
images = torch.load(f"/kaggle/working/images_val256.pt")
tokens = torch.load(f"/kaggle/working/tokens_val256.pt")

with open(f"/kaggle/working/latex_tokenizer256.pkl", "rb") as f:
    tokenizer = load(f)

inv_vocab = {v: k for k, v in tokenizer.word_index.items()}

def decode(seq):
    # Filter out start and end tokens
    filtered = [t for t in seq if t != START_TOKEN and t != END_TOKEN and t != 0]
    return "".join(inv_vocab.get(t, "") for t in filtered)

# Inference
N = 500
exact_matches = 0
total_edit_dist = 0.0

print(f"Evaluating on {N} test samples...")
print("-" * 60)

for i in range(N):
    img = images[i:i+1]  # (1, 1, 256, 256)
    img = img.repeat(1, 3, 1, 1).to(DEVICE)  # (1, 3, 256, 256)
    gt_tokens = tokens[i]
    
    pred_tokens = model.generate(img, max_len=MAX_LEN, sos_idx=START_TOKEN, eos_idx=END_TOKEN)
    
    ground_truth = decode(gt_tokens.tolist())
    prediction = decode(pred_tokens)
    
    is_exact = prediction == ground_truth
    edit_dist = normalized_edit_distance(prediction, ground_truth)
    
    if is_exact:
        exact_matches += 1
    total_edit_dist += edit_dist
    
    status = "EXACT" if is_exact else f"edit_dist={edit_dist:.4f}"
    print(f"  [{i+1}/{N}] {status}")
    print(f"    GT:   {ground_truth[:80]}")
    print(f"    PRED: {prediction[:80]}")
    print("-"*40)

accuracy = exact_matches / N
avg_edit_dist = total_edit_dist / N

print("\n" + "=" * 60)
print("SUMMARY")
print("=" * 60)
print(f"Model:                    DinoV2 + LSTM")
print(f"Samples:                  {N}")
print(f"Exact match accuracy:     {accuracy:.2%} ({exact_matches}/{N})")
print(f"Avg normalized edit dist: {avg_edit_dist:.4f}")
# Out:
# config.json:   0%|          | 0.00/548 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/346M [00:00<?, ?B/s]
# Evaluating on 500 test samples...
# ------------------------------------------------------------
#   [1/500] EXACT
#     GT:   \frac{\partial\psi}{\partial t}=p\psi
#     PRED: \frac{\partial\psi}{\partial t}=p\psi
# ----------------------------------------
#   [2/500] edit_dist=0.1765
#     GT:   c_{0}=d/v_{blood}
#     PRED: c_{0}=d/v_{6log2}
# ----------------------------------------
#   [3/500] edit_dist=0.5667
#     GT:   e^{2}/\hbar c\approx1/137
#     PRED: e^{2}/\hbar \tilde{\sigma}||3|
# ----------------------------------------
#   [4/500] edit_dist=0.6364
#     GT:   nassoc(s,\overline{s})
#     PRED: nagscos(s,s)
# ----------------------------------------
#   [5/500] edit_dist=0.4839
#     GT:   eq.1\frac{dv}{dx}=w
#     PRED: e_{2}\cdot1\frac{dv}{dx}=\omega
# ----------------------------------------
#   [6/500] EXACT
#     GT:   \underline{r}
#     PRED: \underline{r}
# ----------------------------------------
#   [7/500] EXACT
#     GT:   \hat{k}_{g}
#     PRED: \hat{k}_{g}
# ----------------------------------------
#   [8/500] edit_dist=0.0870
#     GT:   \int_{0}^{1}f(r)g(r)rdr
#     PRED: \int_{0}^{7}f(r)g(r)dr
# ----------------------------------------
#   [9/500] edit_dist=0.3333
#     GT:   \sigma_{b}=p\cdot\hat{n}_{out}
#     PRED: \sigma_{b}=p\hat{n}_{stan}t
# ----------------------------------------
#   [10/500] edit_dist=0.1500
#     GT:   w_{i}^{*}=\frac{rgq_{bi}}{f_{i}u*^{3}}
#     PRED: w_{i}^{*}=\frac{r_{gq_{it}}}{f_{i}u^{3}}
# ----------------------------------------
#   [11/500] EXACT
#     GT:   z\rightarrow-z^{5}+z_{0}
#     PRED: z\rightarrow-z^{5}+z_{0}
# ----------------------------------------
#   [12/500] edit_dist=0.5000
#     GT:   1/(d_{i}d_{j})^{1/2}
#     PRED: l/(\partial_{i}\partial_{j})^{1/2}
# ----------------------------------------
#   [13/500] edit_dist=0.2619
#     GT:   t_{r}^{\prime}=t-\frac{1}{c}|r-r^{\prime}|
#     PRED: \hat{t}_{r}=t-\frac{1}{c}|r-r^{\prime}|
# ----------------------------------------
#   [14/500] edit_dist=0.2432
#     GT:   \frac{\partial h}{\partial z_{j}^{-}}
#     PRED: \frac{\partial n}{\partial z\rho}
# ----------------------------------------
#   [15/500] EXACT
#     GT:   {j^{\lambda}}^{y}
#     PRED: {j^{\lambda}}^{y}
# ----------------------------------------
#   [16/500] edit_dist=0.0645
#     GT:   r_{i}\rightarrow r=\prod r_{i}
#     PRED: r_{i}\rightarrow r=\prod b_{ik}
# ----------------------------------------
#   [17/500] EXACT
#     GT:   \int_{0}^{1}\phi(p)dp=1
#     PRED: \int_{0}^{1}\phi(p)dp=1
# ----------------------------------------
#   [18/500] edit_dist=0.0455
#     GT:   h(x)=1_{(0,\infty)}(x)
#     PRED: h(x)=l_{(0,\infty)}(x)
# ----------------------------------------
#   [19/500] EXACT
#     GT:   \tilde{x}_{0}
#     PRED: \tilde{x}_{0}
# ----------------------------------------
#   [20/500] EXACT
#     GT:   \sqrt{n}/ln(\sqrt{n})
#     PRED: \sqrt{n}/ln(\sqrt{n})
# ----------------------------------------
#   [21/500] edit_dist=0.3243
#     GT:   a^{\prime}=\lambda_{1}a+\lambda_{2}b
#     PRED: a^{\prime}=\lambda,\hbar+\frac{1}{2}b
# ----------------------------------------
#   [22/500] edit_dist=0.1277
#     GT:   \lambda=\mu_{1}^{2}+\cdot\cdot\cdot+\mu_{k}^{2}
#     PRED: \lambda=\mu_{1}^{2}+\cdot\cdot\mu_{k}^{2}
# ----------------------------------------
#   [23/500] edit_dist=0.0526
#     GT:   \int_{0}^{t}z_{s}ds
#     PRED: \int_{0}^{z}z_{s}ds
# ----------------------------------------
#   [24/500] edit_dist=0.0769
#     GT:   d_{x}(p+ta)=0
#     PRED: p_{x}(p+ta)=0
# ----------------------------------------
#   [25/500] edit_dist=0.2917
#     GT:   \delta t=\dot{q}r
#     PRED: \delta t=\dot{q}\sqrt{r}
# ----------------------------------------
#   [26/500] EXACT
#     GT:   h_{1}(g;z)=0
#     PRED: h_{1}(g;z)=0
# ----------------------------------------
#   [27/500] edit_dist=0.3000
#     GT:   \prod_{i=0}^{k-1}(x-i)^{n}
#     PRED: \frac{k-1}{i=0}^{4-1}(x-i)^{n}
# ----------------------------------------
#   [28/500] edit_dist=0.2222
#     GT:   v(r)=\frac{1}{2}m_{0}\omega^{2}r^{2}
#     PRED: v(r)=\frac{1}{2}mowe^{2}r^{2}
# ----------------------------------------
#   [29/500] edit_dist=0.2927
#     GT:   z_{l}=r_{l}(\omega)+jx_{l}(\omega)
#     PRED: b_{2}=r_{2}(\omega)+j\tau_{z}(\omega_{z})
# ----------------------------------------
#   [30/500] EXACT
#     GT:   \partial_{t}l=\frac{1}{2}\nabla^{2}l
#     PRED: \partial_{t}l=\frac{1}{2}\nabla^{2}l
# ----------------------------------------
#   [31/500] EXACT
#     GT:   \hat{r}\cdot\hat{e}_{3}
#     PRED: \hat{r}\cdot\hat{e}_{3}
# ----------------------------------------
#   [32/500] edit_dist=0.2000
#     GT:   c_{1},c_{2},...\in k
#     PRED: c_{1},c_{2},...k
# ----------------------------------------
#   [33/500] edit_dist=0.0769
#     GT:   \overline{op_{1}}^{\prime}
#     PRED: \overline{q_{1}}^{\prime}
# ----------------------------------------
#   [34/500] EXACT
#     GT:   a=(a_{ij})
#     PRED: a=(a_{ij})
# ----------------------------------------
#   [35/500] EXACT
#     GT:   \varphi\vdash\neg\psi
#     PRED: \varphi\vdash\neg\psi
# ----------------------------------------
#   [36/500] EXACT
#     GT:   \sqrt{n}/ln(\sqrt{n})
#     PRED: \sqrt{n}/ln(\sqrt{n})
# ----------------------------------------
#   [37/500] edit_dist=0.0385
#     GT:   a=\{a_{ij}\}_{i,j=0}^{p-1}
#     PRED: a=\{a_{ij}\}_{i,j=0}^{p-i}
# ----------------------------------------
#   [38/500] EXACT
#     GT:   c=\frac{6000}{200-2x}
#     PRED: c=\frac{6000}{200-2x}
# ----------------------------------------
#   [39/500] EXACT
#     GT:   \frac{\partial w}{\partial t}=f_{e}\cdot v
#     PRED: \frac{\partial w}{\partial t}=f_{e}\cdot v
# ----------------------------------------
#   [40/500] EXACT
#     GT:   a=(\begin{matrix}1&-2\\ 1&-1\end{matrix})
#     PRED: a=(\begin{matrix}1&-2\\ 1&-1\end{matrix})
# ----------------------------------------
#   [41/500] EXACT
#     GT:   (\begin{matrix}4\\ 2\end{matrix})
#     PRED: (\begin{matrix}4\\ 2\end{matrix})
# ----------------------------------------
#   [42/500] EXACT
#     GT:   \frac{x}{2\pi}=\frac{y}{2\pi r}=
#     PRED: \frac{x}{2\pi}=\frac{y}{2\pi r}=
# ----------------------------------------
#   [43/500] EXACT
#     GT:   f(r)=-\frac{k}{r^{3}}
#     PRED: f(r)=-\frac{k}{r^{3}}
# ----------------------------------------
#   [44/500] EXACT
#     GT:   \lambda_{2}=3-\sqrt{5}
#     PRED: \lambda_{2}=3-\sqrt{5}
# ----------------------------------------
#   [45/500] EXACT
#     GT:   \tilde{q}
#     PRED: \tilde{q}
# ----------------------------------------
#   [46/500] edit_dist=0.2000
#     GT:   gh^{\top}=p-p=0
#     PRED: gh^{t}=p-p=0
# ----------------------------------------
#   [47/500] EXACT
#     GT:   -s
#     PRED: -s
# ----------------------------------------
#   [48/500] EXACT
#     GT:   \sqrt{-7}
#     PRED: \sqrt{-7}
# ----------------------------------------
#   [49/500] edit_dist=0.0909
#     GT:   x=y=\frac{i}{\sqrt{2}}
#     PRED: x=x\frac{i}{\sqrt{2}}
# ----------------------------------------
#   [50/500] EXACT
#     GT:   \frac{\partial u}{\partial t}=0
#     PRED: \frac{\partial u}{\partial t}=0
# ----------------------------------------
#   [51/500] edit_dist=0.2069
#     GT:   g=\int_{0}^{t}k(t)x(t)dt
#     PRED: g=\int_{0}^{t}k(t)\times(t)dt
# ----------------------------------------
#   [52/500] edit_dist=0.0263
#     GT:   (\begin{matrix}2n-2\\ n-2\end{matrix})
#     PRED: (\begin{matrix}2&-2\\ n-2\end{matrix})
# ----------------------------------------
#   [53/500] EXACT
#     GT:   tr\{\begin{matrix}4\\ 3\end{matrix}\}
#     PRED: tr\{\begin{matrix}4\\ 3\end{matrix}\}
# ----------------------------------------
#   [54/500] EXACT
#     GT:   \sqrt{-1}
#     PRED: \sqrt{-1}
# ----------------------------------------
#   [55/500] edit_dist=0.0263
#     GT:   n=(\begin{matrix}2k-1\\ k\end{matrix})
#     PRED: h=(\begin{matrix}2k-1\\ k\end{matrix})
# ----------------------------------------
#   [56/500] edit_dist=0.4286
#     GT:   e^{2}=p\cdot p+{m_{0}}^{2}
#     PRED: e^{2}=\rho\rho\rho+m_{0}^{2}
# ----------------------------------------
#   [57/500] EXACT
#     GT:   \sqrt{i}
#     PRED: \sqrt{i}
# ----------------------------------------
#   [58/500] edit_dist=0.6500
#     GT:   i_{f}(f)
#     PRED: i_{\underline{k}}(f)
# ----------------------------------------
#   [59/500] EXACT
#     GT:   \dot{\varphi}^{2}+\dot{\psi}^{2}=1
#     PRED: \dot{\varphi}^{2}+\dot{\psi}^{2}=1
# ----------------------------------------
#   [60/500] edit_dist=0.3500
#     GT:   \hat{t},\hat{\omega}
#     PRED: \hat{h},\hat{w}
# ----------------------------------------
#   [61/500] EXACT
#     GT:   f(x)=|x|^{k+1}
#     PRED: f(x)=|x|^{k+1}
# ----------------------------------------
#   [62/500] EXACT
#     GT:   (\begin{matrix}m\\ n\end{matrix})
#     PRED: (\begin{matrix}m\\ n\end{matrix})
# ----------------------------------------
#   [63/500] edit_dist=0.0333
#     GT:   [a_{j},a_{k}^{*}]=\delta_{j,k}
#     PRED: [a_{j},a_{k}^{*}=\delta_{j,k}
# ----------------------------------------
#   [64/500] edit_dist=0.3529
#     GT:   f(g^{a}h^{c},g^{b}h^{d},\tau)
#     PRED: f(g^{a}h^{\sigma},g^{\alpha},\tau)
# ----------------------------------------
#   [65/500] EXACT
#     GT:   \{\tilde{e}_{k}\}
#     PRED: \{\tilde{e}_{k}\}
# ----------------------------------------
#   [66/500] edit_dist=0.0526
#     GT:   (2^{r}+1)|(2^{k}+1)
#     PRED: (2^{r}+1)/(2^{k}+1)
# ----------------------------------------
#   [67/500] edit_dist=0.0870
#     GT:   \rho^{\prime\prime}=\sum_{n}p_{n}\rho p_{n}
#     PRED: \rho^{\prime\prime}=\sum_{n}\rho_{n}\rho p_{n}
# ----------------------------------------
#   [68/500] EXACT
#     GT:   \int_{a}^{b}f(x)dx
#     PRED: \int_{a}^{b}f(x)dx
# ----------------------------------------
#   [69/500] edit_dist=0.1818
#     GT:   \mathbb{o}
#     PRED: \mathbb{(})
# ----------------------------------------
#   [70/500] EXACT
#     GT:   r^{(3)}=h^{ij}r_{ij}^{(3)}
#     PRED: r^{(3)}=h^{ij}r_{ij}^{(3)}
# ----------------------------------------
#   [71/500] edit_dist=0.0222
#     GT:   e_{c}=\frac{v_{m}}{e_{m}}+\frac{v_{f}}{e_{f}}
#     PRED: e_{c}=\frac{v_{m}}{e_{m}}+\frac{v_{f}}{f_{f}}
# ----------------------------------------
#   [72/500] edit_dist=0.0274
#     GT:   (\begin{matrix}m-1\\ k-1\end{matrix})/(\begin{matrix}n\\ k\end{matrix})
#     PRED: (\begin{matrix}m&1-1\\ k-1\end{matrix})/(\begin{matrix}n\\ k\end{matrix})
# ----------------------------------------
#   [73/500] edit_dist=0.1429
#     GT:   ra_{x}^{*}=\frac{g\beta q_{o}^{\prime\prime}}{\nu\alpha k}x^{4}
#     PRED: r_{x}^{*}=\frac{g\beta_{e_{0}}^{\prime\prime}}{v\alpha k}x^{4}
# ----------------------------------------
#   [74/500] EXACT
#     GT:   \hat{f}(t)
#     PRED: \hat{f}(t)
# ----------------------------------------
#   [75/500] edit_dist=0.0833
#     GT:   y=\frac{1}{2}laea_{y}(\frac{\lambda}{2},\varphi)
#     PRED: y=\frac{1}{2}laeag(\frac{\lambda}{2},\varphi)
# ----------------------------------------
#   [76/500] edit_dist=0.4000
#     GT:   a\rightarrow_{amb}^{*}b
#     PRED: a\rightarrow\infty_{amb}b
# ----------------------------------------
#   [77/500] edit_dist=0.1364
#     GT:   (-b+\sqrt{b^{2}-4c})/2
#     PRED: 1-b+\sqrt{b^{2}-4x}/2
# ----------------------------------------
#   [78/500] edit_dist=0.1316
#     GT:   (\frac{x_{i}-\overline{x}}{s_{x}})
#     PRED: (\frac{x_{i}-\overline{x}}{\zeta_{x}})
# ----------------------------------------
#   [79/500] edit_dist=0.2800
#     GT:   (b-a)e^{n(f(x_{0})-\eta)}
#     PRED: (b-a)e^{n(a(x_{n})-4}
# ----------------------------------------
#   [80/500] edit_dist=0.2105
#     GT:   \gamma_{\chi}^{\mu}
#     PRED: \gamma_{x}^{\mu}
# ----------------------------------------
#   [81/500] edit_dist=0.5455
#     GT:   \frac{dy}{dx}=x+y
#     PRED: \frac{\partial y}{\partial x}=x+y
# ----------------------------------------
#   [82/500] edit_dist=0.1212
#     GT:   \sum c(s_{i})\cdot x_{i}\le b
#     PRED: \sum e\cap(s_{i})\cdot x_{i}\le b
# ----------------------------------------
#   [83/500] EXACT
#     GT:   m
#     PRED: m
# ----------------------------------------
#   [84/500] edit_dist=0.4286
#     GT:   l=10\cdot0.5=5
#     PRED: l=10.05=5
# ----------------------------------------
#   [85/500] EXACT
#     GT:   \tilde{e}_{i}^{3}
#     PRED: \tilde{e}_{i}^{3}
# ----------------------------------------
#   [86/500] edit_dist=0.3000
#     GT:   (u_{\alpha})_{\alpha\in a_{n}}
#     PRED: (u_{\alpha})\propto\inf a_{n}
# ----------------------------------------
#   [87/500] edit_dist=0.3462
#     GT:   \tilde{o}(log(n)^{10.5})
#     PRED: \tilde{o}(logc_{n})^{los\}
# ----------------------------------------
#   [88/500] edit_dist=0.0909
#     GT:   d_{(j_{u})}
#     PRED: d_{(j_{v})}
# ----------------------------------------
#   [89/500] EXACT
#     GT:   \tilde{d}_{4}
#     PRED: \tilde{d}_{4}
# ----------------------------------------
#   [90/500] EXACT
#     GT:   e^{-\beta\hat{h}}
#     PRED: e^{-\beta\hat{h}}
# ----------------------------------------
#   [91/500] edit_dist=0.0909
#     GT:   s=\int ldt
#     PRED: s=\int lddt
# ----------------------------------------
#   [92/500] EXACT
#     GT:   \sum(\overline{x}-x_{i})=0
#     PRED: \sum(\overline{x}-x_{i})=0
# ----------------------------------------
#   [93/500] EXACT
#     GT:   \frac{dy}{y}=-f(t)dt
#     PRED: \frac{dy}{y}=-f(t)dt
# ----------------------------------------
#   [94/500] EXACT
#     GT:   m=\frac{m}{\sqrt{1-v^{2}/c^{2}}}
#     PRED: m=\frac{m}{\sqrt{1-v^{2}/c^{2}}}
# ----------------------------------------
#   [95/500] EXACT
#     GT:   \frac{f_{r}}{f_{s}}=\frac{v_{r}\cdot x}{v_{s}\cdot x}
#     PRED: \frac{f_{r}}{f_{s}}=\frac{v_{r}\cdot x}{v_{s}\cdot x}
# ----------------------------------------
#   [96/500] edit_dist=0.3913
#     GT:   c_{1}:=\{z:|z|=r_{1}\}
#     PRED: c_{1}:=\{z\cdot|z|=r,\}
# ----------------------------------------
#   [97/500] edit_dist=0.4000
#     GT:   \hat{\sigma}_{/j,/j}
#     PRED: \tilde{\sigma}_{1j},l_{j}
# ----------------------------------------
#   [98/500] edit_dist=0.3333
#     GT:   (a\times b)^{\sigma}
#     PRED: (a\leftarrow b)^{\sigma}
# ----------------------------------------
#   [99/500] edit_dist=0.3333
#     GT:   y=20+3\epsilon_{4}+4\epsilon_{8}
#     PRED: y=20+3\epsilon_{4}+4\pi2\end{matrix}
# ----------------------------------------
#   [100/500] edit_dist=0.2857
#     GT:   \lambda(y_{i})<c
#     PRED: \lambda(y_{i})<\sigma
# ----------------------------------------
#   [101/500] edit_dist=0.1190
#     GT:   |\frac{y_{1}+y_{2}}{2}-x|^{2}\ge\delta^{2}
#     PRED: 1\frac{y_{1}+y_{2}}{2}-x^{2}>\delta^{2}
# ----------------------------------------
#   [102/500] edit_dist=0.1471
#     GT:   |\overline{bl}|=\frac{\pi}{2}r
#     PRED: |\overline{bl}|=\frac{\pi}{2}\beta
# ----------------------------------------
#   [103/500] edit_dist=0.0816
#     GT:   [\begin{matrix}2&2&4\\ 3&5\\ 6&6\\ 8\end{matrix}]
#     PRED: [\begin{matrix}2&2&4\\ 3&5\\ 6&6\end{matrix}]
# ----------------------------------------
#   [104/500] EXACT
#     GT:   r=\sqrt{\frac{a}{\pi}}
#     PRED: r=\sqrt{\frac{a}{\pi}}
# ----------------------------------------
#   [105/500] edit_dist=0.5294
#     GT:   (\eta,\sigma)\in p_{1}\times\sigma
#     PRED: (\eta,b)\in p,x\sigma z
# ----------------------------------------
#   [106/500] edit_dist=0.1429
#     GT:   h_{1}(t^{2};z_{2})
#     PRED: h_{1}(\tau^{2};z_{2})
# ----------------------------------------
#   [107/500] edit_dist=0.1000
#     GT:   \mathbb{o}
#     PRED: \mathbb{d}
# ----------------------------------------
#   [108/500] EXACT
#     GT:   \tilde{g}_{33}
#     PRED: \tilde{g}_{33}
# ----------------------------------------
#   [109/500] edit_dist=0.3810
#     GT:   \int_{e}|f|<\epsilon
#     PRED: \int_{e}|f|<\in\theta
# ----------------------------------------
#   [110/500] EXACT
#     GT:   [0]=\emptyset
#     PRED: [0]=\emptyset
# ----------------------------------------
#   [111/500] EXACT
#     GT:   =\frac{1}{(1+z)^{2}}
#     PRED: =\frac{1}{(1+z)^{2}}
# ----------------------------------------
#   [112/500] EXACT
#     GT:   (\begin{matrix}n+1\\ 3\end{matrix})+1
#     PRED: (\begin{matrix}n+1\\ 3\end{matrix})+1
# ----------------------------------------
#   [113/500] EXACT
#     GT:   \{\begin{matrix}3\\ 5/2\end{matrix}\}
#     PRED: \{\begin{matrix}3\\ 5/2\end{matrix}\}
# ----------------------------------------
#   [114/500] EXACT
#     GT:   \frac{\partial^{2}z}{\partial t^{2}}
#     PRED: \frac{\partial^{2}z}{\partial t^{2}}
# ----------------------------------------
#   [115/500] edit_dist=0.1944
#     GT:   \int_{0}^{\infty}e^{ax}cosxdx
#     PRED: \int_{0}^{\infty}e^{ax}cosx\times dx
# ----------------------------------------
#   [116/500] EXACT
#     GT:   \tilde{s}_{i}
#     PRED: \tilde{s}_{i}
# ----------------------------------------
#   [117/500] edit_dist=0.0750
#     GT:   [\begin{matrix}a&b\\ c&d\\ \end{matrix}]
#     PRED: [\begin{matrix}a&b\\ c&d\end{matrix}]
# ----------------------------------------
#   [118/500] EXACT
#     GT:   (\begin{matrix}n\\ q\end{matrix})
#     PRED: (\begin{matrix}n\\ q\end{matrix})
# ----------------------------------------
#   [119/500] edit_dist=0.0588
#     GT:   y^{l}=y_{1:ymid}
#     PRED: y^{l}=y_{1:ymidi}
# ----------------------------------------
#   [120/500] EXACT
#     GT:   \tilde{y}
#     PRED: \tilde{y}
# ----------------------------------------
#   [121/500] edit_dist=0.4500
#     GT:   2^{m},2^{m},1
#     PRED: \partial^{m},z^{m},1
# ----------------------------------------
#   [122/500] edit_dist=0.1212
#     GT:   tan\theta=\frac{|v|^{2}}{|g|r}
#     PRED: tan\theta=\frac{|u|^{2}}{|g|_{r}}
# ----------------------------------------
#   [123/500] edit_dist=0.5500
#     GT:   \tilde{f}(k)
#     PRED: \overline{f}(\kappa)
# ----------------------------------------
#   [124/500] EXACT
#     GT:   \tilde{e}^{a}
#     PRED: \tilde{e}^{a}
# ----------------------------------------
#   [125/500] edit_dist=0.1667
#     GT:   e[(x-\mu_{x})^{2}]
#     PRED: e[(x-\mu x)^{2}]
# ----------------------------------------
#   [126/500] edit_dist=0.2857
#     GT:   [x_{w}y_{w}z_{w}1]^{t}
#     PRED: [x_{w}y_{w}z_{w}\prod^{\top}
# ----------------------------------------
#   [127/500] EXACT
#     GT:   x,x-20
#     PRED: x,x-20
# ----------------------------------------
#   [128/500] EXACT
#     GT:   -\sqrt{x}
#     PRED: -\sqrt{x}
# ----------------------------------------
#   [129/500] EXACT
#     GT:   \tilde{q}
#     PRED: \tilde{q}
# ----------------------------------------
#   [130/500] edit_dist=0.6250
#     GT:   \overline{r_{f}}
#     PRED: \mathbb{r}_{f}
# ----------------------------------------
#   [131/500] EXACT
#     GT:   (\begin{matrix}n+1\\ k\end{matrix})
#     PRED: (\begin{matrix}n+1\\ k\end{matrix})
# ----------------------------------------
#   [132/500] edit_dist=0.3030
#     GT:   \int_{-2}^{6}\frac{dx}{x}
#     PRED: \int_{-2}^{b}\frac{\partial x}{x}
# ----------------------------------------
#   [133/500] edit_dist=0.4762
#     GT:   e_{i}\frac{x^{i}}{i!}
#     PRED: e\frac{x^{2}}{n^{1!}}
# ----------------------------------------
#   [134/500] EXACT
#     GT:   (\begin{matrix}p\\ r\end{matrix})
#     PRED: (\begin{matrix}p\\ r\end{matrix})
# ----------------------------------------
#   [135/500] edit_dist=0.1176
#     GT:   o(kn+1.274^{k})
#     PRED: o(k/n)+1.274^{k})
# ----------------------------------------
#   [136/500] edit_dist=0.1481
#     GT:   \frac{d^{2}u}{dy^{2}}=\frac{1}{\mu}\frac{dp}{dx}
#     PRED: \frac{d^{2}u}{dy^{2}}=\frac{1}{\kappa}\frac{d_{p}}{dx}
# ----------------------------------------
#   [137/500] EXACT
#     GT:   (\begin{matrix}1&0\\ 1&-1\end{matrix})
#     PRED: (\begin{matrix}1&0\\ 1&-1\end{matrix})
# ----------------------------------------
#   [138/500] EXACT
#     GT:   o((n+r)log(n))
#     PRED: o((n+r)log(n))
# ----------------------------------------
#   [139/500] edit_dist=0.1176
#     GT:   0.5<\frac{a}{l}<2
#     PRED: 0.5\frac{a}{l}<z
# ----------------------------------------
#   [140/500] edit_dist=0.5455
#     GT:   \frac{dy}{dx}-y=x
#     PRED: \frac{\partial y}{\partial x}-y=x
# ----------------------------------------
#   [141/500] EXACT
#     GT:   \hat{e}
#     PRED: \hat{e}
# ----------------------------------------
#   [142/500] EXACT
#     GT:   f(d^{\prime},r,w^{\prime})
#     PRED: f(d^{\prime},r,w^{\prime})
# ----------------------------------------
#   [143/500] EXACT
#     GT:   c(k)=(\begin{matrix}2k\\ k\end{matrix})
#     PRED: c(k)=(\begin{matrix}2k\\ k\end{matrix})
# ----------------------------------------
#   [144/500] EXACT
#     GT:   i(\theta)=p_{i}(\theta)q_{i}(\theta)
#     PRED: i(\theta)=p_{i}(\theta)q_{i}(\theta)
# ----------------------------------------
#   [145/500] EXACT
#     GT:   (\begin{matrix}7\\ 3\end{matrix})=35
#     PRED: (\begin{matrix}7\\ 3\end{matrix})=35
# ----------------------------------------
#   [146/500] edit_dist=0.0303
#     GT:   h(r)=r^{2}\cdot loglog\frac{1}{r}
#     PRED: h(r)=r^{2}\cdot coglog\frac{1}{r}
# ----------------------------------------
#   [147/500] EXACT
#     GT:   \tilde{z}_{0}
#     PRED: \tilde{z}_{0}
# ----------------------------------------
#   [148/500] edit_dist=0.1136
#     GT:   x=[\begin{matrix}w+ix\\ y+iz\end{matrix}]
#     PRED: x=\{\begin{matrix}w+i&x\\ y+iz\end{matrix}\}
# ----------------------------------------
#   [149/500] edit_dist=0.2258
#     GT:   \overline{\omega}=exp(-i2\pi/3)
#     PRED: \overline{w}=exp(-12\pi/3)
# ----------------------------------------
#   [150/500] edit_dist=0.1111
#     GT:   \frac{\partial\rho}{\partial t}+\nabla\cdot(\rho v)=0
#     PRED: \frac{\partial\rho}{\partial t}+\nabla\cdot(\varphi)=0
# ----------------------------------------
#   [151/500] edit_dist=0.3279
#     GT:   lim_{i\rightarrow\infty}c_{i}t_{a,r_{i}\#}\mu=\nu
#     PRED: lim_{i\rightarrow\infty}c_{i\infty}c_{a_{1}}r_{i}\mu_{i}\mu=1
# ----------------------------------------
#   [152/500] edit_dist=0.2162
#     GT:   p_{avg}=\frac{1}{2}r_{a}i_{\circ}^{2}
#     PRED: p_{eky}=\frac{1}{2}r_{a}i_{0}^{2}
# ----------------------------------------
#   [153/500] EXACT
#     GT:   f(n):=n!
#     PRED: f(n):=n!
# ----------------------------------------
#   [154/500] EXACT
#     GT:   [\begin{matrix}a\\ b\\ c\end{matrix}]
#     PRED: [\begin{matrix}a\\ b\\ c\end{matrix}]
# ----------------------------------------
#   [155/500] EXACT
#     GT:   \hat{k}_{g}
#     PRED: \hat{k}_{g}
# ----------------------------------------
#   [156/500] EXACT
#     GT:   \sum_{j=0}^{n}(-1)^{j}(\begin{matrix}n\\ j\end{matrix})p(j)=0
#     PRED: \sum_{j=0}^{n}(-1)^{j}(\begin{matrix}n\\ j\end{matrix})p(j)=0
# ----------------------------------------
#   [157/500] EXACT
#     GT:   x=y=\frac{i}{\sqrt{2}}
#     PRED: x=y=\frac{i}{\sqrt{2}}
# ----------------------------------------
#   [158/500] EXACT
#     GT:   \hat{y}\in\{-1,1\}
#     PRED: \hat{y}\in\{-1,1\}
# ----------------------------------------
#   [159/500] edit_dist=0.4286
#     GT:   gf(q)^{n}
#     PRED: gf(q)^{\prime}
# ----------------------------------------
#   [160/500] EXACT
#     GT:   (\begin{matrix}a&b/2\\ b/2&c\end{matrix})
#     PRED: (\begin{matrix}a&b/2\\ b/2&c\end{matrix})
# ----------------------------------------
#   [161/500] EXACT
#     GT:   s\{\begin{matrix}5\\ 4\end{matrix}\}
#     PRED: s\{\begin{matrix}5\\ 4\end{matrix}\}
# ----------------------------------------
#   [162/500] EXACT
#     GT:   \underline{x}(t)
#     PRED: \underline{x}(t)
# ----------------------------------------
#   [163/500] edit_dist=0.6667
#     GT:   [0,
#     PRED: [0_{1}
# ----------------------------------------
#   [164/500] EXACT
#     GT:   (\begin{matrix}6\\ 2\end{matrix})(\begin{matrix}43\\ 4\end{matrix})
#     PRED: (\begin{matrix}6\\ 2\end{matrix})(\begin{matrix}43\\ 4\end{matrix})
# ----------------------------------------
#   [165/500] edit_dist=0.6000
#     GT:   j=1,2,\cdot\cdot\cdot,k-1
#     PRED: j=1,2,...,k-1
# ----------------------------------------
#   [166/500] edit_dist=0.1803
#     GT:   \overline{op_{1}}^{\prime}=\overline{op_{1}^{\prime}}
#     PRED: \overline{\sigma_{p}_{1}^{\prime}}=\overline{op_{1}^{\prime}}
# ----------------------------------------
#   [167/500] EXACT
#     GT:   s\notin t
#     PRED: s\notin t
# ----------------------------------------
#   [168/500] edit_dist=0.0526
#     GT:   0\le f(\vec{r})\le1
#     PRED: 0\lef(\vec{r})\le1
# ----------------------------------------
#   [169/500] EXACT
#     GT:   e=\sum_{n=-\infty}^{\infty}e[n]^{2}
#     PRED: e=\sum_{n=-\infty}^{\infty}e[n]^{2}
# ----------------------------------------
#   [170/500] edit_dist=0.0400
#     GT:   \int_{a}^{b}[f(x)-g(x)]dx
#     PRED: \int_{u}^{b}[f(x)-g(x)]dx
# ----------------------------------------
#   [171/500] EXACT
#     GT:   \{\hat{f}_{n}\}_{n=1}^{\infty}
#     PRED: \{\hat{f}_{n}\}_{n=1}^{\infty}
# ----------------------------------------
#   [172/500] edit_dist=0.1458
#     GT:   x\mapsto\{\langle e_{k},x\rangle\}_{k\in n}
#     PRED: x\mapsto\{\langle\{e_{k_{1}}x\rangle\}_{k\in n}}
# ----------------------------------------
#   [173/500] edit_dist=0.1250
#     GT:   \int\psi\psi^{*}dv=n_{s}
#     PRED: \int\psi\mu^{*}dv=n_{s}
# ----------------------------------------
#   [174/500] EXACT
#     GT:   \prod_{i=1}^{4}i=24
#     PRED: \prod_{i=1}^{4}i=24
# ----------------------------------------
#   [175/500] edit_dist=0.0714
#     GT:   (x,y,z,az^{4})
#     PRED: (x,y,z,z^{4})
# ----------------------------------------
#   [176/500] EXACT
#     GT:   s\{\begin{matrix}4\\ 3\end{matrix}\}
#     PRED: s\{\begin{matrix}4\\ 3\end{matrix}\}
# ----------------------------------------
#   [177/500] edit_dist=0.0588
#     GT:   r_{1}r_{3}=\frac{r_{a}r_{b}^{2}r_{c}}{r_{t}^{2}}
#     PRED: r_{1}r_{3}=\frac{r_{a}r_{b}^{2}r_{c}}{r_{\tau}^{2}}
# ----------------------------------------
#   [178/500] edit_dist=0.0357
#     GT:   \tilde{p}(x_{1},...,x_{n-1})
#     PRED: \tilde{p}(x_{n},...,x_{n-1})
# ----------------------------------------
#   [179/500] edit_dist=0.1951
#     GT:   d:\phi\mapsto\frac{1}{i}\phi^{\prime}
#     PRED: d:\phi\rightarrow\frac{1}{i}\phi^{\prime}
# ----------------------------------------
#   [180/500] EXACT
#     GT:   \prod_{k=1}^{n}f(k)
#     PRED: \prod_{k=1}^{n}f(k)
# ----------------------------------------
#   [181/500] EXACT
#     GT:   \sqrt{x}/lnx
#     PRED: \sqrt{x}/lnx
# ----------------------------------------
#   [182/500] EXACT
#     GT:   y
#     PRED: y
# ----------------------------------------
#   [183/500] EXACT
#     GT:   s_{k}=(\begin{matrix}m\\ k\end{matrix})\frac{(m-k)!}{m!}=\frac{1}{k!}
#     PRED: s_{k}=(\begin{matrix}m\\ k\end{matrix})\frac{(m-k)!}{m!}=\frac{1}{k!}
# ----------------------------------------
#   [184/500] edit_dist=0.5000
#     GT:   angle(x_{1}):=\theta
#     PRED: mrgf(x_{1}):\notin
# ----------------------------------------
#   [185/500] EXACT
#     GT:   x_{0}\in m(t_{0})
#     PRED: x_{0}\in m(t_{0})
# ----------------------------------------
#   [186/500] EXACT
#     GT:   e_{n}=\hbar\omega(n+\frac{1}{2})
#     PRED: e_{n}=\hbar\omega(n+\frac{1}{2})
# ----------------------------------------
#   [187/500] edit_dist=0.5455
#     GT:   (pf)^{\wedge}=q\hat{f}
#     PRED: (pf)^{n}=qf
# ----------------------------------------
#   [188/500] EXACT
#     GT:   \sqrt{x}
#     PRED: \sqrt{x}
# ----------------------------------------
#   [189/500] EXACT
#     GT:   \tilde{b}_{3}
#     PRED: \tilde{b}_{3}
# ----------------------------------------
#   [190/500] EXACT
#     GT:   x\notin n
#     PRED: x\notin n
# ----------------------------------------
#   [191/500] edit_dist=0.1250
#     GT:   \overline{k_{q}}
#     PRED: \overline{k}_{q}
# ----------------------------------------
#   [192/500] EXACT
#     GT:   [\begin{matrix}0&1\\ 1&0\end{matrix}]
#     PRED: [\begin{matrix}0&1\\ 1&0\end{matrix}]
# ----------------------------------------
#   [193/500] EXACT
#     GT:   (d,(\begin{matrix}d+1\\ 2\end{matrix}))
#     PRED: (d,(\begin{matrix}d+1\\ 2\end{matrix}))
# ----------------------------------------
#   [194/500] edit_dist=0.1515
#     GT:   x_{0}=\frac{s^{2}-1}{s^{2}+1}
#     PRED: x_{0}=\frac{s^{2}-1}{\zeta^{2}+1}
# ----------------------------------------
#   [195/500] EXACT
#     GT:   x=\pm\sqrt[m]{a^{n}}
#     PRED: x=\pm\sqrt[m]{a^{n}}
# ----------------------------------------
#   [196/500] edit_dist=0.0417
#     GT:   y=\frac{1}{2}laea_{y}(\frac{\lambda}{2},\varphi)
#     PRED: y=\frac{1}{2}loeq_{y}(\frac{\lambda}{2},\varphi)
# ----------------------------------------
#   [197/500] edit_dist=0.3208
#     GT:   m=(\begin{matrix}-i&i\\ exp(it)&exp(-it)\end{matrix})
#     PRED: m=(\begin{matrix}-i\\ exp(it)&i\end{matrix};exp(-it)
# ----------------------------------------
#   [198/500] EXACT
#     GT:   (\begin{matrix}0&1\\ -1&0\end{matrix})
#     PRED: (\begin{matrix}0&1\\ -1&0\end{matrix})
# ----------------------------------------
#   [199/500] EXACT
#     GT:   \frac{d\mu}{dn}
#     PRED: \frac{d\mu}{dn}
# ----------------------------------------
#   [200/500] EXACT
#     GT:   i_{2}=\int f(\theta)d^{3}x
#     PRED: i_{2}=\int f(\theta)d^{3}x
# ----------------------------------------
#   [201/500] edit_dist=0.5882
#     GT:   s\notin
#     PRED: s\notin\mathbb{n}
# ----------------------------------------
#   [202/500] EXACT
#     GT:   \hat{f}(x)
#     PRED: \hat{f}(x)
# ----------------------------------------
#   [203/500] edit_dist=0.0833
#     GT:   h(x)|x^{n}-1
#     PRED: h(x)/x^{n}-1
# ----------------------------------------
#   [204/500] edit_dist=0.4583
#     GT:   l=n_{l}-n_{\overline{l}}
#     PRED: l=n_{l}-n_{l}
# ----------------------------------------
#   [205/500] EXACT
#     GT:   z(n;t)=o(n^{2-1/t})
#     PRED: z(n;t)=o(n^{2-1/t})
# ----------------------------------------
#   [206/500] edit_dist=0.1111
#     GT:   \frac{p}{q}\cdot\pi^{2m}
#     PRED: \frac{p}{q}\pi\cdot\pi^{2m}
# ----------------------------------------
#   [207/500] EXACT
#     GT:   \int x^{k}d\mu(x)=m_{k}
#     PRED: \int x^{k}d\mu(x)=m_{k}
# ----------------------------------------
#   [208/500] EXACT
#     GT:   \int_{0}^{t}\lambda(t)dt=1
#     PRED: \int_{0}^{t}\lambda(t)dt=1
# ----------------------------------------
#   [209/500] edit_dist=0.2222
#     GT:   \delta(\omega\cdot x_{1,2})
#     PRED: \delta(\omega,x_{1,2})
# ----------------------------------------
#   [210/500] EXACT
#     GT:   \frac{dy}{dx}=0
#     PRED: \frac{dy}{dx}=0
# ----------------------------------------
#   [211/500] edit_dist=0.4400
#     GT:   t_{n}n!=n^{n-2}n!
#     PRED: t_{n}h^{\prime}=h^{n-2}n!
# ----------------------------------------
#   [212/500] edit_dist=0.3871
#     GT:   \{x_{i},x_{j}\}\notin e
#     PRED: \{x_{i},x_{j}\notin e\mathbb{e}
# ----------------------------------------
#   [213/500] edit_dist=0.0606
#     GT:   lim\frac{x}{y}=\frac{limx}{limy}
#     PRED: lim\frac{x}{y}=\frac{limx}{limax}
# ----------------------------------------
#   [214/500] edit_dist=0.0833
#     GT:   c(c^{m},c^{n\times n})=0
#     PRED: c(c^{m},c^{n\times})=0
# ----------------------------------------
#   [215/500] EXACT
#     GT:   p_{n}\#=\prod_{k=1}^{n}p_{k}
#     PRED: p_{n}\#=\prod_{k=1}^{n}p_{k}
# ----------------------------------------
#   [216/500] EXACT
#     GT:   \lambda_{1}=(\begin{matrix}0&1&0\\ 1&0&0\\ 0&0&0\end{matrix})
#     PRED: \lambda_{1}=(\begin{matrix}0&1&0\\ 1&0&0\\ 0&0&0\end{matrix})
# ----------------------------------------
#   [217/500] edit_dist=0.5789
#     GT:   h(g,u_{l})=[l:k]
#     PRED: h(g,0,2)=[l!\kappa]
# ----------------------------------------
#   [218/500] edit_dist=0.1250
#     GT:   \int\int_{x}\int_{y}^{z}
#     PRED: \iint_{x}\int_{y}^{z}
# ----------------------------------------
#   [219/500] EXACT
#     GT:   (\begin{matrix}c_{i}\\ i\end{matrix})
#     PRED: (\begin{matrix}c_{i}\\ i\end{matrix})
# ----------------------------------------
#   [220/500] EXACT
#     GT:   \sum_{i=n}^{m}\frac{(\begin{matrix}i\\ n\end{matrix})}{2^{i}}
#     PRED: \sum_{i=n}^{m}\frac{(\begin{matrix}i\\ n\end{matrix})}{2^{i}}
# ----------------------------------------
#   [221/500] edit_dist=0.2667
#     GT:   (f^{+})_{+}
#     PRED: (f_{f^{+})}_{+}
# ----------------------------------------
#   [222/500] EXACT
#     GT:   [\begin{matrix}0\\ 1\end{matrix}]
#     PRED: [\begin{matrix}0\\ 1\end{matrix}]
# ----------------------------------------
#   [223/500] EXACT
#     GT:   \hat{\nu}_{i}
#     PRED: \hat{\nu}_{i}
# ----------------------------------------
#   [224/500] edit_dist=0.2800
#     GT:   10^{-12}w/\sqrt{hz}
#     PRED: 10^{-12}////\sqrt{hl_{z}}
# ----------------------------------------
#   [225/500] EXACT
#     GT:   x_{n}=m^{n}x_{0}
#     PRED: x_{n}=m^{n}x_{0}
# ----------------------------------------
#   [226/500] EXACT
#     GT:   h(e^{i\omega})
#     PRED: h(e^{i\omega})
# ----------------------------------------
#   [227/500] edit_dist=0.0938
#     GT:   v_{y}\sqrt{v_{x}^{2}+v_{y}^{2}}
#     PRED: v_{y}\sqrt{r_{2c}^{2}+v_{y}^{2}}
# ----------------------------------------
#   [228/500] edit_dist=0.1944
#     GT:   o(|\omega|k^{2}log(1/\epsilon))
#     PRED: \theta(|\omega|e^{2}log(1/\epsilon))
# ----------------------------------------
#   [229/500] EXACT
#     GT:   \{0,1,-1\}
#     PRED: \{0,1,-1\}
# ----------------------------------------
#   [230/500] EXACT
#     GT:   e_{p}=k_{b}t
#     PRED: e_{p}=k_{b}t
# ----------------------------------------
#   [231/500] edit_dist=0.0500
#     GT:   c(1-\frac{r_{s}}{r})
#     PRED: c(l-\frac{r_{s}}{r})
# ----------------------------------------
#   [232/500] edit_dist=0.3824
#     GT:   \delta_{0}logf=-kf^{2}
#     PRED: \delta_{0}logf=-kff^{\prime\prime}
# ----------------------------------------
#   [233/500] EXACT
#     GT:   \hat{l}
#     PRED: \hat{l}
# ----------------------------------------
#   [234/500] edit_dist=0.3333
#     GT:   p^{-1}fp
#     PRED: p^{-1}|f_{p}
# ----------------------------------------
#   [235/500] edit_dist=0.0851
#     GT:   m=[\begin{matrix}m_{1}&0\\ 0&m_{2}\end{matrix}]
#     PRED: m=[\begin{matrix}m&0\\ 0&m_{2}\end{matrix}]
# ----------------------------------------
#   [236/500] edit_dist=0.0750
#     GT:   [\begin{matrix}x&0\\ 0&y\\ \end{matrix}]
#     PRED: [\begin{matrix}x&0\\ 0&y\end{matrix}]
# ----------------------------------------
#   [237/500] edit_dist=0.2195
#     GT:   e\cap\overline{e}=\delta\otimes c
#     PRED: e\cap\overline{e}=\delta\otimes\mathbb{c}
# ----------------------------------------
#   [238/500] edit_dist=0.0909
#     GT:   f[x,y]/(xy)
#     PRED: f[x,y]/(x)
# ----------------------------------------
#   [239/500] EXACT
#     GT:   \tilde{m}=m//g
#     PRED: \tilde{m}=m//g
# ----------------------------------------
#   [240/500] EXACT
#     GT:   \int_{a}^{b}f(x)dx
#     PRED: \int_{a}^{b}f(x)dx
# ----------------------------------------
#   [241/500] edit_dist=0.2857
#     GT:   s=\int ldx_{3}
#     PRED: s=\int ldxdx
# ----------------------------------------
#   [242/500] edit_dist=0.2917
#     GT:   ff\in l^{1}(r^{n})
#     PRED: f=f\in l^{\prime}(r^{n})
# ----------------------------------------
#   [243/500] EXACT
#     GT:   (\begin{matrix}n\\ c\end{matrix})
#     PRED: (\begin{matrix}n\\ c\end{matrix})
# ----------------------------------------
#   [244/500] edit_dist=0.1471
#     GT:   g_{kl}=2\chi\delta n\overline{n}
#     PRED: g_{kl}=2\times\delta n\overline{n}
# ----------------------------------------
#   [245/500] edit_dist=0.0500
#     GT:   y=a\frac{d-c}{a-b}+c
#     PRED: y=a\frac{2-c}{a-b}+c
# ----------------------------------------
#   [246/500] EXACT
#     GT:   [\frac{\alpha}{\pi}]=[\frac{\alpha}{\theta}]
#     PRED: [\frac{\alpha}{\pi}]=[\frac{\alpha}{\theta}]
# ----------------------------------------
#   [247/500] edit_dist=0.5217
#     GT:   dir(\alpha/k\cdot1_{k})
#     PRED: din(\alpha\kappa,2\nu)
# ----------------------------------------
#   [248/500] EXACT
#     GT:   \int ldt
#     PRED: \int ldt
# ----------------------------------------
#   [249/500] edit_dist=0.2143
#     GT:   d_{e}(x_{e}+1)
#     PRED: de(x_{e}+1)
# ----------------------------------------
#   [250/500] EXACT
#     GT:   \{\begin{matrix}3\\ 3\end{matrix}\}
#     PRED: \{\begin{matrix}3\\ 3\end{matrix}\}
# ----------------------------------------
#   [251/500] edit_dist=0.2609
#     GT:   \delta e^{tot}=q+w
#     PRED: \delta e^{tot}=q+\omega
# ----------------------------------------
#   [252/500] edit_dist=0.0714
#     GT:   d_{e}(x_{e}+1)
#     PRED: a_{e}(x_{e}+1)
# ----------------------------------------
#   [253/500] EXACT
#     GT:   |z|=\sqrt{a^{2}+b^{2}}
#     PRED: |z|=\sqrt{a^{2}+b^{2}}
# ----------------------------------------
#   [254/500] edit_dist=0.3333
#     GT:   4\sigma/\sqrt{n}=w
#     PRED: 4r/\sqrt{n}=w
# ----------------------------------------
#   [255/500] edit_dist=0.0244
#     GT:   [\begin{matrix}b/d&p\\ c/d&q\end{matrix}]
#     PRED: [\begin{matrix}b/d&p\\ 0/d&q\end{matrix}]
# ----------------------------------------
#   [256/500] EXACT
#     GT:   dm=(\frac{dy}{l})m
#     PRED: dm=(\frac{dy}{l})m
# ----------------------------------------
#   [257/500] EXACT
#     GT:   a_{\epsilon}^{n}(x,y)
#     PRED: a_{\epsilon}^{n}(x,y)
# ----------------------------------------
#   [258/500] edit_dist=0.1364
#     GT:   \mu y=\int\mu q(x)dx
#     PRED: \mu_{y}=\int\mu q(x)dx
# ----------------------------------------
#   [259/500] edit_dist=0.4286
#     GT:   d_{p}^{1}
#     PRED: d_{p}^{\prime}
# ----------------------------------------
#   [260/500] edit_dist=0.3125
#     GT:   p(x<a)=0.98
#     PRED: p(x<\alpha)=0.98
# ----------------------------------------
#   [261/500] EXACT
#     GT:   \hat{p}
#     PRED: \hat{p}
# ----------------------------------------
#   [262/500] edit_dist=0.2051
#     GT:   |\epsilon_{n+1}|\le m{\epsilon_{n}}^{2}
#     PRED: |\xi_{n+1}|\le m\epsilon_{n}^{2}
# ----------------------------------------
#   [263/500] edit_dist=0.2340
#     GT:   p=\frac{e}{t}=\frac{1}{2}a\rho v^{3}
#     PRED: p=\frac{\overline{z}}{t}=\frac{1}{2}a\rho v^{3}
# ----------------------------------------
#   [264/500] edit_dist=0.0513
#     GT:   a=\frac{m}{\rho}\frac{n^{2}-1}{n^{2}+2}
#     PRED: a=\frac{m}{\rho}\frac{n^{2}-1}{n^{2+2}}
# ----------------------------------------
#   [265/500] EXACT
#     GT:   \int f(x,y)dx
#     PRED: \int f(x,y)dx
# ----------------------------------------
#   [266/500] edit_dist=0.2308
#     GT:   x\mapsto xcos(2\pi x)+1
#     PRED: x\mapsto x\in cos(2\pi x)t
# ----------------------------------------
#   [267/500] edit_dist=0.2917
#     GT:   e=\gamma_{(u)}m_{0}c^{2}
#     PRED: e=\gamma_{(w)m}cos^{2}
# ----------------------------------------
#   [268/500] EXACT
#     GT:   \frac{dh}{dt}=0
#     PRED: \frac{dh}{dt}=0
# ----------------------------------------
#   [269/500] edit_dist=0.0417
#     GT:   \int_{1}^{3}(27-x^{3})dx
#     PRED: \int_{1}^{3}(27-x^{4})dx
# ----------------------------------------
#   [270/500] EXACT
#     GT:   \int_{s}1ds
#     PRED: \int_{s}1ds
# ----------------------------------------
#   [271/500] edit_dist=0.0270
#     GT:   \omega=\frac{d\theta}{dt}=\frac{v}{r}
#     PRED: \omega=\frac{d\theta}{dt}=\frac{v}{p}
# ----------------------------------------
#   [272/500] EXACT
#     GT:   \tilde{e}=\gamma(-,e)
#     PRED: \tilde{e}=\gamma(-,e)
# ----------------------------------------
#   [273/500] edit_dist=0.3333
#     GT:   f_{\alpha}(x)=-f_{\alpha}(\tilde{x})
#     PRED: f_{d}(x)=-f_{d}(\tilde{x})
# ----------------------------------------
#   [274/500] EXACT
#     GT:   \sqrt{\theta}
#     PRED: \sqrt{\theta}
# ----------------------------------------
#   [275/500] EXACT
#     GT:   \psi
#     PRED: \psi
# ----------------------------------------
#   [276/500] edit_dist=0.4545
#     GT:   n^{1/h}\le|b\cap[1,n]|
#     PRED: n^{y_{h}}\lefbart[1,n]
# ----------------------------------------
#   [277/500] edit_dist=0.3103
#     GT:   \int_{\mathbb{r}}f(x-y)g(y)dy
#     PRED: \int_{\pi}f(x-y)g(y)dy
# ----------------------------------------
#   [278/500] EXACT
#     GT:   1-2-3
#     PRED: 1-2-3
# ----------------------------------------
#   [279/500] edit_dist=0.0698
#     GT:   \sum_{n=0}^{n}(\begin{matrix}n\\ n\end{matrix})^{2}=(\begin{matrix}2n\\ n\end{ma
#     PRED: \sum_{n=0}^{n}(\begin{matrix}n\\ n\end{matrix})=(\begin{matrix}2&v\\ n\end{matri
# ----------------------------------------
#   [280/500] edit_dist=0.0345
#     GT:   \chi_{imp}=\frac{c}{t+\theta}
#     PRED: \chi_{inp}=\frac{c}{t+\theta}
# ----------------------------------------
#   [281/500] edit_dist=0.0952
#     GT:   \frac{b_{2}-1}{b_{1}b_{2}}=\frac{1}{b_{1}}-\frac{1}{b_{1}b_{2}}
#     PRED: \frac{b_{2}-1}{b_{1}b}=\frac{1}{b_{2}},\frac{1}{b_{1}b_{2}}
# ----------------------------------------
#   [282/500] edit_dist=0.1250
#     GT:   k=\int|\kappa|ds
#     PRED: k=\int1\kappa/ds
# ----------------------------------------
#   [283/500] edit_dist=0.1875
#     GT:   \int_{d}^{\infty}e^{f(x)}dx
#     PRED: \int_{\alpha}^{\infty}e^{f(x)}dx
# ----------------------------------------
#   [284/500] edit_dist=0.2000
#     GT:   e(k)=\hat{x}(k)-x(k)
#     PRED: e(k)=\hat{x}(\kappa)-x(k)
# ----------------------------------------
#   [285/500] edit_dist=0.1875
#     GT:   p=\{p_{\theta}|\theta\in\theta\}
#     PRED: p=\{p_{0}|\theta\in\theta\}
# ----------------------------------------
#   [286/500] EXACT
#     GT:   i=\int xcos(x)dx
#     PRED: i=\int xcos(x)dx
# ----------------------------------------
#   [287/500] edit_dist=0.4000
#     GT:   dn(m,z)/dm
#     PRED: d\wedge(m,z)/dm
# ----------------------------------------
#   [288/500] edit_dist=0.1429
#     GT:   \frac{4}{12}\times\frac{23}{12}=0.63\dot{8}ft^{2}
#     PRED: \frac{4}{12}\times\frac{23}{12}=0.63\theta t^{2}
# ----------------------------------------
#   [289/500] EXACT
#     GT:   \tilde{b}_{5}
#     PRED: \tilde{b}_{5}
# ----------------------------------------
#   [290/500] EXACT
#     GT:   m=[\begin{matrix}a&b-a\\ 0&b\end{matrix}]
#     PRED: m=[\begin{matrix}a&b-a\\ 0&b\end{matrix}]
# ----------------------------------------
#   [291/500] EXACT
#     GT:   \hat{y}\in\{-1,1\}
#     PRED: \hat{y}\in\{-1,1\}
# ----------------------------------------
#   [292/500] EXACT
#     GT:   \hat{h}=\hat{h}(\hat{p})
#     PRED: \hat{h}=\hat{h}(\hat{p})
# ----------------------------------------
#   [293/500] EXACT
#     GT:   f=p-\frac{\partial v}{\partial r}
#     PRED: f=p-\frac{\partial v}{\partial r}
# ----------------------------------------
#   [294/500] edit_dist=0.1212
#     GT:   \sum_{l}l^{2}4^{-2l}e^{-4\beta l}
#     PRED: \sum_{l}l^{2}4^{-2l-4\beta l}
# ----------------------------------------
#   [295/500] edit_dist=0.1000
#     GT:   30<\epsilon_{r}<50
#     PRED: 30<\epsilon<r_{r}<50
# ----------------------------------------
#   [296/500] edit_dist=0.4231
#     GT:   fx/so(1,3)\rightarrow x
#     PRED: f\times/50013\rightarrow x
# ----------------------------------------
#   [297/500] EXACT
#     GT:   \frac{\partial q^{i}}{\partial x_{j}}
#     PRED: \frac{\partial q^{i}}{\partial x_{j}}
# ----------------------------------------
#   [298/500] EXACT
#     GT:   \tilde{t}_{i}
#     PRED: \tilde{t}_{i}
# ----------------------------------------
#   [299/500] edit_dist=0.5357
#     GT:   ra=\{ra|r\in r\}
#     PRED: r_{a}=\{ral\in r\mathbb{r}\}
# ----------------------------------------
#   [300/500] edit_dist=0.0833
#     GT:   \tilde{u}(x)
#     PRED: \tilde{x}(x)
# ----------------------------------------
#   [301/500] edit_dist=0.7021
#     GT:   value=\lambda v.(\lambda h.hv)
#     PRED: udece=\tau_{0}\cdot(\lambda n\cdot n\cdot n\mu)
# ----------------------------------------
#   [302/500] EXACT
#     GT:   \sqrt{(}t)
#     PRED: \sqrt{(}t)
# ----------------------------------------
#   [303/500] edit_dist=0.2308
#     GT:   \prod_{i=n-r+1}^{n}i
#     PRED: \prod_{i=n-r+r+1}^{n}i^{i}
# ----------------------------------------
#   [304/500] edit_dist=0.0769
#     GT:   \tilde{g}_{n}
#     PRED: \tilde{g}_{m}
# ----------------------------------------
#   [305/500] EXACT
#     GT:   \frac{df}{dz}=g
#     PRED: \frac{df}{dz}=g
# ----------------------------------------
#   [306/500] EXACT
#     GT:   f=\tilde{f}i
#     PRED: f=\tilde{f}i
# ----------------------------------------
#   [307/500] edit_dist=0.2143
#     GT:   e_{p,m}=\frac{1}{2}li^{2}
#     PRED: e_{pm}=\frac{1}{2}l\beta^{2}
# ----------------------------------------
#   [308/500] EXACT
#     GT:   (c-r)
#     PRED: (c-r)
# ----------------------------------------
#   [309/500] EXACT
#     GT:   i\notin x
#     PRED: i\notin x
# ----------------------------------------
#   [310/500] EXACT
#     GT:   \sqrt{0}
#     PRED: \sqrt{0}
# ----------------------------------------
#   [311/500] edit_dist=0.1250
#     GT:   t^{*}=\frac{(t-t_{o})}{(t_{s}-t_{o})}
#     PRED: \tau^{*}=\frac{(t-t_{0})}{(t_{s}-t_{0})}
# ----------------------------------------
#   [312/500] EXACT
#     GT:   t(p)=\frac{1-z_{a}}{1+z_{a}}
#     PRED: t(p)=\frac{1-z_{a}}{1+z_{a}}
# ----------------------------------------
#   [313/500] EXACT
#     GT:   \tilde{\chi}
#     PRED: \tilde{\chi}
# ----------------------------------------
#   [314/500] EXACT
#     GT:   \int cos^{2}xdx
#     PRED: \int cos^{2}xdx
# ----------------------------------------
#   [315/500] edit_dist=0.2500
#     GT:   o()
#     PRED: o(g)
# ----------------------------------------
#   [316/500] EXACT
#     GT:   \sqrt{t}
#     PRED: \sqrt{t}
# ----------------------------------------
#   [317/500] EXACT
#     GT:   b^{\prime}\in(\begin{matrix}c\\ b\end{matrix})
#     PRED: b^{\prime}\in(\begin{matrix}c\\ b\end{matrix})
# ----------------------------------------
#   [318/500] edit_dist=0.1429
#     GT:   \omega=\rho+i\tilde{\rho}(\rho)
#     PRED: \omega=\rho+i\tilde{\rho}^{(\rho i}
# ----------------------------------------
#   [319/500] edit_dist=0.0625
#     GT:   m(a)=\int_{a}xdn
#     PRED: m(a)=\int_{a}xdd
# ----------------------------------------
#   [320/500] edit_dist=0.5385
#     GT:   q(\sqrt{13})
#     PRED: \begin{matrix}q(\sqrt{13})
# ----------------------------------------
#   [321/500] EXACT
#     GT:   c(\vec{n})
#     PRED: c(\vec{n})
# ----------------------------------------
#   [322/500] EXACT
#     GT:   ss\{\begin{matrix}2\\ 4\end{matrix}\}
#     PRED: ss\{\begin{matrix}2\\ 4\end{matrix}\}
# ----------------------------------------
#   [323/500] edit_dist=0.6154
#     GT:   c_{\tilde{y}}
#     PRED: c_{y}
# ----------------------------------------
#   [324/500] EXACT
#     GT:   \{(-1)^{\pi}\}
#     PRED: \{(-1)^{\pi}\}
# ----------------------------------------
#   [325/500] EXACT
#     GT:   \frac{\partial}{\partial\theta}
#     PRED: \frac{\partial}{\partial\theta}
# ----------------------------------------
#   [326/500] EXACT
#     GT:   \{1,2,3\}\notin\{1,2,3\}
#     PRED: \{1,2,3\}\notin\{1,2,3\}
# ----------------------------------------
#   [327/500] EXACT
#     GT:   \mu_{0}\epsilon_{0}=1/c^{2}
#     PRED: \mu_{0}\epsilon_{0}=1/c^{2}
# ----------------------------------------
#   [328/500] edit_dist=0.1364
#     GT:   u=2\sqrt{-\frac{p}{3}}
#     PRED: u=\sqrt[-\frac{p}{3}
# ----------------------------------------
#   [329/500] edit_dist=0.4186
#     GT:   \frac{\partial}{\partial z}p_{c}^{p}(z_{0})
#     PRED: \frac{\partial p_{c}^{p}}{(l^{p}})
# ----------------------------------------
#   [330/500] EXACT
#     GT:   \frac{1}{2}v^{2}=u(x)
#     PRED: \frac{1}{2}v^{2}=u(x)
# ----------------------------------------
#   [331/500] EXACT
#     GT:   \tilde{d}_{6}
#     PRED: \tilde{d}_{6}
# ----------------------------------------
#   [332/500] edit_dist=0.1212
#     GT:   \int_{t-r}^{t}e(t^{\prime})dt
#     PRED: \int_{t-r}^{t}e(t^{\prime})dt^{t}
# ----------------------------------------
#   [333/500] edit_dist=0.0370
#     GT:   ai_{t}=100\times\frac{d}{n}
#     PRED: ai_{t}=100\times\frac{2}{n}
# ----------------------------------------
#   [334/500] EXACT
#     GT:   \int_{0}^{t}z_{s}ds
#     PRED: \int_{0}^{t}z_{s}ds
# ----------------------------------------
#   [335/500] edit_dist=0.0667
#     GT:   (a^{t}a)^{-1}=q
#     PRED: (a^{+}a)^{-1}=q
# ----------------------------------------
#   [336/500] edit_dist=0.1429
#     GT:   hr\{\begin{matrix}p\\ q\end{matrix}\}
#     PRED: h\notin\{\begin{matrix}p\\ q\end{matrix}\}
# ----------------------------------------
#   [337/500] EXACT
#     GT:   \int_{c}^{d}f(x)dx
#     PRED: \int_{c}^{d}f(x)dx
# ----------------------------------------
#   [338/500] EXACT
#     GT:   [\gamma^{\mu},\gamma^{\nu}]_{+}=2g^{\mu\nu}
#     PRED: [\gamma^{\mu},\gamma^{\nu}]_{+}=2g^{\mu\nu}
# ----------------------------------------
#   [339/500] edit_dist=0.6316
#     GT:   j_{(z_{v})}
#     PRED: \overline{j}(z_{v})
# ----------------------------------------
#   [340/500] EXACT
#     GT:   \gamma_{nl}|a|^{2}a
#     PRED: \gamma_{nl}|a|^{2}a
# ----------------------------------------
#   [341/500] EXACT
#     GT:   \prod_{n}(z-c_{n})
#     PRED: \prod_{n}(z-c_{n})
# ----------------------------------------
#   [342/500] EXACT
#     GT:   \tilde{\pi}
#     PRED: \tilde{\pi}
# ----------------------------------------
#   [343/500] edit_dist=0.2973
#     GT:   q(\theta^{(t)}|\theta^{(t)})
#     PRED: \mathbb{q}(\theta^{(t)|\theta^{(t)})}
# ----------------------------------------
#   [344/500] EXACT
#     GT:   (i+2^{-n}m)^{2^{n}}
#     PRED: (i+2^{-n}m)^{2^{n}}
# ----------------------------------------
#   [345/500] edit_dist=0.0435
#     GT:   \int_{0}^{3}|x^{2}-4|dx
#     PRED: \int_{0}^{3}|x^{2}-4/dx
# ----------------------------------------
#   [346/500] EXACT
#     GT:   \tilde{l}
#     PRED: \tilde{l}
# ----------------------------------------
#   [347/500] edit_dist=0.5789
#     GT:   \underline{\underline{k}}=\underline{\underline{a^{t}ka}}
#     PRED: \underline{k}=\frac{a^{t}ka}{-}
# ----------------------------------------
#   [348/500] edit_dist=0.2308
#     GT:   -\vec{\omega}\times\vec{r}
#     PRED: -\vec{w}\times\vec{r}
# ----------------------------------------
#   [349/500] EXACT
#     GT:   \int_{1}^{3}(27-x^{3})dx
#     PRED: \int_{1}^{3}(27-x^{3})dx
# ----------------------------------------
#   [350/500] edit_dist=0.2609
#     GT:   ff\in l^{1}(r^{n})
#     PRED: ff\in l^{\prime}(r^{n})
# ----------------------------------------
#   [351/500] edit_dist=0.7267
#     GT:   \mu_{g}(h_{1},h_{2})=(-1)^{k}p^{(\begin{matrix}k\\ 2\end{matrix})}
# ...
#   [389/500] EXACT
#     GT:   (\begin{matrix}4\\ 7\end{matrix})
#     PRED: (\begin{matrix}4\\ 7\end{matrix})
# ----------------------------------------
#   [390/500] EXACT
#     GT:   \int_{0}^{1}-ln(x)f(x)dx
#     PRED: \int_{0}^{1}-ln(x)f(x)dx
# ----------------------------------------
#   [391/500] edit_dist=0.2045
#     GT:   f_{\xi}(x)=\langle\xi|\pi(x)\xi\rangle
#     PRED: f_{\xi}(x)=\langle\backslash\pi(x)\xi\rangle
# ----------------------------------------
#   [392/500] EXACT
#     GT:   \int\frac{dy}{y}
#     PRED: \int\frac{dy}{y}
# ----------------------------------------
#   [393/500] edit_dist=0.4167
#     GT:   o(n^{log_{2}3})
#     PRED: \sigma(n^{logg_{2}}^{3})
# ----------------------------------------
#   [394/500] EXACT
#     GT:   (\begin{matrix}1&2\\ 2&4\end{matrix})
#     PRED: (\begin{matrix}1&2\\ 2&4\end{matrix})
# ----------------------------------------
#   [395/500] edit_dist=0.0417
#     GT:   e=\sqrt{h^{2}+(a-b)^{2}}
#     PRED: e=\sqrt{4^{2}+(a-b)^{2}}
# ----------------------------------------
#   [396/500] edit_dist=0.5217
#     GT:   \hat{\zeta}_{0}(\omega)
#     PRED: \hat{s}_{d}(w)
# ----------------------------------------
#   [397/500] edit_dist=0.4688
#     GT:   0,c_{i},-c_{i},c_{i}^{*}
#     PRED: 0,c_{i}-l_{i}l_{i}^{\frac{1}{2}}
# ----------------------------------------
#   [398/500] EXACT
#     GT:   \varphi
#     PRED: \varphi
# ----------------------------------------
#   [399/500] edit_dist=0.1538
#     GT:   p_{max}=\frac{1}{4}p_{max}q_{max}
#     PRED: p_{max}=\frac{1}{4}p_{max}\circ q_{max}
# ----------------------------------------
#   [400/500] edit_dist=0.0976
#     GT:   [\begin{matrix}x&=&p\\ y&=&p\end{matrix}]
#     PRED: [\begin{matrix}x&p\\ y&p\end{matrix}]
# ----------------------------------------
#   [401/500] edit_dist=0.3000
#     GT:   -a(e-1)
#     PRED: -a(e^{-1})
# ----------------------------------------
#   [402/500] edit_dist=0.3846
#     GT:   m^{+}\oplus l
#     PRED: m^{+}\theta l
# ----------------------------------------
#   [403/500] edit_dist=0.1429
#     GT:   ||f_{n}(x)||_{b}\le g(x)
#     PRED: ||f_{n}(x)||_{b}\le g_{f}(x)
# ----------------------------------------
#   [404/500] edit_dist=0.2632
#     GT:   \frac{2}{\frac{1}{60}+\frac{1}{40}}=48
#     PRED: \frac{2}{6^{0}+\frac{1}{400}}=48
# ----------------------------------------
#   [405/500] edit_dist=0.2353
#     GT:   i(x;y)\le h(x)
#     PRED: i(x_{1}y)\le h(x)
# ----------------------------------------
#   [406/500] EXACT
#     GT:   \hat{z}
#     PRED: \hat{z}
# ----------------------------------------
#   [407/500] edit_dist=0.4348
#     GT:   s\approx l_{isco}+s_{1}
#     PRED: s\approx lise0+5
# ----------------------------------------
#   [408/500] EXACT
#     GT:   p_{i}\#=\prod_{j=1}^{i}p_{j}
#     PRED: p_{i}\#=\prod_{j=1}^{i}p_{j}
# ----------------------------------------
#   [409/500] EXACT
#     GT:   \int_{\gamma}dz=0
#     PRED: \int_{\gamma}dz=0
# ----------------------------------------
#   [410/500] edit_dist=0.2667
#     GT:   \chi_{0.50}^{2}
#     PRED: x_{0.50}^{2}
# ----------------------------------------
#   [411/500] EXACT
#     GT:   \hat{b}_{i}
#     PRED: \hat{b}_{i}
# ----------------------------------------
#   [412/500] EXACT
#     GT:   \tilde{e}_{i}l\subset l
#     PRED: \tilde{e}_{i}l\subset l
# ----------------------------------------
#   [413/500] edit_dist=0.2000
#     GT:   y_{i,j}=\sqrt{x_{i,j}}
#     PRED: y_{i,j}=\sqrt{x_{i}w_{n}}
# ----------------------------------------
#   [414/500] EXACT
#     GT:   (\begin{matrix}m\\ r\end{matrix})_{q}
#     PRED: (\begin{matrix}m\\ r\end{matrix})_{q}
# ----------------------------------------
#   [415/500] EXACT
#     GT:   e
#     PRED: e
# ----------------------------------------
#   [416/500] edit_dist=0.0455
#     GT:   v(t)=i\frac{dl(t)}{dt}
#     PRED: v(t)=i\frac{di(t)}{dt}
# ----------------------------------------
#   [417/500] edit_dist=0.5405
#     GT:   r=\sum_{a\in\sigma}v(a)r_{a}
#     PRED: r=\sum_{\in\simes}\sum_{a\in z}j(a)/r
# ----------------------------------------
#   [418/500] edit_dist=0.0769
#     GT:   c_{h}\ge\frac{t}{\chi_{t}}(\frac{\partial m}{\partial t})_{h}^{2}
#     PRED: c_{h}\ge\frac{t}{x^{t}}(\frac{\partial m}{\partial t})_{h}^{2}
# ----------------------------------------
#   [419/500] EXACT
#     GT:   n_{\alpha}^{l}
#     PRED: n_{\alpha}^{l}
# ----------------------------------------
#   [420/500] edit_dist=0.1613
#     GT:   \kappa=a_{p}^{-1}(\overline{r})
#     PRED: k=a_{p}^{-1}(\overline{r})
# ----------------------------------------
#   [421/500] EXACT
#     GT:   r_{0,1}=2.405
#     PRED: r_{0,1}=2.405
# ----------------------------------------
#   [422/500] EXACT
#     GT:   \hat{w}(f)
#     PRED: \hat{w}(f)
# ----------------------------------------
#   [423/500] edit_dist=0.2326
#     GT:   \underline{p}(cl_{1}^{\le})=\{x_{1},x_{5}\}
#     PRED: \underline{p}(c|\vec{1})=\{x_{1},x_{t}\}
# ----------------------------------------
#   [424/500] EXACT
#     GT:   \sqrt{a^{2}+b^{2}}=c
#     PRED: \sqrt{a^{2}+b^{2}}=c
# ----------------------------------------
#   [425/500] edit_dist=0.2093
#     GT:   \underline{p}(cl_{1}^{\le})=\{x_{1},x_{5}\}
#     PRED: \underline{p}(cl\le\}=\{x_{1},x_{s}\}
# ----------------------------------------
#   [426/500] EXACT
#     GT:   \infty k\delta(s)\hat{z}
#     PRED: \infty k\delta(s)\hat{z}
# ----------------------------------------
#   [427/500] edit_dist=0.7391
#     GT:   1019(4.163\%)
#     PRED: 10/96463^{\circ}^{0}(0)
# ----------------------------------------
#   [428/500] EXACT
#     GT:   \{\begin{matrix}3\\ 7\end{matrix}\}
#     PRED: \{\begin{matrix}3\\ 7\end{matrix}\}
# ----------------------------------------
#   [429/500] EXACT
#     GT:   b(1-a-d)=0
#     PRED: b(1-a-d)=0
# ----------------------------------------
#   [430/500] edit_dist=0.4348
#     GT:   \frac{\partial n}{\partial t}=-\nabla\cdot j+w
#     PRED: \frac{2n}{2t}=-\nabla\cdot s+tw
# ----------------------------------------
#   [431/500] EXACT
#     GT:   \int_{a}^{b}f(x)dx
#     PRED: \int_{a}^{b}f(x)dx
# ----------------------------------------
#   [432/500] edit_dist=0.1250
#     GT:   m(l)_{n}=m_{n+l}
#     PRED: m(i)_{n}=m_{n+1}
# ----------------------------------------
#   [433/500] EXACT
#     GT:   pr(r_{i}<\underline{r})
#     PRED: pr(r_{i}<\underline{r})
# ----------------------------------------
#   [434/500] EXACT
#     GT:   c_{x\tilde{y}}
#     PRED: c_{x\tilde{y}}
# ----------------------------------------
#   [435/500] edit_dist=0.9000
#     GT:   l
#     PRED: \mathbb{l}
# ----------------------------------------
#   [436/500] edit_dist=0.0345
#     GT:   l=\frac{1}{k}l=i-\frac{1}{k}a
#     PRED: l=\frac{1}{k}l=l-\frac{1}{k}a
# ----------------------------------------
#   [437/500] edit_dist=0.0800
#     GT:   \sigma_{y=0},\sigma_{y=1}
#     PRED: \sigma_{y}=0,\sigma_{y=1}
# ----------------------------------------
#   [438/500] EXACT
#     GT:   \hat{1}
#     PRED: \hat{1}
# ----------------------------------------
#   [439/500] EXACT
#     GT:   \frac{n}{2\pi}sin\frac{2\pi}{n}
#     PRED: \frac{n}{2\pi}sin\frac{2\pi}{n}
# ----------------------------------------
#   [440/500] edit_dist=0.3158
#     GT:   \partial_{t}u=\delta u+\xi
#     PRED: \partial_{t}u=\delta u+t\epsilon^{\xi}
# ----------------------------------------
#   [441/500] edit_dist=0.8077
#     GT:   \phi=\bigwedge_{r}\phi_{r}
#     PRED: \omega=\lambda\beta_{c}
# ----------------------------------------
#   [442/500] edit_dist=0.2903
#     GT:   \hat{l}x(x)=\lambda x(x)
#     PRED: \frac{l}{x}(x)=\lambda x\chi(x)
# ----------------------------------------
#   [443/500] EXACT
#     GT:   \{\begin{matrix}3\\ 5\end{matrix}\}
#     PRED: \{\begin{matrix}3\\ 5\end{matrix}\}
# ----------------------------------------
#   [444/500] edit_dist=0.1000
#     GT:   12^{2}+35^{2}=37^{2}
#     PRED: |2^{2}+35^{2}=31^{2}
# ----------------------------------------
#   [445/500] EXACT
#     GT:   \overline{z}
#     PRED: \overline{z}
# ----------------------------------------
#   [446/500] EXACT
#     GT:   \frac{da}{dt}=[a,h]+\frac{\partial a}{\partial t}
#     PRED: \frac{da}{dt}=[a,h]+\frac{\partial a}{\partial t}
# ----------------------------------------
#   [447/500] edit_dist=0.3684
#     GT:   a]=\{x\le a\}
#     PRED: \sigma j=\{x\le a\}
# ----------------------------------------
#   [448/500] edit_dist=0.4737
#     GT:   \sigma_{1}\mapsto(-t)
#     PRED: \sigma_{y}\mapsto(\rho)-\frac{-t}{(t)}
# ----------------------------------------
#   [449/500] EXACT
#     GT:   (\begin{matrix}i&-1\\ i&1\end{matrix})
#     PRED: (\begin{matrix}i&-1\\ i&1\end{matrix})
# ----------------------------------------
#   [450/500] edit_dist=0.1860
#     GT:   \hat{q}=2^{-1/2}(\hat{a}^{\dagger}+\hat{a})
#     PRED: \hat{q}=2^{-12}(\hat{a}^{t}+\hat{a})
# ----------------------------------------
#   [451/500] EXACT
#     GT:   \frac{dn}{dt}
#     PRED: \frac{dn}{dt}
# ----------------------------------------
#   [452/500] edit_dist=0.3478
#     GT:   2\pi ib|db|=i\frac{d\sigma}{d\omega}d\omega
#     PRED: 2\pi ib_{b}d(b_{b})=i\frac{d\sigma}{d\omega}ds
# ----------------------------------------
#   [453/500] EXACT
#     GT:   (\begin{matrix}1&d\\ 0&1\end{matrix})
#     PRED: (\begin{matrix}1&d\\ 0&1\end{matrix})
# ----------------------------------------
#   [454/500] edit_dist=0.0769
#     GT:   \int f(x)dx=1
#     PRED: \int r(x)dx=1
# ----------------------------------------
#   [455/500] edit_dist=0.1071
#     GT:   v_{-}=be^{\frac{-1}{rc}t}
#     PRED: v_{-}=be^{\frac{-1}{rc}}^{t}
# ----------------------------------------
#   [456/500] EXACT
#     GT:   \hat{l}^{2}
#     PRED: \hat{l}^{2}
# ----------------------------------------
#   [457/500] EXACT
#     GT:   \tilde{v}
#     PRED: \tilde{v}
# ----------------------------------------
#   [458/500] edit_dist=0.0556
#     GT:   p(r)=\frac{1}{z}e^{-\frac{f(r)}{kt}}
#     PRED: p(r)=\frac{1}{z}e^{\frac{-f(r)}{kt}}
# ----------------------------------------
#   [459/500] edit_dist=0.1500
#     GT:   f^{2}=k_{1}k_{2}\frac{m_{1}m_{2}}{r^{2}}
#     PRED: f^{2}=k,k_{2}\frac{m_{1}\mu_{2}}{r^{2}}
# ----------------------------------------
#   [460/500] EXACT
#     GT:   (\begin{matrix}0\\ 1\end{matrix})
#     PRED: (\begin{matrix}0\\ 1\end{matrix})
# ----------------------------------------
#   [461/500] edit_dist=0.1818
#     GT:   \frac{\partial x}{\partial\theta}
#     PRED: \frac{\partial x}{\partial b}
# ----------------------------------------
#   [462/500] edit_dist=0.0333
#     GT:   k([\overline{x}])=i^{r-1}([y])
#     PRED: k([\overline{x}])=i^{r-1}([x])
# ----------------------------------------
#   [463/500] edit_dist=0.5085
#     GT:   [a,\overline{q}]=\frac{1}{2}\overline{q}
#     PRED: \{\mathbb{a},\overline{\alpha}]=\frac{1}{2}\omega^{-}\omega
# ----------------------------------------
#   [464/500] EXACT
#     GT:   \tilde{t}_{i}
#     PRED: \tilde{t}_{i}
# ----------------------------------------
#   [465/500] edit_dist=0.2766
#     GT:   m_{j}\sim\rho^{\frac{3}{2}(\gamma-\frac{4}{3})}
#     PRED: m_{j}\sim\rho_{\rho\frac{3}{2}}(r-\frac{4}{3})
# ----------------------------------------
#   [466/500] EXACT
#     GT:   \sqrt{(}t)
#     PRED: \sqrt{(}t)
# ----------------------------------------
#   [467/500] EXACT
#     GT:   t=\sqrt{n_{0}/2^{k}}
#     PRED: t=\sqrt{n_{0}/2^{k}}
# ----------------------------------------
#   [468/500] EXACT
#     GT:   (=\hat{\beta}\hat{\alpha})
#     PRED: (=\hat{\beta}\hat{\alpha})
# ----------------------------------------
#   [469/500] edit_dist=0.0541
#     GT:   (\begin{matrix}1&t\\ 0&1\end{matrix})
#     PRED: (\begin{matrix}3&t\\ 0&s\end{matrix})
# ----------------------------------------
#   [470/500] EXACT
#     GT:   \frac{(2b^{2}+2c^{2}-a^{2})}{4}
#     PRED: \frac{(2b^{2}+2c^{2}-a^{2})}{4}
# ----------------------------------------
#   [471/500] EXACT
#     GT:   \int\sigma_{x}da=0
#     PRED: \int\sigma_{x}da=0
# ----------------------------------------
#   [472/500] edit_dist=0.3871
#     GT:   h[w_{1},...,w_{n}]|j|
#     PRED: h[\omega_{1},...,\omega_{n}]|j|
# ----------------------------------------
#   [473/500] EXACT
#     GT:   \frac{du}{ds}=0
#     PRED: \frac{du}{ds}=0
# ----------------------------------------
#   [474/500] EXACT
#     GT:   \overline{x}\sim n(\mu,\sigma^{2}/n)
#     PRED: \overline{x}\sim n(\mu,\sigma^{2}/n)
# ----------------------------------------
#   [475/500] edit_dist=0.3617
#     GT:   \hat{t}(x)^{-1}\hat{h}\hat{t}(x)=\hat{h}
#     PRED: \hat{t}(\theta^{+}\hat{h}\hat{i}(\alpha)\hat{k}
# ----------------------------------------
#   [476/500] edit_dist=0.1778
#     GT:   (d^{\nabla})^{2}\sigma=f^{\nabla}\wedge\sigma
#     PRED: (d^{\nabla})^{2}\sigma^{\nabla}1\sigma
# ----------------------------------------
#   [477/500] EXACT
#     GT:   z=(\begin{matrix}z&0\\ w&-z\end{matrix})
#     PRED: z=(\begin{matrix}z&0\\ w&-z\end{matrix})
# ----------------------------------------
#   [478/500] EXACT
#     GT:   p(a_{1})\le p(a_{1})
#     PRED: p(a_{1})\le p(a_{1})
# ----------------------------------------
#   [479/500] edit_dist=0.6538
#     GT:   \int dx=x+c
#     PRED: \int\partial_{\lambda}=x+c
# ----------------------------------------
#   [480/500] EXACT
#     GT:   (\begin{matrix}0&0\\ 0&1\end{matrix})
#     PRED: (\begin{matrix}0&0\\ 0&1\end{matrix})
# ----------------------------------------
#   [481/500] edit_dist=0.5263
#     GT:   \gamma_{nl}|a|^{2}a
#     PRED: r_{nel/a}^{2}a
# ----------------------------------------
#   [482/500] edit_dist=0.1852
#     GT:   \int_{v_{1}}^{v_{2}}pdv
#     PRED: \int_{v_{1}}^{v_{2}}d^{d}dv
# ----------------------------------------
#   [483/500] EXACT
#     GT:   c^{n}=\bigoplus_{i=1}^{k}y_{i}
#     PRED: c^{n}=\bigoplus_{i=1}^{k}y_{i}
# ----------------------------------------
#   [484/500] EXACT
#     GT:   \tilde{x}\rightarrow x
#     PRED: \tilde{x}\rightarrow x
# ----------------------------------------
#   [485/500] EXACT
#     GT:   \sqrt{g}
#     PRED: \sqrt{g}
# ----------------------------------------
#   [486/500] edit_dist=0.3607
#     GT:   -\frac{p\dot{r}}{r^{2}}=-\epsilon sin\theta\dot{\theta}
#     PRED: -\frac{p^{\dot}}{p^{2}}=-\epsilon_{i}\omega\times\theta\theta
# ----------------------------------------
#   [487/500] edit_dist=0.0270
#     GT:   15*(\begin{matrix}66\\ 8\end{matrix})
#     PRED: 15*(\begin{matrix}66\\ 3\end{matrix})
# ----------------------------------------
#   [488/500] EXACT
#     GT:   \frac{k_{i}}{k_{d}}=\omega_{0}^{2}
#     PRED: \frac{k_{i}}{k_{d}}=\omega_{0}^{2}
# ----------------------------------------
#   [489/500] EXACT
#     GT:   =k\int_{r}^{\infty}\rho dr
#     PRED: =k\int_{r}^{\infty}\rho dr
# ----------------------------------------
#   [490/500] edit_dist=0.0227
#     GT:   \frac{\partial}{\partial z}f(\overline{z},z)
#     PRED: \frac{\partial}{\partial z}f(\overline{r},z)
# ----------------------------------------
#   [491/500] edit_dist=0.2333
#     GT:   w_{r}=\alpha s+\beta aw_{p}
#     PRED: w_{r}=\alpha\int_{\beta}aw_{p}
# ----------------------------------------
#   [492/500] edit_dist=0.8846
#     GT:   (pf)^{\wedge}=q\hat{f}
#     PRED: \mathbb{p}_{f})^{n}=q^{n}f
# ----------------------------------------
#   [493/500] edit_dist=0.4667
#     GT:   n=\frac{i-r}{||i-r||}
#     PRED: n=\frac{i-r}{1i^{-}r^{\prime}}
# ----------------------------------------
#   [494/500] edit_dist=0.2500
#     GT:   t_{2}=t_{1}e^{\mu_{s}\beta}
#     PRED: t_{\alpha}=t_{1}e^{\mu_{s}}\beta
# ----------------------------------------
#   [495/500] edit_dist=0.2857
#     GT:   \int_{0}^{1}g_{n}=1
#     PRED: \int_{0}^{1}g\sim s=1
# ----------------------------------------
#   [496/500] edit_dist=0.3429
#     GT:   \frac{1}{min_{i}h_{c}(o)-t_{i}}
#     PRED: \frac{1}{min^{\prime}}(rc(0)-t_{i})
# ----------------------------------------
#   [497/500] EXACT
#     GT:   \dot{y}=\frac{1}{c}\overline{h}(0,y,0)
#     PRED: \dot{y}=\frac{1}{c}\overline{h}(0,y,0)
# ----------------------------------------
#   [498/500] edit_dist=0.5806
#     GT:   \frac{dx}{dt}=c
#     PRED: \frac{\partial x}{\partial t}=c
# ----------------------------------------
#   [499/500] edit_dist=0.5974
#     GT:   (\begin{matrix}\alpha&\beta\\ \overline{\beta}&\overline{\alpha}\end{matrix})
#     PRED: (\frac{\alpha}{\beta}\frac{\beta}{\alpha})
# ----------------------------------------
#   [500/500] edit_dist=0.0750
#     GT:   p=(\begin{matrix}a+1\\ 1\\ \end{matrix})
#     PRED: p=(\begin{matrix}a+1\\ 1\end{matrix})
# ----------------------------------------
#
# ============================================================
# SUMMARY
# ============================================================
# Model:                    DinoV2 + LSTM
# Samples:                  500
# Exact match accuracy:     47.00% (235/500)
# Avg normalized edit dist: 0.1350

# %%
import os
print(os.listdir("/kaggle/input/datasets/ronaldtran/run1-output"))
# Out:
# ['dinov2_model256.pt', 'dinov2_model256AttnLstm.pt', 'dinov2_attn_lora256.pt']
